# %%
import json

import datetime, time
import simpy

import shapely.geometry
from simplekml import Kml, Style

import pandas as pd
import openclsim.core as core
import openclsim.model as model

import datetime

import numpy as np

from plot import vessel_planning

from vo_colos.utils.object_registry import SiteRegistry, VesselRegistry
from vo_colos.utils.object_registry import ClassInspect

from vo_colos.utils.base_task import SimulationFactory

# %%
with open("config.json", 'r') as fp:
    config = json.load(fp)

# %%
class message:
    id = 1
    task = {
        "id": 1,
        "engine": "colos",
        "project_id": "1234567890",
        "tag": "testsimulation",
        "config": config["config"],
    }
    status = "new"

sim = SimulationFactory(message)

# %%
sim.simulate()
# Out:
# init
# level: 55
# completed init
# init
# level: 0
# completed init
# init
# level: 0
# completed init
# init
# level: 0
# completed init
# while Activity keep_resources []
# get_full_event : default
# start get_available
# start event instance None
# while Activity keep_resources []
# get_full_event : default
# start get_available
# start event instance None
# <openclsim.model.SequentialActivity object at 0x0000019A7E967C48>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A7E9677C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# <openclsim.model.SequentialActivity object at 0x0000019A08266488>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A08266588>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# put_callback - id_ default
# {}
# put_callback - id_ default
# {'default': {55: <Event() object at 0x19a08266288>}}
# amount :55
# put_callback - id_ default
# {}
# put_callback - id_ default
# {}
# Mover_move after mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_empty1)
# Mover_move after move
# Activity end(sailing_empty)
# <openclsim.model.ShiftAmountActivity object at 0x0000019A082574C8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 55, 'destination.a701b4ec-ab2c-11ea-9b06-2079183a5c9a': 5}
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08266888>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 55, 'destination.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08257708>}
# shift amount process keep_resources []
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08266ac8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08257708>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826adc8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08257708>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826adc8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08257708>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826adc8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08257708>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826adc8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 55, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 55, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0826ae08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 50, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a0826ae08>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 50 of default
#   destination:  barge_1 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08257708>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826adc8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826adc8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826adc8>}
# released processor : {}
# {}
# Activity end(loading1)
# <openclsim.model.MoveActivity object at 0x0000019A082577C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08266ac8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826aa48>}
# Mover_move after mover resource request
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08266ac8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826aa48>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08266ac8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826aa48>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08266ac8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826aa48>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 50, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 50, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0827a288>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 45, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a0827a288>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 45 of default
#   destination:  barge_2 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08266ac8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826aa48>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826aa48>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826ac88>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0826aa48>}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x0000019A08266B88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_full1)
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08257AC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.a701b4ec-ab2c-11ea-9b06-2079183a5c9a': 5, 'destination.to_site': 55}
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aa08>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aa08>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08266ac8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aa08>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08266ac8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aa08>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08266ac8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aa08>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08266ac8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a08266388>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing_full)
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 55}]
# <FilterStoreGet() object at 0x19a0827a448>
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08266E88>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5, 'destination.to_site': 50}
# put_callback - id_ default
# {'default': {55: <Event() object at 0x19a08266288>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_1
#   origin        barge_1  contains: 0 of default
#   destination:  to_site contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aa08>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08266ac8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08266ac8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading1)
# Activity end(WhileFull1)
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a08257408>}
# shift amount process keep_resources []
# start get_available
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000019A7E967C48>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A7E9677C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a08257408>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826a8c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a08257408>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826a8c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a08257408>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826a8c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a08257408>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826a8c8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0826aa08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 5, 'capacity': 55}]
# <FilterStoreGet() object at 0x19a082667c8>
# put_callback - id_ default
# {'default': {55: <Event() object at 0x19a08266288>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 10, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_2
#   origin        barge_2  contains: 0 of default
#   destination:  to_site contains: 10 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a08257408>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826a8c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826a8c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(WhileFull)
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000019A08266488>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A08266588>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_empty1)
# <openclsim.model.ShiftAmountActivity object at 0x0000019A082574C8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 45, 'destination.a701b4ec-ab2c-11ea-9b06-2079183a5c9a': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826ab08>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826ab08>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826ab08>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a388>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826ab08>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a388>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826ab08>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a388>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 45, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 45, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0827a608>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 40, 'capacity': 55}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing_empty)
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a0826aa08>
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08266888>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 40, 'destination.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5}
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 40 of default
#   destination:  barge_1 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826ab08>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a388>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a388>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>}
# released processor : {}
# {}
# Activity end(loading1)
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826ac48>}
# shift amount process keep_resources []
# start get_available
# <openclsim.model.MoveActivity object at 0x0000019A082577C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a948>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a948>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a948>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 40, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 40, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0827ab08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 35, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a0827ab08>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 35 of default
#   destination:  barge_2 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a948>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a948>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827a3c8>}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x0000019A08266B88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_full1)
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08257AC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.a701b4ec-ab2c-11ea-9b06-2079183a5c9a': 5, 'destination.to_site': 45}
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aac8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aac8>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a908>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aac8>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a908>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aac8>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a908>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aac8>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a908>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0827adc8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing_full)
# destination store before put: [{'id': 'default', 'level': 10, 'capacity': 55}]
# <FilterStoreGet() object at 0x19a0827ac08>
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08266E88>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5, 'destination.to_site': 40}
# put_callback - id_ default
# {'default': {55: <Event() object at 0x19a08266288>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 15, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_1
#   origin        barge_1  contains: 0 of default
#   destination:  to_site contains: 15 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826aac8>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a908>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a908>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading1)
# Activity end(WhileFull1)
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0827ae48>}
# shift amount process keep_resources []
# start get_available
# condition event triggered: False False round 1
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000019A7E967C48>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A7E9677C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0827ae48>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a082891c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0827ae48>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a082891c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0827ae48>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a082891c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0827ae48>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a082891c8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a08289248>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 15, 'capacity': 55}]
# <FilterStoreGet() object at 0x19a08289248>
# put_callback - id_ default
# {'default': {55: <Event() object at 0x19a08266288>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 20, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_2
#   origin        barge_2  contains: 0 of default
#   destination:  to_site contains: 20 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0827ae48>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a082891c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a082891c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(WhileFull)
# condition event triggered: False False round 1
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000019A08266488>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A08266588>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_empty1)
# <openclsim.model.ShiftAmountActivity object at 0x0000019A082574C8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 35, 'destination.a701b4ec-ab2c-11ea-9b06-2079183a5c9a': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826a108>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289608>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289608>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a08289588>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289608>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a08289588>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289608>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a08289588>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 35, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 35, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0827a588>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 30, 'capacity': 55}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing_empty)
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a0827a648>
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08266888>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 30, 'destination.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5}
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 30 of default
#   destination:  barge_1 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289608>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a08289588>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289608>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a08289588>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289608>}
# released processor : {}
# {}
# Activity end(loading1)
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a7e967088>}
# shift amount process keep_resources []
# start get_available
# <openclsim.model.MoveActivity object at 0x0000019A082577C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289888>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289888>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826a108>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289888>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826a108>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289888>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826a108>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 30, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 30, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a08289b48>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 25, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a08289b48>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 25 of default
#   destination:  barge_2 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289888>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826a108>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289888>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0826a108>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289888>}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x0000019A08266B88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_full1)
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08257AC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.a701b4ec-ab2c-11ea-9b06-2079183a5c9a': 5, 'destination.to_site': 35}
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826ac48>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08289e08>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08289e08>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08289e08>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08289e08>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0827a948>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing_full)
# destination store before put: [{'id': 'default', 'level': 20, 'capacity': 55}]
# <FilterStoreGet() object at 0x19a08289d08>
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08266E88>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5, 'destination.to_site': 30}
# put_callback - id_ default
# {'default': {55: <Event() object at 0x19a08266288>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 25, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_1
#   origin        barge_1  contains: 0 of default
#   destination:  to_site contains: 25 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826ac48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08289e08>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a08289e08>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading1)
# Activity end(WhileFull1)
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826a108>}
# shift amount process keep_resources []
# start get_available
# condition event triggered: False False round 2
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000019A7E967C48>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A7E9677C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08290088>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08290088>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08290088>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08290088>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a08290348>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 25, 'capacity': 55}]
# <FilterStoreGet() object at 0x19a08290348>
# put_callback - id_ default
# {'default': {55: <Event() object at 0x19a08266288>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 30, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_2
#   origin        barge_2  contains: 0 of default
#   destination:  to_site contains: 30 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a0826a108>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08290088>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08290088>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(WhileFull)
# condition event triggered: False False round 2
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000019A08266488>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A08266588>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_empty1)
# <openclsim.model.ShiftAmountActivity object at 0x0000019A082574C8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 25, 'destination.a701b4ec-ab2c-11ea-9b06-2079183a5c9a': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a082895c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a082895c8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a082895c8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082901c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a082895c8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082901c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a082895c8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082901c8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 25, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 25, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a08290608>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 20, 'capacity': 55}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing_empty)
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a08290448>
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08266888>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 20, 'destination.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5}
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 20 of default
#   destination:  barge_1 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a082895c8>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082901c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082901c8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>}
# released processor : {}
# {}
# Activity end(loading1)
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a788>}
# shift amount process keep_resources []
# start get_available
# <openclsim.model.MoveActivity object at 0x0000019A082577C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a788>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a788>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082906c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a788>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082906c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a788>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082906c8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 20, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 20, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a08290888>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 15, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a08290888>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 15 of default
#   destination:  barge_2 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a788>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082906c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a082904c8>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082906c8>}
# ...
# released processor : {}
# {}
# Activity end(loading1)
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a048>}
# shift amount process keep_resources []
# start get_available
# <openclsim.model.MoveActivity object at 0x0000019A082577C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a048>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827ab08>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a048>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827ab08>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a308>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a048>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827ab08>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a308>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a048>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827ab08>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a308>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 10, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 10, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0827ad48>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 5, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a0827ad48>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 5 of default
#   destination:  barge_2 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a0827a048>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827ab08>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a308>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827ab08>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a0827a308>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a0827ab08>}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x0000019A08266B88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_full1)
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08257AC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.a701b4ec-ab2c-11ea-9b06-2079183a5c9a': 5, 'destination.to_site': 15}
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967d48>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967d48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827aec8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967d48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827aec8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967d48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827aec8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967d48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827aec8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a0827a788>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing_full)
# destination store before put: [{'id': 'default', 'level': 40, 'capacity': 55}]
# <FilterStoreGet() object at 0x19a0827a788>
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08266E88>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5, 'destination.to_site': 10}
# put_callback - id_ default
# {'default': {55: <Event() object at 0x19a08266288>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 45, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_1
#   origin        barge_1  contains: 0 of default
#   destination:  to_site contains: 45 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967d48>, <simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827aec8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827aec8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading1)
# Activity end(WhileFull1)
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967088>}
# shift amount process keep_resources []
# start get_available
# condition event triggered: False False round 4
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000019A7E967C48>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A7E9677C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08289ec8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08289ec8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08289ec8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08289ec8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a08289f08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 45, 'capacity': 55}]
# <FilterStoreGet() object at 0x19a08289f08>
# put_callback - id_ default
# {'default': {55: <Event() object at 0x19a08266288>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 50, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_2
#   origin        barge_2  contains: 0 of default
#   destination:  to_site contains: 50 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A03CE6648>: <Request() object at 0x19a7e967088>, <simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08289ec8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E967C88>: <Request() object at 0x19a08289ec8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(WhileFull)
# condition event triggered: False False round 4
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000019A08266488>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000019A08266588>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_empty1)
# <openclsim.model.ShiftAmountActivity object at 0x0000019A082574C8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 5, 'destination.a701b4ec-ab2c-11ea-9b06-2079183a5c9a': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a388>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a388>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289508>}
# site request : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a388>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289508>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082895c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a388>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289508>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082895c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a388>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289508>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082895c8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x19a08289248>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 55}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing_empty)
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x19a082898c8>
# <openclsim.model.ShiftAmountActivity object at 0x0000019A08266888>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 0, 'destination.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5}
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 0 of default
#   destination:  barge_1 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000019A7E967F88>: <Request() object at 0x19a0827a388>, <simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289508>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082895c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289508>, <simpy.resources.resource.Resource object at 0x0000019A00E3ACC8>: <Request() object at 0x19a082895c8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000019A7E952888>: <Request() object at 0x19a08289508>}
# released processor : {}
# {}
# Activity end(loading1)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\users\d4l\github\openclsim\openclsim\model.py in conditional_process(activity_log, env, condition_event, sub_process, name, requested_resources, keep_resources)
#     554         sub_process.start()
# --> 555         yield from sub_process.call_main_proc(activity_log=activity_log, env=env)
#     556         sub_process.end()
#
# c:\users\d4l\github\openclsim\openclsim\model.py in sequential_process(activity_log, env, sub_processes, name, requested_resources, keep_resources)
#     825         sub_process.start()
# --> 826         yield from sub_process.call_main_proc(activity_log=sub_process, env=env)
#     827         sub_process.end()
#
# c:\users\d4l\github\openclsim\openclsim\model.py in shift_amount_process(activity_log, env, processor, origin, destination, name, duration, amount, requested_resources, keep_resources, id_, engine_order, stop_reservation_waiting_event)
#     784         raise RuntimeError(
# --> 785             f"Attempting to shift content from an empty origin or to a full destination. ({all_amounts})"
#     786         )
#
# RuntimeError: Attempting to shift content from an empty origin or to a full destination. ({'origin.from_site': 0, 'destination.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5})
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-519ef8340310> in <module>
# ----> 1 sim.simulate()
#
# c:\users\d4l\github\vo-colos\vo_colos\utils\base_task.py in simulate(self)
#     249         self.activity_factory()
#     250
# --> 251         self.env.run()
#     252
#     253         self.logs = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\simpy\core.py in run(self, until)
#     136         try:
#     137             while True:
# --> 138                 self.step()
#     139         except StopSimulation as exc:
#     140             return exc.args[0]  # == until.value
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\simpy\core.py in step(self)
#     228             exc = type(event._value)(*event._value.args)
#     229             exc.__cause__ = event._value
# --> 230             raise exc
#
# RuntimeError: Attempting to shift content from an empty origin or to a full destination. ({'origin.from_site': 0, 'destination.a701b4ed-ab2c-11ea-ba15-2079183a5c9a': 5})

# %%
objects = list(sim.vessels)
activities = []
for obj in objects:
    print(set(obj.log["Message"]))
    activities.extend(set(obj.log["Message"]))

activities = list(set(activities))
C = np.linspace(0,255, len(activities))
colors = {}

for i in range(len(activities)):
    colors[i] = f'rgb({int(C[i]/2)},{int(C[len(C) - 1 - i]/1.5)},{int(C[i])})'

vessel_planning(objects, activities, colors)
# Out:
# {'transfer default to barge_2', 'transfer default to barge_1'}
# {'sailing empty', 'sailing filled', 'transfer default to to_site', 'transfer default to barge_1'}
# {'sailing empty', 'transfer default to barge_2', 'sailing filled', 'transfer default to to_site'}
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="25045b93-8e28-41d9-a7bd-747a47af06db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("25045b93-8e28-41d9-a7bd-747a47af06db")) {
#                     Plotly.newPlot(
#                         '25045b93-8e28-41d9-a7bd-747a47af06db',
#                         [{"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(0,170,0)", "width": 10}, "mode": "lines", "name": "sailing filled", "type": "scatter", "x": ["2020-06-10T18:11:25", "2020-06-10T18:11:25", "2020-06-10T20:40:46.902451", "2020-06-10T20:40:46.902451", "2020-06-10T20:40:46.902451", "2020-06-11T00:40:16.424411", "2020-06-11T00:40:16.424411", "2020-06-11T03:09:38.326862", "2020-06-11T03:09:38.326862", "2020-06-11T03:09:38.326862", "2020-06-11T07:09:07.848823", "2020-06-11T07:09:07.848823", "2020-06-11T09:38:29.751273", "2020-06-11T09:38:29.751273", "2020-06-11T09:38:29.751273", "2020-06-11T13:37:59.273234", "2020-06-11T13:37:59.273234", "2020-06-11T16:07:21.175685", "2020-06-11T16:07:21.175685", "2020-06-11T16:07:21.175685", "2020-06-11T20:06:50.697645", "2020-06-11T20:06:50.697645", "2020-06-11T22:36:12.600096", "2020-06-11T22:36:12.600096", "2020-06-11T22:36:12.600096", "2020-06-10T19:11:25", "2020-06-10T19:11:25", "2020-06-10T21:40:46.902451", "2020-06-10T21:40:46.902451", "2020-06-10T21:40:46.902451", "2020-06-11T01:40:16.424411", "2020-06-11T01:40:16.424411", "2020-06-11T04:09:38.326862", "2020-06-11T04:09:38.326862", "2020-06-11T04:09:38.326862", "2020-06-11T08:09:07.848823", "2020-06-11T08:09:07.848823", "2020-06-11T10:38:29.751273", "2020-06-11T10:38:29.751273", "2020-06-11T10:38:29.751273", "2020-06-11T14:37:59.273234", "2020-06-11T14:37:59.273234", "2020-06-11T17:07:21.175685", "2020-06-11T17:07:21.175685", "2020-06-11T17:07:21.175685", "2020-06-11T21:06:50.697645", "2020-06-11T21:06:50.697645", "2020-06-11T23:36:12.600096", "2020-06-11T23:36:12.600096", "2020-06-11T23:36:12.600096"], "y": ["barge_1", "barge_1", "barge_1", "barge_1", null, "barge_1", "barge_1", "barge_1", "barge_1", null, "barge_1", "barge_1", "barge_1", "barge_1", null, "barge_1", "barge_1", "barge_1", "barge_1", null, "barge_1", "barge_1", "barge_1", "barge_1", null, "barge_2", "barge_2", "barge_2", "barge_2", null, "barge_2", "barge_2", "barge_2", "barge_2", null, "barge_2", "barge_2", "barge_2", "barge_2", null, "barge_2", "barge_2", "barge_2", "barge_2", null, "barge_2", "barge_2", "barge_2", "barge_2", null]}, {"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(31,127,63)", "width": 10}, "mode": "lines", "name": "transfer default to to_site", "type": "scatter", "x": ["2020-06-10T20:40:46.902451", "2020-06-10T20:40:46.902451", "2020-06-10T21:40:46.902451", "2020-06-10T21:40:46.902451", "2020-06-10T21:40:46.902451", "2020-06-10T20:40:46.902451", "2020-06-10T20:40:46.902451", "2020-06-10T21:40:46.902451", "2020-06-10T21:40:46.902451", "2020-06-10T21:40:46.902451", "2020-06-11T03:09:38.326862", "2020-06-11T03:09:38.326862", "2020-06-11T04:09:38.326862", "2020-06-11T04:09:38.326862", "2020-06-11T04:09:38.326862", "2020-06-11T03:09:38.326862", "2020-06-11T03:09:38.326862", "2020-06-11T04:09:38.326862", "2020-06-11T04:09:38.326862", "2020-06-11T04:09:38.326862", "2020-06-11T09:38:29.751273", "2020-06-11T09:38:29.751273", "2020-06-11T10:38:29.751273", "2020-06-11T10:38:29.751273", "2020-06-11T10:38:29.751273", "2020-06-11T09:38:29.751273", "2020-06-11T09:38:29.751273", "2020-06-11T10:38:29.751273", "2020-06-11T10:38:29.751273", "2020-06-11T10:38:29.751273", "2020-06-11T16:07:21.175685", "2020-06-11T16:07:21.175685", "2020-06-11T17:07:21.175685", "2020-06-11T17:07:21.175685", "2020-06-11T17:07:21.175685", "2020-06-11T16:07:21.175685", "2020-06-11T16:07:21.175685", "2020-06-11T17:07:21.175685", "2020-06-11T17:07:21.175685", "2020-06-11T17:07:21.175685", "2020-06-11T22:36:12.600096", "2020-06-11T22:36:12.600096", "2020-06-11T23:36:12.600096", "2020-06-11T23:36:12.600096", "2020-06-11T23:36:12.600096", "2020-06-11T22:36:12.600096", "2020-06-11T22:36:12.600096", "2020-06-11T23:36:12.600096", "2020-06-11T23:36:12.600096", "2020-06-11T23:36:12.600096", "2020-06-10T21:40:46.902451", "2020-06-10T21:40:46.902451", "2020-06-10T22:40:46.902451", "2020-06-10T22:40:46.902451", "2020-06-10T22:40:46.902451", "2020 ...
