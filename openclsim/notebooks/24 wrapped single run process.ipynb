# %%
import datetime, time
import simpy

import shapely.geometry
from simplekml import Kml, Style

import pandas as pd
import openclsim.core as core
import openclsim.model as model
import openclsim.plot as plot

from plot import vessel_planning

# setup environment
simulation_start = 0
my_env = simpy.Environment(initial_time=simulation_start)
registry = {}
keep_resources = {}

# %%
Site = type(
    "Site",
    (
        core.Identifiable,
        core.Log,
        core.Locatable,
        core.HasContainer,
        core.HasResource,
    ),
    {},
)

TransportProcessingResource = type(
    "TransportProcessingResource",
    (
        core.Identifiable,
        core.Log,
        core.ContainerDependentMovable,
        core.Processor,
        core.LoadingFunction,
        core.UnloadingFunction,
        core.HasResource,
    ),
    {},
)

# %%
location_from_site = shapely.geometry.Point(4.18055556, 52.18664444)  # lon, lat
location_to_site = shapely.geometry.Point(4.25222222, 52.11428333)  # lon, lat

data_from_site = {
    "env": my_env,
    "name": "Winlocatie",
    "geometry": location_from_site,
    "capacity": 5_000_000,
    "level": 5_000_000,
}


data_to_site = {
    "env": my_env,
    "name": "Dumplocatie",
    "geometry": location_to_site,
    "capacity": 5_000_000,
    "level": 0,
}

from_site = Site(**data_from_site)
to_site = Site(**data_to_site)
# Out:
# init
# level: 5000000
# completed init
# init
# level: 0
# completed init

# %%
data_hopper = {
    "env": my_env,
    "name": "Hopper 01",
    "geometry": location_from_site,
    "capacity":1000,
    "compute_v":lambda x: 10 + 2 * x,
    "loading_rate":1,
    "unloading_rate":5,
}

hopper = TransportProcessingResource(**data_hopper)
# Out:
# init
# level: 0
# completed init

# %%
single_run, activity, while_activity  = model.single_run_process(
    env=my_env,
    origin=from_site,
    destination=to_site,
    mover=hopper,
    loader=hopper,
    unloader=hopper
)
# Out:
# while Activity keep_resources []
# start put_available
# register new event
# get_full_event : default
# start get_available
# evaluate event <Event() object at 0x2629b738808> as triggered False and processed False
# evaluate event <Event() object at 0x2629b88ed88> as triggered False and processed False
# start event instance None

# %%
my_env.run()
# Out:
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# put_callback - id_ default
# {}
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# put_callback - id_ default
# {}
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 5000000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88ebc8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88ebc8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88ebc8>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 5000000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 5000000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892548>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4999000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b892548>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4999000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88ebc8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88ebc8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 5000000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88ebc8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88ebc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892788>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88ebc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892788>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88ebc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892788>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88ebc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892788>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b8928c8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b8928c8>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88ebc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892788>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892788>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 4999000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892588>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892588>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892588>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892ac8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892588>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892ac8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892588>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892ac8>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 4999000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 4999000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892908>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4998000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b892908>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4998000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892588>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892ac8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892ac8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 4999000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892c88>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892c88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892c88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892c88>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b886848>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 1000, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b886e48>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 2000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 2000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892c88>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892c88>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 1
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 4998000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892a48>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892a48>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892a48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892b88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892a48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892b88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892a48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892b88>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 4998000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 4998000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892d88>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4997000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b892d88>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4997000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892a48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892b88>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892b88>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 4998000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7188>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7188>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7188>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7188>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b8a7488>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 2000, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b8a7488>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 3000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 3000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7188>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7188>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 2
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 4997000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892e48>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892e48>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892e48>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 4997000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 4997000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892ec8>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4996000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b892ec8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4996000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892e48>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b892e48>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 4997000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629ae49048>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892ec8>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892ec8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892ec8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892ec8>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892e48>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 3000, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b886e48>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 4000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 4000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892ec8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892ec8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 3
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 4996000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b886848>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b886848>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b886848>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 4996000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 4996000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892cc8>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4995000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b8927c8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4995000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b886848>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b886848>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 4996000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892dc8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892dc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892dc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892dc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892dc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892b08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 4000, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b892b08>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 5000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 5000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892dc8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8928c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 4
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 4995000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a73c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a73c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a73c8>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 4995000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 4995000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b8863c8>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4994000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b8928c8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4994000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b886e48>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a73c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a73c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 4995000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892a08>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892a08>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7108>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892a08>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7108>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892a08>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7108>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892a08>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7108>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b8a7548>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 5000, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b8a7548>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 6000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 6000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892a08>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7108>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7108>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 5
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 4994000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e7c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e7c8>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a76c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a76c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a76c8>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 4994000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 4994000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b8a7648>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4993000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b8a7648>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4993000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a76c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a76c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 4994000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892908>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892908>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892908>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892908>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892d48>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 6000, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b892d48>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 7000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 7000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b8863c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892908>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892908>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 6
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 4993000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88e188>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88e188>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88e188>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 4993000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 4993000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b8927c8>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4992000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b892648>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4992000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629ae49048>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88e188>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b88e188>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 4993000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8926c8>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8926c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8926c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8926c8>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892588>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 7000, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b892588>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 8000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 8000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b88e7c8>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8926c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8926c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 7
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 4992000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e188>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e188>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e188>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7348>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e188>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7348>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e188>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7348>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 4992000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 4992000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b892d88>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4991000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b8926c8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4991000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b88e188>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7348>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7348>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 4992000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892888>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892888>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7508>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892888>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7508>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892888>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7508>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892888>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7508>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b8a7248>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 8000, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b8a7248>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 9000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 9000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892888>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7508>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7508>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 8
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002629B88E548>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002629B886688>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B886748>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fb67f28-ac81-11ea-ae00-2079183a5c9a': 4991000, 'destination.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892b88>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892b88>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892b88>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7788>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892b88>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7788>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892b88>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7788>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Hopper 01
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 4991000, 'capacity': 5000000}]
# start get 1000
# store_status {'id': 'default', 'level': 4991000, 'capacity': 5000000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b8a73c8>
# start get_callback
# {'default': {5000000: <Event() object at 0x2629b738808>}}
# origin store after get: [{'id': 'default', 'level': 4990000, 'capacity': 5000000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# <FilterStoreGet() object at 0x2629b8a73c8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 4990000 of default
#   destination:  Hopper 01 contains: 1000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b892b88>, <simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7788>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886B48>: <Request() object at 0x2629b8a7788>}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002629B886EC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing filled)
# <openclsim.model.ShiftAmountActivity object at 0x000002629B88E208>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.7fbc4b98-ac81-11ea-93ec-2079183a5c9a': 1000, 'destination.7fb67f29-ac81-11ea-9973-2079183a5c9a': 4991000}
# destination request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892848>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892848>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7848>}
# site request : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892848>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7848>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892848>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7848>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892848>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7848>}
# _shift_amount
# start _shift_amount
# amount 1000
# processor start process
# transfer default to Dumplocatie
# processor process with rate
# origin store before get: [{'id': 'default', 'level': 1000, 'capacity': 1000}]
# start get 1000
# store_status {'id': 'default', 'level': 1000, 'capacity': 1000}
# end get 1000
# get_callback - id_ <StorePut() object at 0x2629b8a7908>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1000}]
# processing expected duration {duration}
# destination store before put: [{'id': 'default', 'level': 9000, 'capacity': 5000000}]
# <FilterStoreGet() object at 0x2629b8a7908>
# put_callback - id_ default
# {'default': {5000000: <Event() object at 0x2629b88ed88>}}
# amount :5000000
# destination store after put: [{'id': 'default', 'level': 10000, 'capacity': 5000000}]
# processor end process
# Processed 1000 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 10000 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000002629B873BC8>: <Request() object at 0x2629b892848>, <simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7848>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000002629B886488>: <Request() object at 0x2629b8a7848>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(Single run process)
# condition event triggered: False False round 9
# while loop requested_resources {}
# while loop keep_resources []

# %%
objects = [from_site, to_site, hopper]

activities = []
for obj in objects:
    activities.extend(set(obj.log["Message"]))

activities = list(set(activities))

vessel_planning(objects, activities)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="4fbdfe3a-8d66-4954-bad1-1df2608a1f66" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4fbdfe3a-8d66-4954-bad1-1df2608a1f66")) {
#                     Plotly.newPlot(
#                         '4fbdfe3a-8d66-4954-bad1-1df2608a1f66',
#                         [{"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(39,11,212)", "width": 10}, "mode": "lines", "name": "sailing empty", "type": "scatter", "x": ["1970-01-01T01:00:00", "1970-01-01T01:00:00", "1970-01-01T01:00:00", "1970-01-01T01:00:00", "1970-01-01T01:00:00", "1970-01-01T01