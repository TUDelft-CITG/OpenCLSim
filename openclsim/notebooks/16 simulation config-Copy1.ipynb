# %%
import json

import datetime, time
import simpy

import shapely.geometry
from simplekml import Kml, Style

import pandas as pd
import openclsim.core as core
import openclsim.model as model

import datetime

import numpy as np

from plot import vessel_planning
from vo_colos.utils import SimulationFactory

from vo_colos.utils.object_registry import SiteRegistry, VesselRegistry
from vo_colos.utils.object_registry import ClassInspect

# %%
with open("config.json", 'r') as fp:
    config = json.load(fp)

# %%
class message:
    id = 1
    task = {
        "id": 1,
        "engine": "colos",
        "project_id": "1234567890",
        "tag": "testsimulation",
        "config": config["config"],
    }
    status = "new"

sim = SimulationFactory(message)

# %%
sim.simulate()
# Out:
# init
# level: 55
# completed init
# init
# level: 0
# completed init
# init
# level: 0
# completed init
# init
# level: 0
# completed init
# while Activity keep_resources []
# get_full_event : default
# start get_available
# start event instance None
# while Activity keep_resources []
# get_full_event : default
# start get_available
# start event instance None
# <openclsim.model.SequentialActivity object at 0x0000025148D6E808>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002513F5F32C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# <openclsim.model.SequentialActivity object at 0x000002513F5F37C8>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000025148D67348>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# put_callback - id_ default
# {}
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# put_callback - id_ default
# {}
# put_callback - id_ default
# {}
# Mover_move after mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_empty1)
# Mover_move after move
# Activity end(sailing_empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002513F5F3608>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 55, 'destination.9d9947f4-ab17-11ea-80a1-2079183a5c9a': 5}
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D67B48>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>}
# {'origin.from_site': 55, 'destination.9d9947f5-ab17-11ea-b173-2079183a5c9a': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>}
# shift amount process keep_resources []
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>}
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x2514832efc8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x2514832efc8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x2514832efc8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x2514832efc8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 55, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 55, 'capacity': 55}
# end get 5
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x2514832efc8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x2514832efc8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x2514832efc8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 50, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 50, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x25148d81188>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 45, 'capacity': 55}]
# after get
# after check_down time
# get_callback - id_ <StorePut() object at 0x25148d81288>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 45, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x25148d81288>
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x25148d811c8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 45 of default
#   destination:  barge_1 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6a5c8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x2514832efc8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x2514832efc8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81088>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>}
# {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>}
# Activity end(loading1)
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 45 of default
#   destination:  barge_2 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25141adf2c8>}
# keep resources []
# release destination : {}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002513F5F3108>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# <openclsim.model.MoveActivity object at 0x0000025148D67CC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_full1)
# Mover_move after move
# Activity end(sailing_full)
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D67248>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.9d9947f4-ab17-11ea-80a1-2079183a5c9a': 5, 'destination.to_site': 55}
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D6E548>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>}
# {'origin.9d9947f5-ab17-11ea-b173-2079183a5c9a': 5, 'destination.to_site': 55}
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>}
# shift amount process keep_resources []
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x25148d6eb88>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# get_callback - id_ <StorePut() object at 0x25148d6ed88>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 55}]
# <FilterStoreGet() object at 0x25148d6ee08>
# destination store before put: [{'id': 'default', 'level': 5, 'capacity': 55}]
# <FilterStoreGet() object at 0x25148d6ed88>
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 10, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_2
#   origin        barge_2  contains: 0 of default
#   destination:  to_site contains: 10 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2513f5f3848>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ef88>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# Activity end(unloading)
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 10, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_1
#   origin        barge_1  contains: 0 of default
#   destination:  to_site contains: 10 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ed48>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading1)
# Activity end(WhileFull)
# Activity end(WhileFull1)
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002513F5F37C8>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000025148D67348>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000025148D6E808>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002513F5F32C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_empty)
# Mover_move after move
# Activity end(sailing_empty1)
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D67B48>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 45, 'destination.9d9947f5-ab17-11ea-b173-2079183a5c9a': 5}
# <openclsim.model.ShiftAmountActivity object at 0x000002513F5F3608>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>}
# {'origin.from_site': 45, 'destination.9d9947f4-ab17-11ea-80a1-2079183a5c9a': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>}
# shift amount process keep_resources []
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>}
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d81548>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d81548>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d81548>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d81548>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 45, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 45, 'capacity': 55}
# end get 5
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d81548>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d81548>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d81548>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 40, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 40, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x25148d81688>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 35, 'capacity': 55}]
# after get
# after check_down time
# get_callback - id_ <StorePut() object at 0x25148d81a48>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 35, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x25148d81a48>
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x25148d81b88>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 35 of default
#   destination:  barge_2 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x2513f5f3308>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d81548>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d81548>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d81488>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>}
# {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>}
# Activity end(loading)
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 35 of default
#   destination:  barge_1 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6ee88>}
# keep resources []
# release destination : {}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading1)
# <openclsim.model.MoveActivity object at 0x0000025148D67CC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# <openclsim.model.MoveActivity object at 0x000002513F5F3108>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_full)
# Mover_move after move
# Activity end(sailing_full1)
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D6E548>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.9d9947f5-ab17-11ea-b173-2079183a5c9a': 5, 'destination.to_site': 45}
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D67248>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>}
# {'origin.9d9947f4-ab17-11ea-80a1-2079183a5c9a': 5, 'destination.to_site': 45}
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>}
# shift amount process keep_resources []
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x25148d81f48>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# get_callback - id_ <StorePut() object at 0x25148d96088>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 10, 'capacity': 55}]
# <FilterStoreGet() object at 0x25148d96088>
# destination store before put: [{'id': 'default', 'level': 15, 'capacity': 55}]
# <FilterStoreGet() object at 0x25148d96148>
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 20, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_1
#   origin        barge_1  contains: 0 of default
#   destination:  to_site contains: 20 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6efc8>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81bc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# Activity end(unloading1)
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 20, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_2
#   origin        barge_2  contains: 0 of default
#   destination:  to_site contains: 20 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d81d08>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading)
# Activity end(WhileFull1)
# Activity end(WhileFull)
# condition event triggered: False False round 1
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000025148D6E808>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002513F5F32C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# condition event triggered: False False round 1
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002513F5F37C8>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000025148D67348>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_empty1)
# Mover_move after move
# Activity end(sailing_empty)
# <openclsim.model.ShiftAmountActivity object at 0x000002513F5F3608>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 35, 'destination.9d9947f4-ab17-11ea-80a1-2079183a5c9a': 5}
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D67B48>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>}
# {'origin.from_site': 35, 'destination.9d9947f5-ab17-11ea-b173-2079183a5c9a': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>}
# shift amount process keep_resources []
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>}
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d967c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d967c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d967c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d967c8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 35, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 35, 'capacity': 55}
# end get 5
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d967c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d967c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d967c8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 30, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 30, 'capacity': 55}
# end get 5
# get_callback - id_ <StorePut() object at 0x25148d81088>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 25, 'capacity': 55}]
# after get
# after check_down time
# get_callback - id_ <StorePut() object at 0x25148d96b08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 25, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x25148d81ac8>
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x25148d81588>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 25 of default
#   destination:  barge_1 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d6eb48>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d967c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d967c8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d96788>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>}
# {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>}
# Activity end(loading1)
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 25 of default
#   destination:  barge_2 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6ee08>}
# keep resources []
# release destination : {}
# released origin : {}
# released processor : {}
# {}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x000002513F5F3108>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# <openclsim.model.MoveActivity object at 0x0000025148D67CC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_full1)
# Mover_move after move
# Activity end(sailing_full)
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D67248>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.9d9947f4-ab17-11ea-80a1-2079183a5c9a': 5, 'destination.to_site': 35}
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D6E548>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>}
# {'origin.9d9947f5-ab17-11ea-b173-2079183a5c9a': 5, 'destination.to_site': 35}
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>}
# shift amount process keep_resources []
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x25148d81f08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# get_callback - id_ <StorePut() object at 0x25148d94288>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 20, 'capacity': 55}]
# <FilterStoreGet() object at 0x25148d94288>
# destination store before put: [{'id': 'default', 'level': 25, 'capacity': 55}]
# <FilterStoreGet() object at 0x25148d94248>
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 30, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_2
#   origin        barge_2  contains: 0 of default
#   destination:  to_site contains: 30 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x2514832efc8>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96c48>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# Activity end(unloading)
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 30, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_1
#   origin        barge_1  contains: 0 of default
#   destination:  to_site contains: 30 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96c88>}
# keep resources []
# ...
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96708>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96708>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96708>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96708>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96708>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96708>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x25148d96f08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# get_callback - id_ <StorePut() object at 0x25148d96448>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 40, 'capacity': 55}]
# <FilterStoreGet() object at 0x25148d96448>
# destination store before put: [{'id': 'default', 'level': 45, 'capacity': 55}]
# <FilterStoreGet() object at 0x25148d96348>
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 50, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_2
#   origin        barge_2  contains: 0 of default
#   destination:  to_site contains: 50 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d6ee08>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96708>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d96708>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# Activity end(unloading)
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 50, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_1
#   origin        barge_1  contains: 0 of default
#   destination:  to_site contains: 50 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d96bc8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(unloading1)
# Activity end(WhileFull)
# Activity end(WhileFull1)
# condition event triggered: False False round 4
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000002513F5F37C8>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x0000025148D67348>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# condition event triggered: False False round 4
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000025148D6E808>
# conditional
# start event instance None
# <openclsim.model.MoveActivity object at 0x000002513F5F32C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_empty)
# Mover_move after move
# Activity end(sailing_empty1)
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D67B48>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.from_site': 5, 'destination.9d9947f5-ab17-11ea-b173-2079183a5c9a': 5}
# <openclsim.model.ShiftAmountActivity object at 0x000002513F5F3608>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>}
# {'origin.from_site': 5, 'destination.9d9947f4-ab17-11ea-80a1-2079183a5c9a': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# shift amount process keep_resources []
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d810c8>}
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d810c8>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d67688>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d810c8>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d67688>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d810c8>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d67688>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d810c8>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d67688>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to barge_2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 55}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 55}
# end get 5
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D60FC8>: <Request() object at 0x25148d810c8>, <simpy.resources.resource.Resource object at 0x0000025148D6A308>: <Request() object at 0x25148d67688>}
# start get_available
# get_callback - id_ <StorePut() object at 0x25148d811c8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 55}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 5}]
# <FilterStoreGet() object at 0x25148d59d88>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 5}]
# after put
# processor end process
# Processed 5 of default:
#   by:          cutter
#   origin        from_site  contains: 0 of default
#   destination:  barge_2 contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d6c048>, <simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# Activity end(loading)
# <openclsim.model.MoveActivity object at 0x0000025148D67CC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing_full)
# <openclsim.model.ShiftAmountActivity object at 0x0000025148D6E548>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# {'origin.9d9947f5-ab17-11ea-b173-2079183a5c9a': 5, 'destination.to_site': 5}
# destination request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d81a88>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d81a88>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d819c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d81a88>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d819c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d81a88>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d819c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d81a88>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d819c8>}
# _shift_amount
# start _shift_amount
# amount 5
# processor start process
# transfer default to to_site
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 5, 'capacity': 5}]
# start get 5
# store_status {'id': 'default', 'level': 5, 'capacity': 5}
# end get 5
# get_callback - id_ <StorePut() object at 0x25148d811c8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 5}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 50, 'capacity': 55}]
# <FilterStoreGet() object at 0x25148d817c8>
# put_callback - id_ default
# {'default': {55: <Event() object at 0x2513f5f3708>}}
# amount :55
# destination store after put: [{'id': 'default', 'level': 55, 'capacity': 55}]
# after put
# processor end process
# Processed 5 of default:
#   by:          barge_2
#   origin        barge_2  contains: 0 of default
#   destination:  to_site contains: 55 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D68F88>: <Request() object at 0x25148d81a88>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d819c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>, <simpy.resources.resource.Resource object at 0x0000025148D6DE88>: <Request() object at 0x25148d819c8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# Activity end(unloading)
# Activity end(WhileFull)
# condition event triggered: True True round 5
# while loop requested_resources {<simpy.resources.resource.Resource object at 0x0000025148D64488>: <Request() object at 0x25148d81348>}
# while loop keep_resources []

# %%
objects = list(sim.vessels)
activities = []
for obj in objects:
    print(set(obj.log["Message"]))
    activities.extend(set(obj.log["Message"]))

activities = list(set(activities))

            
C = np.linspace(0,255, len(activities))
colors = {}

for i in range(len(activities)):
    colors[i] = f'rgb({int(C[i]/2)},{int(C[len(C) - 1 - i]/1.5)},{int(C[i])})'

vessel_planning(objects, activities, colors)
# Out:
# {'transfer default to barge_1', 'transfer default to barge_2'}
# {'sailing empty', 'transfer default to barge_1', 'sailing filled', 'transfer default to to_site'}
# {'sailing empty', 'transfer default to barge_2', 'sailing filled', 'transfer default to to_site'}
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="afd3b316-4fcb-4d08-a51c-712fea083a90" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("