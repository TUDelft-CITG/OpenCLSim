# %% [markdown]
# # Demo SingleRun
# This notebook shows a single run consisting of the following four phases:
# * sail empty
# * loading
# * sail full
# * unloading

# %%
import datetime, time
import simpy

import shapely.geometry
from simplekml import Kml, Style

import pandas as pd
import openclsim.core as core
import openclsim.model as model
import openclsim.plot as plot
import openclsim.plugins as plugin

from plot import vessel_planning

import matplotlib.pyplot as plt
# %matplotlib inline

# setup environment
simulation_start  = datetime.datetime(2010,1,1)
my_env = simpy.Environment(initial_time=simulation_start.timestamp())
registry = {}
keep_resources = {}

import numpy as np

# %% [markdown]
# ## Definition of Site

# %%
# The generic site class
Site = type(
    "Site",
    (
        core.Identifiable,  # Give it a name
        core.Log,  # Allow logging of all discrete events
        core.Locatable,  # Add coordinates to extract distance information and visualize
        core.HasContainer,  # Add information on the material available at the site
        core.HasResource,
    ),  # Add information on serving equipment
    {},
)  # The dictionary is empty because the site type is generic

# Information on the extraction site - the "from site" - the "win locatie"
location_from_site = shapely.geometry.Point(4.18055556, 52.18664444)  # lon, lat

data_from_site = {
    "env": my_env,  # The simpy environment defined in the first cel
    "name": "Winlocatie",  # The name of the site
    "ID": "6dbbbdf4-4589-11e9-a501-b469212bff5d",  # For logging purposes
    "geometry": location_from_site,  # The coordinates of the project site
    "capacity": 40,  # The capacity of the site
    "level": 40,
}  # The actual volume of the site

# Information on the dumping site - the "to site" - the "dump locatie"
location_to_site = shapely.geometry.Point(4.25222222, 52.11428333)  # lon, lat

data_to_site = {
    "env": my_env,  # The simpy environment defined in the first cel
    "name": "Dumplocatie",  # The name of the site
    "ID": "6dbbbdf5-4589-11e9-82b2-b469212bff5c",  # For logging purposes
    "geometry": location_to_site,  # The coordinates of the project site
    "capacity": 40,  # The capacity of the site
    "level": 0,
}  # The actual volume of the site (empty of course)

# The two objects used for the simulation
from_site = Site(**data_from_site)
to_site = Site(**data_to_site)
# Out:
# init
# level: 40
# completed init
# init
# level: 0
# completed init

# %% [markdown]
# ## Definition of Vessels

# %%
# The generic class for an object that can move and transport (a TSHD for example)
TransportProcessingResource = type(
    "TransportProcessingResource",
    (
        core.Identifiable,  # Give it a name
        core.Log,  # Allow logging of all discrete events
        core.ContainerDependentMovable,  # A moving container, so capacity and location
        core.Processor,  # Allow for loading and unloading
        core.HasResource,  # Add information on serving equipment
        core.HasCosts,  # Add information on costs
        core.LoadingFunction,  # Add a loading function
        core.UnloadingFunction,  # Add an unloading function
    ),
    {},
)

# For more realistic simulation you might want to have speed dependent on the volume carried by the vessel
def compute_v_provider(v_empty, v_full):
    return lambda x: 10

# TSHD variables
data_hopper = {
    "env": my_env,  # The simpy environment
    "name": "Hopper 01",  # Name
    "ID": "6dbbbdf6-4589-11e9-95a2-b469212bff5b",  # For logging purposes
    "geometry": location_from_site,  # It starts at the "from site"
    "loading_rate": 1,  # Loading rate
    "unloading_rate": 1,  # Unloading rate
    "capacity": 4,  # Capacity of the hopper - "Beunvolume"
    "compute_v": compute_v_provider(5, 4.5),  # Variable speed
    "weekrate": 7,
}

hopper = TransportProcessingResource(**data_hopper)
# Out:
# init
# level: 0
# completed init

# %% [markdown]
# ## Definition of process

# %%
TestMoveActivity =  type(
    "TestMoveActivity",
    (
        plugin.HasTestPluginMoveActivity,
        plugin.HasWeatherPluginMoveActivity,
        model.MoveActivity,  # the order is critical!
    ),
    {},
)


TestShift =  type(
    "TestMoveActivity",
    (
        plugin.HasTestPluginMoveActivity,
        plugin.HasWeatherPluginMoveActivity,
        model.ShiftAmountActivity,  # the order is critical!
    ),
    {},
)

# %%
metocean_df = pd.read_csv("../demo/unit_test_weather.csv")
metocean_df = metocean_df.set_index(pd.to_datetime(metocean_df["Time"], dayfirst=True))
metocean_df = metocean_df.sort_index()

metocean_df["Hs [m]"] = 4 + \
                        1.5*np.sin(metocean_df['  Hour']/24 * 8 *np.pi) + \
                        1.5*np.sin(metocean_df['  Hour']/24 * 6 *np.pi)

metocean_df["DateTime"] = [datetime.datetime.strptime(dt, '%d-%m-%Y %H:%M') for dt in metocean_df["Time"]]

# %%
criteria_data_sail = {
    "event_name":"this",
    "condition":"Hs [m]",
    "maximum":3,
    "window_length":datetime.timedelta(hours=1)
}

sailing_crit = core.WorkabilityCriterion(**criteria_data_sail)

criteria_data_load = {
    "event_name":"this",
    "condition":"Hs [m]",
    "maximum":2,
    "window_length":datetime.timedelta(hours=1)
}

load_crit = core.WorkabilityCriterion(**criteria_data_load)

# %%
single_run = []

single_run.append(
    TestMoveActivity(**{
        "env": my_env,
        "name": "Soil movement",
        "registry": registry,
        "mover": hopper,
        "destination": from_site,
        "metocean_criteria":[sailing_crit],
        "metocean_df": metocean_df,
        "postpone_start": True,
    })
)

single_run.append(
    TestShift(**{
        "env": my_env,  # The simpy environment defined in the first cel
        "name": "Transfer MP",  # We are moving soil
        "ID": "6dbbbdf7-4589-11e9-bf3b-b469212bff52",  # For logging purposes
        "registry": registry,
        "processor": hopper,
        "origin": from_site,
        "destination": hopper,
        "amount": 4,
        "duration": 3600,
        "postpone_start": True,
        "metocean_criteria":[load_crit],
        "metocean_df": metocean_df,
    })
)

single_run.append(
    TestMoveActivity(**{
        "env": my_env,
        "name": "Soil movement",
        "registry": registry,
        "mover": hopper,
        "destination": to_site,
        "metocean_criteria":[sailing_crit],
        "metocean_df": metocean_df,
        "postpone_start": True,
    })
)

single_run.append(
    TestShift(**{
        "env": my_env,  # The simpy environment defined in the first cel
        "name": "Transfer TP",  # We are moving soil
        "ID": "6dbbbdf7-4589-11e9-bf3b-b469212bff54",  # For logging purposes
        "registry": registry,
        "processor": hopper,
        "origin": hopper,
        "destination": to_site,
        "amount": 4,
        "duration": 3600,
        "postpone_start": True,
        "metocean_criteria":[load_crit],
        "metocean_df": metocean_df,
    })
)

sequential_activity_data = {
    "env": my_env,
    "name": "Single run process",
    "ID": "6dbbbdf7-4589-11e9-bf3b-b469212bff60",  # For logging purposes
    "registry": registry,
    "sub_processes": single_run,
    "postpone_start": True,
}
activity = model.SequentialActivity(**sequential_activity_data)

expr = [{"type":"container", "concept": to_site, "state":"full"}]
while_data = {
    "env": my_env,  # The simpy environment defined in the first cel
    "name": "while",  # We are moving soil
    "ID": "6dbbbdf7-4589-11e9-bf3b-b469212bff5g",  # For logging purposes
    "registry": registry,
    "sub_process": activity,
    # "condition_event": [from_site.container.get_empty_event, to_site.container.get_full_event],
    #"condition_event": to_site.container.get_full_event,
    "condition_event": expr,
    "postpone_start": False,
}
while_activity = model.WhileActivity(**while_data)
# Out:
# check weather plugin
# True
# True
# True
# regrister weather plugin
# check weather plugin
# True
# True
# True
# regrister weather plugin
# check weather plugin
# True
# True
# True
# regrister weather plugin
# check weather plugin
# True
# True
# True
# regrister weather plugin
# while Activity keep_resources []
# get_full_event : default
# start get_available
# start event instance None

# %%
my_env.run()
# Out:
# <openclsim.model.SequentialActivity object at 0x000001AD42B46AC8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# put_callback - id_ default
# {}
# put_callback - id_ default
# {'default': {40: <Event() object at 0x1ad42b4fc88>}}
# amount :40
# put_callback - id_ default
# {}
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [13800.0]
# we have to wait for 13800.0
# delay processing 13800.0
# before delay 1262300400.0
# after delay 1262314200.0
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# plugin_data start_preprocessing: 1262300400.0
# plugin_data start_activity: 1262314200.0
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B1FBC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf4-4589-11e9-a501-b469212bff5d': 40, 'destination.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b41808>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b41808>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b41808>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad40eeb9c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b41808>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad40eeb9c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b41808>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad40eeb9c8>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Hopper 01
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 40, 'capacity': 40}]
# start get 4
# store_status {'id': 'default', 'level': 40, 'capacity': 40}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad41aa3fc8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 36, 'capacity': 40}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 4}]
# <FilterStoreGet() object at 0x1ad41aa3fc8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 4, 'capacity': 4}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 36 of default
#   destination:  Hopper 01 contains: 4 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b41808>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad40eeb9c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad40eeb9c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer MP)
# <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1262317800.0
# after delay 1262317800.0
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# plugin_data start_preprocessing: 1262317800.0
# plugin_data start_activity: 1262317800.0
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B4F108>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4, 'destination.6dbbbdf5-4589-11e9-82b2-b469212bff5c': 40}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3848>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3848>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42acc708>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3848>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42acc708>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3848>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42acc708>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3848>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42acc708>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 4, 'capacity': 4}]
# start get 4
# store_status {'id': 'default', 'level': 4, 'capacity': 4}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad3b802748>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 4}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 40}]
# <FilterStoreGet() object at 0x1ad42b4fa48>
# put_callback - id_ default
# {'default': {40: <Event() object at 0x1ad42b4fc88>}}
# amount :40
# destination store after put: [{'id': 'default', 'level': 4, 'capacity': 40}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 4 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3848>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42acc708>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42acc708>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000001AD42B46AC8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [31457.175409]
# we have to wait for 31457.175409
# delay processing 31457.175409
# before delay 1262322342.8245912
# after delay 1262353800.0000002
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# plugin_data start_preprocessing: 1262322342.8245912
# plugin_data start_activity: 1262353800.0000002
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B1FBC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf4-4589-11e9-a501-b469212bff5d': 36, 'destination.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad41aa3f88>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad41aa3f88>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad41aa3f88>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad3b765cc8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad41aa3f88>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad3b765cc8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad41aa3f88>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad3b765cc8>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Hopper 01
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 36, 'capacity': 40}]
# start get 4
# store_status {'id': 'default', 'level': 36, 'capacity': 40}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad4128bd48>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 32, 'capacity': 40}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 4}]
# <FilterStoreGet() object at 0x1ad42ae5408>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 4, 'capacity': 4}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 32 of default
#   destination:  Hopper 01 contains: 4 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad41aa3f88>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad3b765cc8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad3b765cc8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer MP)
# <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [17057.175409]
# we have to wait for 17057.175409
# delay processing 17057.175409
# before delay 1262358342.8245914
# after delay 1262375400.0000005
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# plugin_data start_preprocessing: 1262358342.8245914
# plugin_data start_activity: 1262375400.0000005
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B4F108>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4, 'destination.6dbbbdf5-4589-11e9-82b2-b469212bff5c': 36}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3108>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3108>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bbc8>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3108>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bbc8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3108>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bbc8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3108>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bbc8>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 4, 'capacity': 4}]
# start get 4
# store_status {'id': 'default', 'level': 4, 'capacity': 4}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad42b1bc08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 4}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 4, 'capacity': 40}]
# <FilterStoreGet() object at 0x1ad42b1bc08>
# put_callback - id_ default
# {'default': {40: <Event() object at 0x1ad42b4fc88>}}
# amount :40
# destination store after put: [{'id': 'default', 'level': 8, 'capacity': 40}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 8 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41aa3108>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bbc8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bbc8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 1
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000001AD42B46AC8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1262379942.8245916
# after delay 1262379942.8245916
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# plugin_data start_preprocessing: 1262379942.8245916
# plugin_data start_activity: 1262379942.8245916
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B1FBC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf4-4589-11e9-a501-b469212bff5d': 32, 'destination.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bfc8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bfc8>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bfc8>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b0ce88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bfc8>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b0ce88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bfc8>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b0ce88>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Hopper 01
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 32, 'capacity': 40}]
# start get 4
# store_status {'id': 'default', 'level': 32, 'capacity': 40}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad42b13408>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 28, 'capacity': 40}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 4}]
# <FilterStoreGet() object at 0x1ad42b13408>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 4, 'capacity': 4}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 28 of default
#   destination:  Hopper 01 contains: 4 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1bfc8>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b0ce88>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b0ce88>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer MP)
# <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [16114.350817]
# we have to wait for 16114.350817
# delay processing 16114.350817
# before delay 1262384485.6491828
# after delay 1262400599.9999998
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# plugin_data start_preprocessing: 1262384485.6491828
# plugin_data start_activity: 1262400599.9999998
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B4F108>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4, 'destination.6dbbbdf5-4589-11e9-82b2-b469212bff5c': 32}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41a7d988>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41a7d988>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0c888>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41a7d988>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0c888>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41a7d988>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0c888>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41a7d988>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0c888>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 4, 'capacity': 4}]
# start get 4
# store_status {'id': 'default', 'level': 4, 'capacity': 4}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad41aa3fc8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 4}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 8, 'capacity': 40}]
# <FilterStoreGet() object at 0x1ad3b765cc8>
# put_callback - id_ default
# {'default': {40: <Event() object at 0x1ad42b4fc88>}}
# amount :40
# destination store after put: [{'id': 'default', 'level': 12, 'capacity': 40}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 12 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad41a7d988>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0c888>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0c888>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 2
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000001AD42B46AC8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1262405142.824591
# after delay 1262405142.824591
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# plugin_data start_preprocessing: 1262405142.824591
# plugin_data start_activity: 1262405142.824591
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B1FBC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf4-4589-11e9-a501-b469212bff5d': 28, 'destination.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0ca48>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0ca48>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0ca48>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b1b508>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0ca48>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b1b508>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0ca48>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b1b508>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Hopper 01
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 28, 'capacity': 40}]
# start get 4
# store_status {'id': 'default', 'level': 28, 'capacity': 40}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad42b1bec8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 24, 'capacity': 40}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 4}]
# <FilterStoreGet() object at 0x1ad42b1bec8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 4, 'capacity': 4}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 24 of default
#   destination:  Hopper 01 contains: 4 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b0ca48>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b1b508>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b1b508>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer MP)
# <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [30514.350818]
# we have to wait for 30514.350818
# delay processing 30514.350818
# before delay 1262409685.649182
# after delay 1262440200.0
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# plugin_data start_preprocessing: 1262409685.649182
# plugin_data start_activity: 1262440200.0
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B4F108>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4, 'destination.6dbbbdf5-4589-11e9-82b2-b469212bff5c': 28}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad3b81afc8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad3b81afc8>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b13788>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad3b81afc8>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b13788>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad3b81afc8>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b13788>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad3b81afc8>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b13788>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 4, 'capacity': 4}]
# start get 4
# store_status {'id': 'default', 'level': 4, 'capacity': 4}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad42b1bb88>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 4}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 12, 'capacity': 40}]
# <FilterStoreGet() object at 0x1ad42b13648>
# put_callback - id_ default
# {'default': {40: <Event() object at 0x1ad42b4fc88>}}
# amount :40
# destination store after put: [{'id': 'default', 'level': 16, 'capacity': 40}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 16 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad3b81afc8>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b13788>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b13788>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 3
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000001AD42B46AC8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [17057.175409]
# we have to wait for 17057.175409
# delay processing 17057.175409
# before delay 1262444742.8245912
# after delay 1262461800.0000002
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# plugin_data start_preprocessing: 1262444742.8245912
# plugin_data start_activity: 1262461800.0000002
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B1FBC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# ...
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [30514.350817]
# we have to wait for 30514.350817
# delay processing 30514.350817
# before delay 1262582485.6491826
# after delay 1262612999.9999995
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# plugin_data start_preprocessing: 1262582485.6491826
# plugin_data start_activity: 1262612999.9999995
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B4F108>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4, 'destination.6dbbbdf5-4589-11e9-82b2-b469212bff5c': 8}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b16e88>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b16e88>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1b248>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b16e88>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1b248>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b16e88>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1b248>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b16e88>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1b248>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 4, 'capacity': 4}]
# start get 4
# store_status {'id': 'default', 'level': 4, 'capacity': 4}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad42b1b508>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 4}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 32, 'capacity': 40}]
# <FilterStoreGet() object at 0x1ad42b1b508>
# put_callback - id_ default
# {'default': {40: <Event() object at 0x1ad42b4fc88>}}
# amount :40
# destination store after put: [{'id': 'default', 'level': 36, 'capacity': 40}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 36 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b16e88>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1b248>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b1b248>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 8
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000001AD42B46AC8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [17057.175409]
# we have to wait for 17057.175409
# delay processing 17057.175409
# before delay 1262617542.8245907
# after delay 1262634599.9999998
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D188>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B1FB88>
# plugin_data start_preprocessing: 1262617542.8245907
# plugin_data start_activity: 1262634599.9999998
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B1FBC8>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf4-4589-11e9-a501-b469212bff5d': 4, 'destination.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b162c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b162c8>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b162c8>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b4f8c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b162c8>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b4f8c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b162c8>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b4f8c8>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Hopper 01
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 4, 'capacity': 40}]
# start get 4
# store_status {'id': 'default', 'level': 4, 'capacity': 40}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad42b1bf48>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 40}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 4}]
# <FilterStoreGet() object at 0x1ad42b19788>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 4, 'capacity': 4}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Winlocatie  contains: 0 of default
#   destination:  Hopper 01 contains: 4 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b162c8>, <simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b4f8c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41A9D2C8>: <Request() object at 0x1ad42b4f8c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer MP)
# <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2010-01-01T03:50:00.000000000' '2010-01-01T05:10:00.000000000']
#  ['2010-01-01T14:50:00.000000000' '2010-01-01T15:10:00.000000000']
#  ['2010-01-01T20:50:00.000000000' '2010-01-01T22:30:00.000000000']
#  ['2010-01-02T03:50:00.000000000' '2010-01-02T05:10:00.000000000']
#  ['2010-01-02T14:50:00.000000000' '2010-01-02T15:10:00.000000000']
#  ['2010-01-02T20:50:00.000000000' '2010-01-02T22:30:00.000000000']
#  ['2010-01-03T03:50:00.000000000' '2010-01-03T05:10:00.000000000']
#  ['2010-01-03T14:50:00.000000000' '2010-01-03T15:10:00.000000000']
#  ['2010-01-03T20:50:00.000000000' '2010-01-03T22:30:00.000000000']
#  ['2010-01-04T03:50:00.000000000' '2010-01-04T05:10:00.000000000']
#  ['2010-01-04T14:50:00.000000000' '2010-01-04T15:10:00.000000000']
#  ['2010-01-04T20:50:00.000000000' '2010-01-04T22:30:00.000000000']
#  ['2010-01-05T03:50:00.000000000' '2010-01-05T05:10:00.000000000']
#  ['2010-01-05T14:50:00.000000000' '2010-01-05T15:10:00.000000000']
#  ['2010-01-05T20:50:00.000000000' '2010-01-05T22:30:00.000000000']
#  ['2010-01-06T03:50:00.000000000' '2010-01-06T05:10:00.000000000']
#  ['2010-01-06T14:50:00.000000000' '2010-01-06T15:10:00.000000000']
#  ['2010-01-06T20:50:00.000000000' '2010-01-06T22:30:00.000000000']
#  ['2010-01-07T03:50:00.000000000' '2010-01-07T05:10:00.000000000']
#  ['2010-01-07T14:50:00.000000000' '2010-01-07T15:10:00.000000000']
#  ['2010-01-07T20:50:00.000000000' '2010-01-07T22:30:00.000000000']
#  ['2010-01-08T03:50:00.000000000' '2010-01-08T05:10:00.000000000']
#  ['2010-01-08T14:50:00.000000000' '2010-01-08T15:10:00.000000000']
#  ['2010-01-08T20:50:00.000000000' '2010-01-08T21:50:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1262639142.824591
# after delay 1262639142.824591
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# Mover_move after move
# plugin_data mover: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data origin: <__main__.TransportProcessingResource object at 0x000001AD41AA3A88>
# plugin_data destination: <__main__.Site object at 0x000001AD41A9D0C8>
# plugin_data engine_oder: 1.0
# plugin_data activity_log: <__main__.TestMoveActivity object at 0x000001AD42B41C08>
# plugin_data start_preprocessing: 1262639142.824591
# plugin_data start_activity: 1262639142.824591
# Activity end(Soil movement)
# <__main__.TestMoveActivity object at 0x000001AD42B4F108>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.6dbbbdf6-4589-11e9-95a2-b469212bff5b': 4, 'destination.6dbbbdf5-4589-11e9-82b2-b469212bff5c': 4}
# destination request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b19f48>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b19f48>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b17288>}
# site request : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b19f48>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b17288>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b19f48>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b17288>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b19f48>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b17288>}
# _shift_amount
# start _shift_amount
# amount 4
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 4, 'capacity': 4}]
# start get 4
# store_status {'id': 'default', 'level': 4, 'capacity': 4}
# end get 4
# get_callback - id_ <StorePut() object at 0x1ad42b17d48>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 4}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 36, 'capacity': 40}]
# <FilterStoreGet() object at 0x1ad42b17d48>
# put_callback - id_ default
# {'default': {40: <Event() object at 0x1ad42b4fc88>}}
# amount :40
# destination store after put: [{'id': 'default', 'level': 40, 'capacity': 40}]
# after put
# processor end process
# Processed 4 of default:
#   by:          Hopper 01
#   origin        Hopper 01  contains: 0 of default
#   destination:  Dumplocatie contains: 40 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000001AD41A9D548>: <Request() object at 0x1ad42b19f48>, <simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b17288>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000001AD41AA3D88>: <Request() object at 0x1ad42b17288>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: True True round 9
# while loop requested_resources {}
# while loop keep_resources []

# %%
log_df = pd.DataFrame(hopper.log)
data =log_df[['Message', 'ActivityState', 'Timestamp', 'Value', 'ActivityID']]
data = data.drop_duplicates()
data
# Out:
#                              Message ActivityState                  Timestamp  \
# 0                      sailing empty         START 2010-01-01 03:50:00.000000
# 1                      sailing empty          STOP 2010-01-01 03:50:00.000000
# 2      transfer default to Hopper 01         START 2010-01-01 03:50:00.000000
# 4      transfer default to Hopper 01          STOP 2010-01-01 04:50:00.000000
# 6                     sailing filled         START 2010-01-01 04:50:00.000000
# ..                               ...           ...                        ...
# 112    transfer default to Hopper 01          STOP 2010-01-04 22:05:42.824591
# 114                   sailing filled         START 2010-01-04 22:05:42.824591
# 115                   sailing filled          STOP 2010-01-04 22:21:25.649182
# 116  transfer default to Dumplocatie         START 2010-01-04 22:21:25.649182
# 118  transfer default to Dumplocatie          STOP 2010-01-04 23:21:25.649182
#
#      Value                            ActivityID
# 0        0  1a544728-abd3-11ea-adb6-2079183a5c9a
# 1        0  1a544728-abd3-11ea-adb6-2079183a5c9a
# 2        4  6dbbbdf7-4589-11e9-bf3b-b469212bff52
# 4        4  6dbbbdf7-4589-11e9-bf3b-b469212bff52
# 6        4  1a5a62fa-abd3-11ea-a255-2079183a5c9a
# ..     ...                                   ...
# 112      4  6dbbbdf7-4589-11e9-bf3b-b469212bff52
# 114      4  1a5a62fa-abd3-11ea-a255-2079183a5c9a
# 115      4  1a5a62fa-abd3-11ea-a255-2079183a5c9a
# 116      4  6dbbbdf7-4589-11e9-bf3b-b469212bff54
# 118      4  6dbbbdf7-4589-11e9-bf3b-b469212bff54
#
# [80 rows x 5 columns]

# %%
import plotly.express as px

objects = [hopper, from_site, to_site]


activities = []
for obj in objects:
    activities.extend(set(obj.log["Message"]))

activities = list(set(activities))

fig = vessel_planning(objects, activities)

fig = px.line(metocean_df, x="DateTime", y="Hs [m]", title='Life expectancy in Canada')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="da51fb9b-9d4b-4934-8e4b-e2286efc47f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da51fb9b-9d4b-4934-8e4b-e2286efc47f6")) {
#                     Plotly.newPlot(
#                         'da51fb9b-9d4b-4934-8e4b-e2286efc47f6',
#                         [{"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(121,113,205)", "width": 10}, "mode": "lines", "name": "transfer default to Dumplocatie", "type": "scatter", "x": ["2010-01-01T05:05:42.824591", "2010-01-01T05:05:42.824591", "2010-01-01T06:05:42.824591", "2010-01-01T06:05:42.824591", "2010-01-01T06:05:42.824591", "2010-01-01T05:05:42.824591", "2010-01-01T05:05:42.824591", "2010-01-01T06:05:42.824591", "2010-01-01T06:05:42.824591", "2010-01-01T06:05:42.824591", "2010-01-01T21:05:42.824592", "2010-01-01T21:05:42.824592", "2010-01-01T22:05:42.824592", "2010-01-01T22:05:42.824592", "2010-01-01T22:05:42.824592", "2010-01-01T21:05:42.824592", "2010-01-01T21:05:42.824592", "2010-01-01T22:05:42.824592", "2010-01-01T22:05:42.824592", "2010-01-01T22:05:42.824592", "2010-01-02T04:05:42.824591", "2010-01-02T04:05:42.824591", "2010-01-02T05:05:42.824591", "2010-01-02T05:05:42.824591", "2010-01-02T05:05:42.824591", "2010-01-02T04:05:42.824591", "2010-01-02T04:05:42.824591", "2010-01-02T05:05:42.824591", "2010-01-02T05:05:42.824591", "2010-01-02T05:05:42.824591", "2010-01-02T15:05:42.824591", "2010-01-02T15:05:42.824591", "2010-01-02T16:05:42.824591", "2010-01-02T16:05:42.824591", "2010-01-02T16:05:42.824591", "2010-01-02T15:05:42.824591", "2010-01-02T15:05:42.824591", "2010-01-02T16:05:42.824591", "2010-01-02T16:05:42.824591", "2010-01-02T16:05:42.824591", "2010-01-02T22:21:25.649183", "2010-01-02T22:21:25.649183", "2010-01-02T23:21:25.649183", "2010-01-02T23:21:25.649183", "2010-01-02T23:21:25.649183", "2010-01-02T22:21:25.649183", "2010-01-02T22:21:25.649183", "2010-01-02T23:21:25.649183", "2010-01-02T23:21:25.649183", "2010-01-02T23:21:25.649183", "2010-01-03T05:21:25.649182", "2010-01-03T05:21:25.649182", "2010-01-03T06:21:25.649182", "2010-01-03T06:21:25.649182", "2010-01-03T06:21:25.649182", "2010-01-03T05:21:25.649182", "2010-01-03T05:21:25.649182", "2010-01-03T06:21:25.649182", "2010-01-03T06:21:25.649182", "2010-01-03T06:21:25.649182", "2010-01-03T21:05:42.824591", "2010-01-03T21:05:42.824591", "2010-01-03T22:05:42.824591", "2010-01-03T22:05:42.824591", "2010-01-03T22:05:42.824591", "2010-01-03T21:05:42.824591", "2010-01-03T21:05:42.824591", "2010-01-03T22:05:42.824591", "2010-01-03T22:05:42.824591", "2010-01-03T22:05:42.824591", "2010-01-04T04:05:42.824591", "2010-01-04T04:05:42.824591", "2010-01-04T05:05:42.824591", "2010-01-04T05:05:42.824591", "2010-01-04T05:05:42.824591", "2010-01-04T04:05:42.824591", "2010-01-04T04:05:42.