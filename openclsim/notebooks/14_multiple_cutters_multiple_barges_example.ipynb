# %% [markdown]
# # Demo Multiple Cutters - Multiple Barches
# This notebook shows a basics of a feeder concept. This scenario has two vessels:
# * a *vessel* for the transport of material
# * an *installer*, receiving the material and installing it.
# Thus, we also need two processes - one for each vessel. In this process the hand over of the material is done from the *vessel* to the *installer*.

# %%
import datetime, time
import simpy

import shapely.geometry
from simplekml import Kml, Style

# package(s) for data handling
import pandas as pd
import numpy as np

import openclsim.core as core
import openclsim.model as model
import openclsim.plot as plot
import uuid

from plot import vessel_planning


# setup environment
simulation_start = 0
my_env = simpy.Environment(initial_time=simulation_start)
registry = {}

# %% [markdown]
# ## Definition of Sites

# %%
# The generic site class
Site = type(
    "Site",
    (
        core.Identifiable,  # Give it a name
        core.Log,  # Allow logging of all discrete events
        core.Locatable,  # Add coordinates to extract distance information and visualize
        core.HasContainer,  # Add information on the material available at the site
        core.HasResource,
    ),  # Add information on serving equipment
    {},
)  # The dictionary is empty because the site type is generic

# Information on the extraction site - the "from site" - the "win locatie"
location_from_site = shapely.geometry.Point(4.18055556, 52.18664444)  # lon, lat

data_from_site = {
    "env": my_env,  # The simpy environment defined in the first cel
    "name": "Winlocatie1",  # The name of the site
    "geometry": location_from_site,  # The coordinates of the project site
    "capacity": 24,
    "level": 24,
    "nr_resources":3,
}  # The actual volume of the site
from_site = Site(**data_from_site)

location_to_site = shapely.geometry.Point(4.25222222, 52.11428333)  # lon, lat

data_to_site = {
    "env": my_env,  # The simpy environment defined in the first cel
    "name": "Dumplocatie",  # The name of the site
    "geometry": location_to_site,  # The coordinates of the project site
    "capacity": 24,
    "level": 0,
}  # The actual volume of the site (empty of course)
to_site = Site(**data_to_site)
# Out:
# init
# level: 24
# completed init
# init
# level: 0
# completed init

# %% [markdown]
# ## Definition of Vessels

# %%
# The generic class for an object that can move and transport (a TSHD for example)
TransportProcessingResource = type(
    "TransportProcessingResource",
    (
        core.Identifiable,  # Give it a name
        core.Log,  # Allow logging of all discrete events
        core.ContainerDependentMovable,  # A moving container, so capacity and location
        core.Processor,  # Allow for loading and unloading
        core.HasResource,  # Add information on serving equipment
        core.HasCosts,  # Add information on costs
        core.LoadingFunction,  # Add a loading function
        core.UnloadingFunction,  # Add an unloading function
        # SiteRegistry,
    ),
    {"key": "MultiStoreHopper"},
)

# print(SiteRegistry.inspect("MultiStoreHopper"))
# For more realistic simulation you might want to have speed dependent on the volume carried by the vessel
def compute_v_provider(v_empty, v_full):
    return lambda x: 10

data_cutter1 = {
    "env": my_env,  # The simpy environment
    "name": "Cutter1",  # Name
    "geometry": location_from_site,  # It starts at the "from site"
    "loading_rate": 1,  # Loading rate
    "unloading_rate": 1,  # Unloading rate
    "capacity": 1,
    "level": 0,
    "compute_v": compute_v_provider(5, 4.5),  # Variable speed
    "weekrate": 7,
}
cutter1 = TransportProcessingResource(**data_cutter1)
data_cutter2 = {
    "env": my_env,  # The simpy environment
    "name": "Cutter2",  # Name
    "geometry": location_from_site,  # It starts at the "from site"
    "loading_rate": 1,  # Loading rate
    "unloading_rate": 1,  # Unloading rate
    "capacity": 1,
    "level": 0,
    "compute_v": compute_v_provider(5, 4.5),  # Variable speed
    "weekrate": 7,
}
cutter2 = TransportProcessingResource(**data_cutter2)

# TSHD variables
data_hopper1 = {
    "env": my_env,  # The simpy environment
    "name": "Hopper1",  # Name
    "geometry": location_from_site,  # It starts at the "from site"
    "loading_rate": 1,  # Loading rate
    "unloading_rate": 1,  # Unloading rate
    "capacity": 1,
    "level": 0,
    "compute_v": compute_v_provider(5, 4.5),  # Variable speed
    "weekrate": 7,
}
hopper1 = TransportProcessingResource(**data_hopper1)
data_hopper2 = {
    "env": my_env,  # The simpy environment
    "name": "Hopper2",  # Name
    "geometry": location_from_site,  # It starts at the "from site"
    "loading_rate": 1,  # Loading rate
    "unloading_rate": 1,  # Unloading rate
    "capacity": 1,
    "level": 0,
    "compute_v": compute_v_provider(5, 4.5),  # Variable speed
    "weekrate": 7,
}
hopper2 = TransportProcessingResource(**data_hopper2)
data_hopper3 = {
    "env": my_env,  # The simpy environment
    "name": "Hopper3",  # Name
    "geometry": location_from_site,  # It starts at the "from site"
    "loading_rate": 1,  # Loading rate
    "unloading_rate": 1,  # Unloading rate
    "capacity": 1,
    "level": 0,
    "compute_v": compute_v_provider(5, 4.5),  # Variable speed
    "weekrate": 7,
}
hopper3 = TransportProcessingResource(**data_hopper3)
# Out:
# init
# level: 0
# completed init
# init
# level: 0
# completed init
# init
# level: 0
# completed init
# init
# level: 0
# completed init
# init
# level: 0
# completed init

# %% [markdown]
# ## Definition of Barge process

# %%
cutter_list = [cutter1, cutter2]
for hopper in [hopper1, hopper2, hopper3]:
    first_cutter = cutter_list[0]
    cutter_list= cutter_list[1:]
    cutter_list.append(first_cutter)
    for cutter in cutter_list:
        requested_resources = {}
        run = []
        
        shift_amount_loading_data = {
            "env": my_env,  # The simpy environment defined in the first cel
            "name": "Load",  # We are moving soil
            "registry": registry,
            "processor": cutter,
            "origin": from_site,
            "destination": hopper,
            "amount": 1,
            "duration": 10,
            "requested_resources":requested_resources,
            "keep_resources":[hopper],
            "postpone_start": True,
        }
        run.append(model.ShiftAmountActivity(**shift_amount_loading_data))
        
        move_activity_to_harbor_data = {
            "env": my_env,  # The simpy environment defined in the first cel
            "name": "sailing full",  # We are moving soil
            "registry": registry,
            "mover": hopper,
            "destination": to_site,
            "requested_resources":requested_resources,
            "keep_resources":[hopper],
            "postpone_start": True,
        }
        run.append(model.MoveActivity(**move_activity_to_harbor_data))

        shift_amount_loading_data = {
            "env": my_env,  # The simpy environment defined in the first cel
            "name": "Unload",  # We are moving soil
            "registry": registry,
            "processor": hopper,
            "origin": hopper,
            "destination": to_site,
            "amount": 1,
            "duration": 10,
            "requested_resources":requested_resources,
            "keep_resources":[hopper],
            "postpone_start": True,
        }
        run.append(model.ShiftAmountActivity(**shift_amount_loading_data))
        
        move_activity_to_harbor_data = {
            "env": my_env,  # The simpy environment defined in the first cel
            "name": "sailing empty",  # We are moving soil
            "registry": registry,
            "mover": hopper,
            "destination": from_site,
            "requested_resources":requested_resources,
            "postpone_start": True,
        }
        run.append(model.MoveActivity(**move_activity_to_harbor_data))

        sequential_activity_data = {
            "env": my_env,
            "name": "run",
            "registry": registry,
            "sub_processes": run,
            "postpone_start": True,
        }
        sequential_activity = model.SequentialActivity(**sequential_activity_data)
        
        while_data = {
            "env": my_env,  # The simpy environment defined in the first cel
            "name": "run while",  # We are moving soil
            "registry": registry,
            "sub_process": sequential_activity,
            "condition_event": [{"type":"container", "concept": from_site, "state":"empty"}],
            "postpone_start": False,
        }
        run_activity = model.WhileActivity(**while_data)
# Out:
# while Activity keep_resources []
# start put_available
# register new event
# start event instance None
# while Activity keep_resources []
# start put_available
# check put_available events
# register new event
# start event instance None
# while Activity keep_resources []
# start put_available
# check put_available events
# register new event
# start event instance None
# while Activity keep_resources []
# start put_available
# check put_available events
# register new event
# start event instance None
# while Activity keep_resources []
# start put_available
# check put_available events
# register new event
# start event instance None
# while Activity keep_resources []
# start put_available
# check put_available events
# register new event
# start event instance None

# %%
my_env.run()
# Out:
# <openclsim.model.SequentialActivity object at 0x0000016B4A013748>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A020C08>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 24, 'destination.f3d7de04-abd3-11ea-bd7f-2079183a5c9a': 1}
# <openclsim.model.SequentialActivity object at 0x0000016B49FFABC8>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B49FFA048>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 24, 'destination.f3d7de04-abd3-11ea-bd7f-2079183a5c9a': 1}
# <openclsim.model.SequentialActivity object at 0x0000016B4A001988>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B49FDECC8>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 24, 'destination.f3d7de05-abd3-11ea-bee0-2079183a5c9a': 1}
# <openclsim.model.SequentialActivity object at 0x0000016B4A009D48>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A009188>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 24, 'destination.f3d7de05-abd3-11ea-bee0-2079183a5c9a': 1}
# <openclsim.model.SequentialActivity object at 0x0000016B4A00D248>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A007548>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 24, 'destination.f3d803a2-abd3-11ea-9387-2079183a5c9a': 1}
# <openclsim.model.SequentialActivity object at 0x0000016B4A018688>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A00DA88>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 24, 'destination.f3d803a2-abd3-11ea-9387-2079183a5c9a': 1}
# put_callback - id_ default
# {}
# put_callback - id_ default
# {}
# put_callback - id_ default
# {}
# put_callback - id_ default
# {}
# put_callback - id_ default
# {}
# put_callback - id_ default
# {}
# put_callback - id_ default
# {}
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start get_available
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ffd408>}
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49ff2a48>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ffd408>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00ea08>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ffd408>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00ea08>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ffd408>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00ea08>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Hopper1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 24, 'capacity': 24}]
# start get 1
# store_status {'id': 'default', 'level': 24, 'capacity': 24}
# end get 1
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49ff2a48>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e948>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49ff2a48>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e948>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49ff2a48>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e948>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Hopper2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 23, 'capacity': 24}]
# start get 1
# store_status {'id': 'default', 'level': 23, 'capacity': 24}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b49b2dd48>
# start get_callback
# {'default': {24: <Event() object at 0x16b4a018cc8>}}
# origin store after get: [{'id': 'default', 'level': 22, 'capacity': 24}]
# after get
# after check_down time
# get_callback - id_ <StorePut() object at 0x16b4973b4c8>
# start get_callback
# {'default': {24: <Event() object at 0x16b4a018cc8>}}
# origin store after get: [{'id': 'default', 'level': 22, 'capacity': 24}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1}]
# <FilterStoreGet() object at 0x16b49ffda08>
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1}]
# <FilterStoreGet() object at 0x16b4973b4c8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1, 'capacity': 1}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Cutter2
#   origin        Winlocatie1  contains: 22 of default
#   destination:  Hopper1 contains: 1 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ffd408>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00ea08>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ffd408>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00ea08>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ffd408>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>}
# Activity end(Load)
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1, 'capacity': 1}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Cutter1
#   origin        Winlocatie1  contains: 22 of default
#   destination:  Hopper2 contains: 1 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49ff2a48>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e948>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49ff2a48>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e948>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49ff2a48>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>}
# Activity end(Load)
# <openclsim.model.MoveActivity object at 0x0000016B4A020E08>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# <openclsim.model.MoveActivity object at 0x0000016B497DEC08>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b4a00e9c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b4a00e9c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff2a48>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b4a00e9c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff2a48>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b4a00e9c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff2a48>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Hopper3
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 22, 'capacity': 24}]
# start get 1
# store_status {'id': 'default', 'level': 22, 'capacity': 24}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b4a014208>
# start get_callback
# {'default': {24: <Event() object at 0x16b4a018cc8>}}
# origin store after get: [{'id': 'default', 'level': 21, 'capacity': 24}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1}]
# <FilterStoreGet() object at 0x16b4a014208>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1, 'capacity': 1}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Cutter2
#   origin        Winlocatie1  contains: 21 of default
#   destination:  Hopper3 contains: 1 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b4a00e9c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff2a48>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b4a00e9c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff2a48>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b4a00e9c8>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>}
# Activity end(Load)
# <openclsim.model.MoveActivity object at 0x0000016B4A0078C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing full)
# Mover_move after move
# Activity end(sailing full)
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A013148>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>}
# {'origin.f3d7de04-abd3-11ea-bd7f-2079183a5c9a': 1, 'destination.f3d4333e-abd3-11ea-9932-2079183a5c9a': 24}
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A001408>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>}
# {'origin.f3d7de05-abd3-11ea-bee0-2079183a5c9a': 1, 'destination.f3d4333e-abd3-11ea-9932-2079183a5c9a': 24}
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a0133c8>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a0133c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a0133c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a0133c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a0133c8>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 1, 'capacity': 1}]
# start get 1
# store_status {'id': 'default', 'level': 1, 'capacity': 1}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b4a0149c8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing full)
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 24}]
# <FilterStoreGet() object at 0x16b4a0149c8>
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A007C08>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>}
# {'origin.f3d803a2-abd3-11ea-9387-2079183a5c9a': 1, 'destination.f3d4333e-abd3-11ea-9932-2079183a5c9a': 23}
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1, 'capacity': 24}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Hopper1
#   origin        Hopper1  contains: 0 of default
#   destination:  Dumplocatie contains: 1 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a0133c8>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49b2f848>}
# Activity end(Unload)
# <openclsim.model.MoveActivity object at 0x0000016B4A013448>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b495ab0c8>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b495ab0c8>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b495ab0c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b495ab0c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b495ab0c8>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 1, 'capacity': 1}]
# start get 1
# store_status {'id': 'default', 'level': 1, 'capacity': 1}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b4a0149c8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 1, 'capacity': 24}]
# <FilterStoreGet() object at 0x16b49afd308>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 2, 'capacity': 24}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Hopper2
#   origin        Hopper2  contains: 0 of default
#   destination:  Dumplocatie contains: 2 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b495ab0c8>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff2ac8>}
# Activity end(Unload)
# <openclsim.model.MoveActivity object at 0x0000016B4A0016C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ff5788>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ff5788>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ff5788>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ff5788>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ff5788>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 1, 'capacity': 1}]
# start get 1
# store_status {'id': 'default', 'level': 1, 'capacity': 1}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b49ff58c8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 2, 'capacity': 24}]
# <FilterStoreGet() object at 0x16b4a0133c8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 3, 'capacity': 24}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Hopper3
#   origin        Hopper3  contains: 0 of default
#   destination:  Dumplocatie contains: 3 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ff5788>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00e848>}
# Activity end(Unload)
# <openclsim.model.MoveActivity object at 0x0000016B4A007F08>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# Activity end(run)
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start get_available
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000016B4A013748>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A020C08>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 21, 'destination.f3d7de04-abd3-11ea-bd7f-2079183a5c9a': 1}
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a014888>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a014888>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e7c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a014888>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e7c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a014888>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e7c8>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Hopper1
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 21, 'capacity': 24}]
# start get 1
# store_status {'id': 'default', 'level': 21, 'capacity': 24}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b49fffb88>
# start get_callback
# {'default': {24: <Event() object at 0x16b4a018cc8>}}
# origin store after get: [{'id': 'default', 'level': 20, 'capacity': 24}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing empty)
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1}]
# <FilterStoreGet() object at 0x16b49fffb88>
# Activity end(run)
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1, 'capacity': 1}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Cutter1
#   origin        Winlocatie1  contains: 20 of default
#   destination:  Hopper1 contains: 1 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a014888>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e7c8>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a014888>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a00e7c8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a014888>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>}
# Activity end(Load)
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start get_available
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000016B4A001988>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B49FDECC8>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 20, 'destination.f3d7de05-abd3-11ea-bee0-2079183a5c9a': 1}
# <openclsim.model.MoveActivity object at 0x0000016B49FFA348>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ff5b88>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ff5b88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff5948>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ff5b88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff5948>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ff5b88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff5948>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Hopper2
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 20, 'capacity': 24}]
# start get 1
# store_status {'id': 'default', 'level': 20, 'capacity': 24}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b4a014748>
# start get_callback
# {'default': {24: <Event() object at 0x16b4a018cc8>}}
# origin store after get: [{'id': 'default', 'level': 19, 'capacity': 24}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing empty)
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1}]
# <FilterStoreGet() object at 0x16b4a014748>
# Activity end(run)
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1, 'capacity': 1}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Cutter2
#   origin        Winlocatie1  contains: 19 of default
#   destination:  Hopper2 contains: 1 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ff5b88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff5948>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ff5b88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b49ff5948>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FF2348>: <Request() object at 0x16b49ff5b88>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>}
# Activity end(Load)
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start get_available
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000016B4A00D248>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A007548>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 19, 'destination.f3d803a2-abd3-11ea-9387-2079183a5c9a': 1}
# <openclsim.model.MoveActivity object at 0x0000016B4A0094C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49fefd08>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49fefd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a014648>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49fefd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a014648>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49fefd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a014648>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Hopper3
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 19, 'capacity': 24}]
# start get 1
# store_status {'id': 'default', 'level': 19, 'capacity': 24}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b49fefd48>
# start get_callback
# {'default': {24: <Event() object at 0x16b4a018cc8>}}
# origin store after get: [{'id': 'default', 'level': 18, 'capacity': 24}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1}]
# <FilterStoreGet() object at 0x16b49fefd48>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1, 'capacity': 1}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Cutter1
#   origin        Winlocatie1  contains: 18 of default
#   destination:  Hopper3 contains: 1 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49fefd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a014648>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49fefd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a014648>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b49fefd08>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>}
# Activity end(Load)
# <openclsim.model.MoveActivity object at 0x0000016B4A00DDC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing full)
# <openclsim.model.ShiftAmountActivity object at 0x0000016B49FFA648>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>}
# {'origin.f3d7de04-abd3-11ea-bd7f-2079183a5c9a': 1, 'destination.f3d4333e-abd3-11ea-9932-2079183a5c9a': 21}
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ffa888>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ffa888>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ffa888>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ffa888>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ffa888>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 1, 'capacity': 1}]
# start get 1
# store_status {'id': 'default', 'level': 1, 'capacity': 1}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b49fef608>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing full)
# destination store before put: [{'id': 'default', 'level': 3, 'capacity': 24}]
# <FilterStoreGet() object at 0x16b49fef788>
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A0097C8>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>}
# {'origin.f3d7de05-abd3-11ea-bee0-2079183a5c9a': 1, 'destination.f3d4333e-abd3-11ea-9932-2079183a5c9a': 20}
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 4, 'capacity': 24}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Hopper1
#   origin        Hopper1  contains: 0 of default
#   destination:  Dumplocatie contains: 4 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b49ffa888>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49ffa288>}
# Activity end(Unload)
# <openclsim.model.MoveActivity object at 0x0000016B49FFA908>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a009a08>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a009a08>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a009a08>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a009a08>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a009a08>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 1, 'capacity': 1}]
# start get 1
# store_status {'id': 'default', 'level': 1, 'capacity': 1}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b4a00ee08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing full)
# destination store before put: [{'id': 'default', 'level': 4, 'capacity': 24}]
# <FilterStoreGet() object at 0x16b49ffab48>
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A018108>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>}
# {'origin.f3d803a2-abd3-11ea-9387-2079183a5c9a': 1, 'destination.f3d4333e-abd3-11ea-9932-2079183a5c9a': 19}
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 5, 'capacity': 24}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Hopper2
#   origin        Hopper2  contains: 0 of default
#   destination:  Dumplocatie contains: 5 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a009a08>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b4a013dc8>}
# Activity end(Unload)
# <openclsim.model.MoveActivity object at 0x0000016B4A009A88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a00ee08>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a00ee08>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a00ee08>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a00ee08>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a00dd08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a00ee08>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 1, 'capacity': 1}]
# start get 1
# store_status {'id': 'default', 'level': 1, 'capacity': 1}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b49ffb388>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1}]
# after get
# after check_down time
# ...
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 24}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 1}]
# <FilterStoreGet() object at 0x16b4a03b188>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 1, 'capacity': 1}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Cutter1
#   origin        Winlocatie1  contains: 0 of default
#   destination:  Hopper3 contains: 1 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a048e88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a048f48>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a048e88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9548>: <Request() object at 0x16b4a048f48>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>, <simpy.resources.resource.Resource object at 0x0000016B4A014EC8>: <Request() object at 0x16b4a048e88>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>}
# Activity end(Load)
# <openclsim.model.MoveActivity object at 0x0000016B4A00DDC8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing full)
# <openclsim.model.ShiftAmountActivity object at 0x0000016B49FFA648>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>}
# {'origin.f3d7de04-abd3-11ea-bd7f-2079183a5c9a': 1, 'destination.f3d4333e-abd3-11ea-9932-2079183a5c9a': 3}
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a018e88>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a018e88>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a018e88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a018e88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a018e88>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 1, 'capacity': 1}]
# start get 1
# store_status {'id': 'default', 'level': 1, 'capacity': 1}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b4a03bcc8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing full)
# destination store before put: [{'id': 'default', 'level': 21, 'capacity': 24}]
# <FilterStoreGet() object at 0x16b49ff55c8>
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A0097C8>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>}
# {'origin.f3d7de05-abd3-11ea-bee0-2079183a5c9a': 1, 'destination.f3d4333e-abd3-11ea-9932-2079183a5c9a': 2}
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 22, 'capacity': 24}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Hopper1
#   origin        Hopper1  contains: 0 of default
#   destination:  Dumplocatie contains: 22 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a018e88>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49feff08>}
# Activity end(Unload)
# <openclsim.model.MoveActivity object at 0x0000016B49FFA908>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba88>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba88>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba88>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 1, 'capacity': 1}]
# start get 1
# store_status {'id': 'default', 'level': 1, 'capacity': 1}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b4a04d708>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1}]
# after get
# after check_down time
# Mover_move after move
# Activity end(sailing full)
# destination store before put: [{'id': 'default', 'level': 22, 'capacity': 24}]
# <FilterStoreGet() object at 0x16b4a03b748>
# <openclsim.model.ShiftAmountActivity object at 0x0000016B4A018108>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start event instance None
# start : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>}
# {'origin.f3d803a2-abd3-11ea-9387-2079183a5c9a': 1, 'destination.f3d4333e-abd3-11ea-9932-2079183a5c9a': 1}
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 23, 'capacity': 24}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Hopper2
#   origin        Hopper2  contains: 0 of default
#   destination:  Dumplocatie contains: 23 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba88>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2BC8>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF2E88>: <Request() object at 0x16b49ff9d88>}
# Activity end(Unload)
# <openclsim.model.MoveActivity object at 0x0000016B4A009A88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba08>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba08>}
# site request : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba08>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba08>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba08>}
# _shift_amount
# start _shift_amount
# amount 1
# processor start process
# transfer default to Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 1, 'capacity': 1}]
# start get 1
# store_status {'id': 'default', 'level': 1, 'capacity': 1}
# end get 1
# get_callback - id_ <StorePut() object at 0x16b4a03b148>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0, 'capacity': 1}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 23, 'capacity': 24}]
# <FilterStoreGet() object at 0x16b4a03b148>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 24, 'capacity': 24}]
# after put
# processor end process
# Processed 1 of default:
#   by:          Hopper3
#   origin        Hopper3  contains: 0 of default
#   destination:  Dumplocatie contains: 24 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>, <simpy.resources.resource.Resource object at 0x0000016B49FE9A48>: <Request() object at 0x16b4a03ba08>}
# keep resources [<__main__.TransportProcessingResource object at 0x0000016B49FF5188>]
# release destination : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>}
# released origin : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>}
# released processor : {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>}
# {<simpy.resources.resource.Resource object at 0x0000016B49FF5448>: <Request() object at 0x16b4a0205c8>}
# Activity end(Unload)
# <openclsim.model.MoveActivity object at 0x0000016B4A0183C8>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# Mover_move after move
# Activity end(sailing empty)
# Activity end(run)
# destination request : {<simpy.resources.resource.Resource object at 0x0000016B49FF28C8>: <Request() object at 0x16b49fefe88>}
# shift amount process keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start get_available
# condition event triggered: False False round 3
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x0000016B49FFABC8>
# conditional
# start event instance None
# <openclsim.model.ShiftAmountActivity object at 0x0000016B49FFA048>
# keep_resources []
# SHift amount Activity keep_resources [<__main__.TransportProcessingResource object at 0x0000016B49FF2608>]
# start event instance None
# start : {}
# {'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 0, 'destination.f3d7de04-abd3-11ea-bd7f-2079183a5c9a': 1}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\users\d4l\github\openclsim\openclsim\model.py in conditional_process(activity_log, env, condition_event, sub_process, name, requested_resources, keep_resources)
#     607         sub_process.start()
# --> 608         yield from sub_process.call_main_proc(activity_log=activity_log, env=env)
#     609         sub_process.end()
#
# c:\users\d4l\github\openclsim\openclsim\model.py in sequential_process(activity_log, env, sub_processes, name, requested_resources, keep_resources)
#     878         sub_process.start()
# --> 879         yield from sub_process.call_main_proc(activity_log=sub_process, env=env)
#     880         sub_process.end()
#
# c:\users\d4l\github\openclsim\openclsim\model.py in shift_amount_process(activity_log, env, processor, origin, destination, name, duration, amount, requested_resources, keep_resources, id_, engine_order, stop_reservation_waiting_event)
#     837         raise RuntimeError(
# --> 838             f"Attempting to shift content from an empty origin or to a full destination. ({all_amounts})"
#     839         )
#
# RuntimeError: Attempting to shift content from an empty origin or to a full destination. ({'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 0, 'destination.f3d7de04-abd3-11ea-bd7f-2079183a5c9a': 1})
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-cf25dcac65e6> in <module>
# ----> 1 my_env.run()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\simpy\core.py in run(self, until)
#     136         try:
#     137             while True:
# --> 138                 self.step()
#     139         except StopSimulation as exc:
#     140             return exc.args[0]  # == until.value
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\simpy\core.py in step(self)
#     228             exc = type(event._value)(*event._value.args)
#     229             exc.__cause__ = event._value
# --> 230             raise exc
#
# RuntimeError: Attempting to shift content from an empty origin or to a full destination. ({'origin.f3d40c02-abd3-11ea-a9c5-2079183a5c9a': 0, 'destination.f3d7de04-abd3-11ea-bd7f-2079183a5c9a': 1})

# %% [markdown]
# ## Cutter1 log

# %%
log_df = pd.DataFrame(cutter1.log)
data = log_df[["Message", "ActivityState", "Timestamp", "Value", "ActivityID"]]
data = data.drop_duplicates()
data

# %% [markdown]
# ## Cutter2 log

# %%
log2_df = pd.DataFrame(cutter2.log)
data2 = log2_df[["Message", "ActivityState", "Timestamp", "Value", "ActivityID"]]
data2 = data2.drop_duplicates()
data2

# %% [markdown]
# ## Hopper1 log

# %%
hopper1_log_df = pd.DataFrame(hopper1.log)
data_hopper1 = hopper1_log_df[["Message", "ActivityState", "Timestamp", "Value", "ActivityID"]]
data_hopper1 = data_hopper1.drop_duplicates()
data_hopper1

# %% [markdown]
# ## Hopper2 log

# %%
hopper2_log_df = pd.DataFrame(hopper2.log)
data_hopper2 = hopper2_log_df[["Message", "ActivityState", "Timestamp", "Value", "ActivityID"]]
data_hopper2 = data_hopper2.drop_duplicates()
data_hopper2

# %% [markdown]
# ## Hopper3 log

# %%
hopper3_log_df = pd.DataFrame(hopper3.log)
data_hopper3 = hopper3_log_df[["Message", "ActivityState", "Timestamp", "Value", "ActivityID"]]
data_hopper3 = data_hopper3.drop_duplicates()
data_hopper3

# %%
objects = [cutter1, cutter2, hopper1, hopper2, hopper3]

activities = []
for obj in objects:
    activities.extend(set(obj.log["Message"]))

activities = list(set(activities))

fig = vessel_planning(objects, activities)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="8ac40696-e284-4609-a986-50177bab59e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ac40696-e284-4609-a986-50177bab59e3")) {
#                     Plotly.newPlot(
#                         '8ac40696-e284-4609-a986-50177bab59e3',
#                         [{"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(194,118,212)", "width": 10}, "mode": "lines", "name": "transfer default to Hopper1", "type": "scatter", "x": ["1970-01-01T01:31:45.649183", "1970-01-01T01:31:45.649183", "1970-01-01T01:31:55.649183", "1970-01-01T01:31:55.649183", "1970-01-01T01:31:55.649183", "1970-01-01T02:35:16.947548", "1970-01-01T02:35:16.947548", "1970-01-01T02:35:26.947548", "1970-01-01T02:35:26.947548", "1970-01-01T02:35:26.947548", "1970-01-01T03:38:48.245913", "1970-01-01T03:38:48.245913", "1970-01-01T03:38:58.245913", "1970-01-01T03:38:58.245913", "1970-01-01T03:38:58.245913", "1970-01-01T04:42:19.544278", "1970-01-01T04:42:19.544278", "1970-01-01T04:42:29.544278", "1970-01-01T04:42:29.544278", "1970-01-01T04:42:29.544278", "1970-01-01T01:00:00", "1970-01-01T01:00:00", "1970-01-01T01:00:10", "1970-01-01T01:00:10", "1970-01-01T01:00:10", "1970-01-01T02:03:31.298365", "1970-01-01T02:03:31.298365", "1970-01-01T02:03:41.298365", "1970-01-01T02:03:41.298365", "1970-01-01T02:03:41.298365", "1970-01-01T03:07:02.596730", "1970-01-01T03:07:02.596730", "1970-01-01T03:07:12.596730", "1970-01-01T03:07:12.596730", "1970-01-01T03:07:12.596730", "1970-01-01T04:10:33.895095", "1970-01-01T04:10:33.895095", "1970-01-01T04:10:43.895095", "1970-01-01T04:10:43.895095", "1970-01-01T04:10:43.895095", "1970-01-01T01:00:00", "1970-01-01T01:00:00", "1970-01-01T01:00:10", "1970-01-01T01:00:10", "1970-01-01T01:00:10", "1970-01-01T01:31:45.649183", "1970-01-01T01:31:45.649183", "1970-01-01T01:31:55.649183", "1970-01-01T01:31:55.649183", "1970-01-01T01:31:55.649183", "1970-01-01T02:03:31.298365", "1970-01-01T02:03:31.298365", "1970-01-01T02:03:41.298365", "1970-01-01T02:03:41.298365", "1970-01-01T02:03:41.298365", "1970-01-01T02:35:16.947548", "1970-01-01T02:35:16.947548", "1970-01-01T02:35:26.947548", "1970-01-01T02:35:26.947548", "1970-01-01T02:35:26.947548", "1970-01-01T03:07:02.596730", "1970-01-01T03:07:02.596730", "1970-01-01T03:07:12.596730", "1970-01-01T03:07:12.596730", "1970-01-01T03:07:12.596730", "1970-01-01T03:38:48.245913", "1970-01-01T03:38:48.245913", "1970-01-01T03:38:58.245913", "1970-01-01T03:38:58.245913", "1970-01-01T03:38:58.245913", "1970-01-01T04:10:33.895095", "1970-01-01T04:10:33.895095", "1970-01-01T04:10:43.895095", "1970-01-01T04:10:43.895095", "1970-01-01T04:10:43.895095", "1970-01-01T04:42:19.544278", "1970-01-01T04:42:19.544278", "1970-01-01T04:42:29.544278", "1970-01-01T04:42:29.544278", "1970-01-01T04:42:29.544278"], "y": ["Cutter1", "Cutter1", "Cutter1", "Cutter1", null, "Cutter1", "Cutter1", "Cutter1", "Cutter1", null, "Cutter1", "Cutter1", "Cutter1", "Cutter1", null, "Cutter1", "Cutter1", "Cutter1", "Cutter1", null, "Cutter2", "Cutter2", "Cutter2", "Cutter2", null, "Cutter2", "Cutter2", "Cutter2", "Cutter2", null, "Cutter2", "Cutter2", "Cutter2", "Cutter2", null, "Cutter2", "Cutter2", "Cutter2", "Cutter2", null, "Hopper1", "Hopper1", "Hopper1", "Hopper1", null, "Hopper1", "Hopper1", "Hopper1", "Hopper1", null, "Hopper1", "Hopper1", "Hopper1", "Hopper1", null, "Hopper1", "Hopper1", "Hopper1", "Hopper1", null, "Hopper1", "Hopper1", "Hopper1", "Hopper1", null, "Hopper1", "Hopper1", "Hopper1", "Hopper1", null, "Hopper1", "Hopper1", "Hopper1", "Hopper1", null, "Hopper1", "Hopper1", "Hopper1", "Hopper1", null]}, {"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(236,160,254)", "width": 10}, "mode": "lines", "name": "sailing filled", "type": "scatter", "x": ["1970-01-01T01:00:10", "1970-01-01T01:00:10", "1970-01-01T01:15:52.824591", "1970-01-01T01:15:52.824591", "1970-01-01T01:15:52.824591", "1970-01-01T01:31:55.649183", "1970-01-01T01:31:55.649183", "1970-01-01T01:47:38.473774", "1970-01-01T01:47:38.473774", "1970-01-01T01:47:38.473774", "1970-01-01T02:03:41.298365", "1970-01-01T02:03:41.298365", "1970-01-01T02:19:24.122956", "1970-01-01T02:19:24.122956", "1970-01-01T02:19:24.122956", "1970-01-01T02:35:26.947548", "1970-01-01T02:35:26.9475 ...
