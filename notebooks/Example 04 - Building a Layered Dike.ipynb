# %% [markdown]
# ## Example 04 - Building a Layered Dike

# %% [markdown]
# **Example description:** Example of a construction challenge, with four separate activites, where each activity depends on the progress of the other activities.

# %% [markdown]
# * [**0. Import required libraries:**](#0.-Import-required-libraries)<br>
# * [**1. Define work method:**](#1.-Define-work-method)<br>
#    * [**1.1 Sites:**](#1.1-Define-the-project-sites)<br>
#    * [**1.2 Equipment:**](#1.2-Define-the-project-equipment)<br>
#    * [**1.3 Activities:**](#1.3-Define-the-activity)<br>
# * [**2. Run the simulation:**](#2.-Run-the-simulation)<br>
# * [**3. Post processing:**](#3.-Postprocessing)<br>

# %% [markdown]
# ## 0. Import required libraries

# %%
# package(s) related to time, space and id
import datetime, time
import platform

# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy

# spatial libraries 
import shapely.geometry
from simplekml import Kml, Style

# package(s) for data handling
import numpy as np

# digital twin package
import digital_twin.core as core
import digital_twin.model as model
import digital_twin.plot as plot

# %%
# Create simulation environment
simulation_start = datetime.datetime.now()

my_env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
my_env.epoch = time.mktime(simulation_start.timetuple())

# %% [markdown]
# ## 1. Define work method

# %% [markdown]
# ### 1.1 Define the project sites
# You can specify a project site object by entering mix-ins:
#
#     core.Identifiable - enables you to give the object a name
#     core.Log - enables you to log all discrete events in which the object is involved
#     core.Locatable - enables you to add coordinates to extract distance information and visualize
#     core.HasContainer - enables you to add information on the material available at the site
#     core.HasResource - enables you to add information on serving equipment
#     core.HasWeather - enables you to add weather conditions

# %% [markdown]
# #### First create objects with the desired properties

# %%
Site = type('Site', (core.Identifiable, 
                     core.Log, 
                     core.Locatable, 
                     core.HasContainer, 
                     core.HasResource), {})

# %% [markdown]
# #### Next specify the properties for sites you wish to create

# %%
# origin sites data
data_stock_clay = {"env": my_env,
                   "name": "Clay_Stock",
                   "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000}

data_stock_sand = {"env": my_env,
                   "name": "Sand_Stock",
                   "geometry": shapely.geometry.Point(5.271417603333632, 52.9638452897506),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000}

data_stock_armour = {"env": my_env,
                   "name": "Armour_Stock",
                   "geometry": shapely.geometry.Point(5.919298185633251, 52.94239823421129),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000}

data_stock_levvel = {"env": my_env,
                   "name": "Levvel_Stock",
                   "geometry": shapely.geometry.Point(5.919298185633251, 52.94239823421129),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000}

# %%
# destination sites data

# nr of bins to use
site_count = 20

data_clay = {"start": [5.054676856441372, 52.94042293840172], # Den Oever (lon, lat)
             "stop": [5.294877712236641, 53.06686424241725], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Clay_Layer"}

data_sand = {"start": [5.052051052879287,52.9421894472733], # Den Oever (lon, lat)
             "stop": [5.292216781509101,53.06886359869087], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Sand_Layer"}

data_armour = {"start": [5.049510554598302,52.94393628899332], # Den Oever (lon, lat)
             "stop": [5.289636346490858,53.07053144816584], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Armour_Layer"}

data_levvel = {"start": [5.046556507026805,52.94579445406793], # Den Oever (lon, lat)
             "stop": [5.286775240694118,53.07264015015531], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Levvel_Layer"}

# %% [markdown]
# #### Finally create specific instances of the predefined objects with the specified properties

# %%
# create the site objects
stocks = []
for data in [data_stock_clay, data_stock_sand, data_stock_armour, data_stock_levvel]:
    stock = Site(**data)
    stocks.append(stock)

# %%
sites = []
for data_layer in [data_clay, data_sand, data_armour, data_levvel]:
    start = data_layer['start']
    stop = data_layer['stop']

    # generate the evenly spaced locations between the selected start and stop points
    lons = np.linspace(start[0], stop[0], num=site_count)
    lats = np.linspace(start[1], stop[1], num=site_count)

    # create a Site object for each location
    layer_sites = []
    for i in range(site_count):
        data_site = {"env": my_env,
                     "name": data_layer["name"] + '_' + format(i, '02.0f'),
                     "geometry": shapely.geometry.Point(lons[i], lats[i]),
                     "capacity": data_layer["capacity"]}
        site = Site(**data_site)
        layer_sites.append(site)
    sites.append(layer_sites)

# %% [markdown]
# ### 1.2 Define the project equipment
# You can specify a vessel object by entering mix-ins:
#
#     core.Identifiable - enables you to give the object a name
#     core.Log - enables you to log all discrete events in which the object is involved
#     core.ContainerDependentMovable - A moving container, so capacity and location
#     core.Processor - Allow for loading and unloading
#     core.HasResource - Add information on serving equipment
#     core.HasDepthRestriction - Add information on depth restriction

# %% [markdown]
# #### First create objects with the desired properties

# %%
TransportResource = type('TransportResource', 
                         (core.Identifiable, 
                          core.Log, 
                          core.ContainerDependentMovable, 
                          core.HasResource), {})

TransportProcessingResource = type('TransportProcessingResource', 
                                   (core.Identifiable, 
                                    core.Log, 
                                    core.ContainerDependentMovable, 
                                    core.Processor, 
                                    core.HasResource), {})

ProcessingResource = type('ProcessingResource', 
                          (core.Identifiable, 
                           core.Log, 
                           core.Processor, 
                           core.HasResource,
                           core.Movable), {})

# %% [markdown]
# #### Next specify the properties for equipment you wish to create

# %%
# For more realistic simulation you might want to have speed dependent on the volume carried by the vessel
def compute_v_provider(v_empty, v_full):
    return lambda x: x * (v_full - v_empty) + v_empty

def compute_loading(rate):
    return lambda current_level, desired_level: (desired_level - current_level) / rate

def compute_unloading(rate):
    return lambda current_level, desired_level: (current_level - desired_level) / rate

# %%
# equipment information in database
data_gantry_crane = {"env": my_env,
                     "name": "Gantry crane",
                     "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                     "loading_func": compute_loading(0.1),                # Loading rate
                     "unloading_func": compute_unloading(0.1)}            # Unloading rate


data_installation_crane = {"env": my_env,
                           "name": "Installation crane",
                           "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                           "loading_func": compute_loading(0.5),                # Loading rate
                           "unloading_func": compute_unloading(0.5)}            # Unloading rate


data_transport_barge_01 = {"env": my_env,
                           "name": "Transport barge 01",
                           "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                           "capacity": 1_000,
                           "compute_v": compute_v_provider(v_empty=1.6, v_full=1)}

data_transport_barge_02 = {"env": my_env,
                           "name": "Transport barge 02",
                           "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                           "capacity": 1_000,
                           "compute_v": compute_v_provider(v_empty=1.6, v_full=1)}

# TSHD variables
data_hopper = {"env": my_env,                                       # The simpy environment 
               "name": "Hopper",                                    # Name
               "geometry": shapely.geometry.Point(5.070195628786471, 52.93917167503315),                      # It starts at the "from site"
               "loading_func": compute_loading(1.5),                # Loading rate
               "unloading_func": compute_unloading(1.5),            # Unloading rate
               "capacity": 1_000,                                   # Capacity of the hopper - "Beunvolume"
               "compute_v": compute_v_provider(2, 1.5)}             # Variable speed

# %% [markdown]
# #### Finally create specific instances of the predefined objects with the specified properties

# %%
# create the processing resources
gantry_crane = ProcessingResource(**data_gantry_crane)
installation_crane = ProcessingResource(**data_installation_crane)

# create the transport resources
transport_barge_01 = TransportResource(**data_transport_barge_01)
transport_barge_02 = TransportResource(**data_transport_barge_02)

# create the transport processing resource
hopper = TransportProcessingResource(**data_hopper)

# %% [markdown]
# ### 1.3 Define the activity
# As can be seen in the code fragment above, the Activity class takes the Simpy environment and a name as its constructor arguments. This is because it is defined as a mixin of the SimpyObject and Identifiable core classes. To construct an activity we also needed to define the origin, destination, loader, mover and unloader. Finally, we can optionally define conditions that need to be satisfied for the transportation of materials to take place. These are separated in __start_condition__, __stop_condition__ and __condition__ arguments:
# * __start_condition__: The activity will start as soon as this condition is satisfied. If this condition is not yet satisfied at the start of the simulation the activity will be suspended untill the condition is satisfied at a later time. Since we do not want any clay to be transported to the later sites if the previous site has not yet been completed, we define this condition as a start_condition.
# * __stop_condition__: After the activity has started (the start_condition was satisfied), it will regularly check if the stop_condition has been satisfied. If so, the activity is considered complete and will terminate. A simulation will not terminate untill all of its activities have been completed. By default (with stop_condition=None), the stop_condition is set to either the origin container being empty, or the destination container being full. This is sufficient in our case, so we do not specify a stop_condition.
# * __condition__: After the activity has started (the start_condition was satisfied) and as long as the stop_condition is not satisfied, the activity will continuously check whether this condition is satisfied. If so, it will complete exactly one transportation of materials (loading the mover at the origin and unloading the mover at the destination). If not, the activity will wait untill the condition is satisfied again. Defining such a condition allows for the activity to be temporarily halted, for example due to bad weather or other working conditions, and resuming at a later time when the problem preventing work has passed.
#
# All of these condition arguments take a "Condition" object. This object should have a "satisfied" method which returns a boolean indicating whether the condition is satsified or not. The digital twin package provides a LevelCondition, allowing you to quickly construct a condition which will check if an object extending HasContainer has a certain minimum and/or maximum level. It also provides an AndCondition and OrCondition which allow for combining other condition objects into a single condition. You can also provide your own "Condition" class, for example you could program a "Condition" class which depending on the time in the simulation (the .now fixture of the Simpy environment), returns whether the weather is good enough for work to take place:

# %%
activities = []

# %%
# define the sand layer Activities
clay_layer_index = 0
clay_sites = sites[clay_layer_index]
for i, clay_site in enumerate(clay_sites):
    for barge_index, transport_barge in enumerate([transport_barge_01, transport_barge_02]):
        # for the first site we do not need to define any condition
        condition = None if i == 0 else model.LevelCondition(container=clay_sites[i-1], min_level=data_clay["capacity"])
        activity = model.Activity(env=my_env,
                                  name="Clay_Placement_S" + format(i+1, '02.0f') + "_B" + format(barge_index + 1, '02.0f'),
                                  origin=stocks[clay_layer_index],
                                  destination=clay_site,
                                  loader=gantry_crane,
                                  mover=transport_barge,
                                  unloader=installation_crane,
                                  start_condition=condition)
        activities.append(activity)

# %%
# define the sand layer Activities
sand_layer_index = 1
sand_sites = sites[sand_layer_index]
for i, sand_site in enumerate(sand_sites):
    # for the first site we do not need to define a condition on the previous site
    prev_site_condition = model.TrueCondition() if i == 0 else model.LevelCondition(container=sand_sites[i-1], 
                                                                          min_level=sand_sites[i-1].container.capacity)
    prev_layer_sites = sites[clay_layer_index]
    prev_layer_condition = model.LevelCondition(prev_layer_sites[i], min_level=prev_layer_sites[i].container.capacity)
    start_condition = model.AndCondition([prev_site_condition, prev_layer_condition])
    activity = model.Activity(env=my_env,
                              name="Sand_Placement_S" + format(i+1, '02.0f'),
                              origin=stocks[sand_layer_index],
                              destination=sand_site,
                              loader=hopper,
                              mover=hopper,
                              unloader=hopper,
                              start_condition=start_condition)
    activities.append(activity)

# %%
# define the armour and level layer activities
layer_names = ["Armour_Placement", "Levvel_Placement"]
layer_indices = [2, 3]
for layer_index in layer_indices:
    for barge_index, transport_barge in enumerate([transport_barge_01, transport_barge_02]):
        layer_sites = sites[layer_index]
        for site_index, site in enumerate(layer_sites):
            # for the first site we do not need to define a condition on the previous site
            prev_site_condition = model.TrueCondition() if site_index == 0 else \
                model.LevelCondition(container=layer_sites[site_index-1], 
                                     min_level=layer_sites[site_index-1].container.capacity)
            
            prev_layer_sites = sites[layer_index - 1]
            prev_layer_condition = model.LevelCondition(container=prev_layer_sites[site_index],
                                                        min_level=prev_layer_sites[site_index].container.capacity)
            start_condition = model.AndCondition([prev_site_condition, prev_layer_condition])
            
            activity = model.Activity(env=my_env,
                                      name=layer_names[layer_index-2] + "_S" + format(site_index+1, '02.0f')
                                           + "_B" + format(barge_index+1, '02.0f'),
                                      origin=stocks[layer_index],
                                      destination=site,
                                      loader=gantry_crane,
                                      mover=transport_barge,
                                      unloader=installation_crane,
                                      start_condition=start_condition)
            activities.append(activity)

# %% [markdown]
# ### 2. Run the simulation

# %%
my_env.run()

print("\n*** Activity finished in {} ***".format(datetime.timedelta(seconds=int(my_env.now - my_env.epoch))))
# Out:
# Time = 2019-03-06 08:30
# Start condition is satisfied, Clay_Placement_S01_B01 transporting from Clay_Stock to Clay_Layer_00 started.
#
# Time = 2019-03-06 08:30
# Start condition is satisfied, Clay_Placement_S01_B02 transporting from Clay_Stock to Clay_Layer_00 started.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S02_B01 to Clay_Layer_01 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S02_B02 to Clay_Layer_01 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S03_B01 to Clay_Layer_02 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S03_B02 to Clay_Layer_02 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S04_B01 to Clay_Layer_03 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S04_B02 to Clay_Layer_03 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S05_B01 to Clay_Layer_04 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S05_B02 to Clay_Layer_04 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S06_B01 to Clay_Layer_05 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S06_B02 to Clay_Layer_05 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S07_B01 to Clay_Layer_06 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S07_B02 to Clay_Layer_06 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S08_B01 to Clay_Layer_07 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S08_B02 to Clay_Layer_07 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S09_B01 to Clay_Layer_08 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S09_B02 to Clay_Layer_08 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S10_B01 to Clay_Layer_09 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S10_B02 to Clay_Layer_09 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S11_B01 to Clay_Layer_10 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S11_B02 to Clay_Layer_10 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S12_B01 to Clay_Layer_11 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S12_B02 to Clay_Layer_11 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S13_B01 to Clay_Layer_12 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S13_B02 to Clay_Layer_12 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S14_B01 to Clay_Layer_13 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S14_B02 to Clay_Layer_13 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S15_B01 to Clay_Layer_14 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S15_B02 to Clay_Layer_14 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S16_B01 to Clay_Layer_15 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S16_B02 to Clay_Layer_15 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S17_B01 to Clay_Layer_16 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S17_B02 to Clay_Layer_16 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S18_B01 to Clay_Layer_17 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S18_B02 to Clay_Layer_17 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S19_B01 to Clay_Layer_18 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S19_B02 to Clay_Layer_18 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S20_B01 to Clay_Layer_19 suspended.
#
# Time = 2019-03-06 08:30
# Clay_Placement_S20_B02 to Clay_Layer_19 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S01 to Sand_Layer_00 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S02 to Sand_Layer_01 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S03 to Sand_Layer_02 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S04 to Sand_Layer_03 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S05 to Sand_Layer_04 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S06 to Sand_Layer_05 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S07 to Sand_Layer_06 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S08 to Sand_Layer_07 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S09 to Sand_Layer_08 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S10 to Sand_Layer_09 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S11 to Sand_Layer_10 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S12 to Sand_Layer_11 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S13 to Sand_Layer_12 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S14 to Sand_Layer_13 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S15 to Sand_Layer_14 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S16 to Sand_Layer_15 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S17 to Sand_Layer_16 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S18 to Sand_Layer_17 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S19 to Sand_Layer_18 suspended.
#
# Time = 2019-03-06 08:30
# Sand_Placement_S20 to Sand_Layer_19 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S01_B01 to Armour_Layer_00 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S02_B01 to Armour_Layer_01 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S03_B01 to Armour_Layer_02 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S04_B01 to Armour_Layer_03 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S05_B01 to Armour_Layer_04 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S06_B01 to Armour_Layer_05 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S07_B01 to Armour_Layer_06 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S08_B01 to Armour_Layer_07 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S09_B01 to Armour_Layer_08 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S10_B01 to Armour_Layer_09 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S11_B01 to Armour_Layer_10 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S12_B01 to Armour_Layer_11 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S13_B01 to Armour_Layer_12 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S14_B01 to Armour_Layer_13 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S15_B01 to Armour_Layer_14 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S16_B01 to Armour_Layer_15 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S17_B01 to Armour_Layer_16 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S18_B01 to Armour_Layer_17 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S19_B01 to Armour_Layer_18 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S20_B01 to Armour_Layer_19 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S01_B02 to Armour_Layer_00 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S02_B02 to Armour_Layer_01 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S03_B02 to Armour_Layer_02 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S04_B02 to Armour_Layer_03 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S05_B02 to Armour_Layer_04 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S06_B02 to Armour_Layer_05 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S07_B02 to Armour_Layer_06 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S08_B02 to Armour_Layer_07 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S09_B02 to Armour_Layer_08 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S10_B02 to Armour_Layer_09 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S11_B02 to Armour_Layer_10 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S12_B02 to Armour_Layer_11 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S13_B02 to Armour_Layer_12 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S14_B02 to Armour_Layer_13 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S15_B02 to Armour_Layer_14 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S16_B02 to Armour_Layer_15 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S17_B02 to Armour_Layer_16 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S18_B02 to Armour_Layer_17 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S19_B02 to Armour_Layer_18 suspended.
#
# Time = 2019-03-06 08:30
# Armour_Placement_S20_B02 to Armour_Layer_19 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S01_B01 to Levvel_Layer_00 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S02_B01 to Levvel_Layer_01 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S03_B01 to Levvel_Layer_02 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S04_B01 to Levvel_Layer_03 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S05_B01 to Levvel_Layer_04 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S06_B01 to Levvel_Layer_05 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S07_B01 to Levvel_Layer_06 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S08_B01 to Levvel_Layer_07 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S09_B01 to Levvel_Layer_08 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S10_B01 to Levvel_Layer_09 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S11_B01 to Levvel_Layer_10 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S12_B01 to Levvel_Layer_11 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S13_B01 to Levvel_Layer_12 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S14_B01 to Levvel_Layer_13 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S15_B01 to Levvel_Layer_14 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S16_B01 to Levvel_Layer_15 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S17_B01 to Levvel_Layer_16 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S18_B01 to Levvel_Layer_17 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S19_B01 to Levvel_Layer_18 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S20_B01 to Levvel_Layer_19 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S01_B02 to Levvel_Layer_00 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S02_B02 to Levvel_Layer_01 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S03_B02 to Levvel_Layer_02 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S04_B02 to Levvel_Layer_03 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S05_B02 to Levvel_Layer_04 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S06_B02 to Levvel_Layer_05 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S07_B02 to Levvel_Layer_06 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S08_B02 to Levvel_Layer_07 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S09_B02 to Levvel_Layer_08 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S10_B02 to Levvel_Layer_09 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S11_B02 to Levvel_Layer_10 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S12_B02 to Levvel_Layer_11 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S13_B02 to Levvel_Layer_12 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S14_B02 to Levvel_Layer_13 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S15_B02 to Levvel_Layer_14 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S16_B02 to Levvel_Layer_15 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S17_B02 to Levvel_Layer_16 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S18_B02 to Levvel_Layer_17 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S19_B02 to Levvel_Layer_18 suspended.
#
# Time = 2019-03-06 08:30
# Levvel_Placement_S20_B02 to Levvel_Layer_19 suspended.
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-06 23:30
# Start condition is satisfied, Clay_Placement_S02_B01 transporting from Clay_Stock to Clay_Layer_01 started.
#
# Time = 2019-03-06 23:30
# Start condition is satisfied, Clay_Placement_S02_B02 transporting from Clay_Stock to Clay_Layer_01 started.
#
# Time = 2019-03-06 23:30
# Start condition is satisfied, Sand_Placement_S01 transporting from Sand_Stock to Sand_Layer_00 started.
#
# Time = 2019-03-06 23:36
# Stop condition is satisfied, Clay_Placement_S01_B01 transporting from Clay_Stock to Clay_Layer_00 completed.
#
# Time = 2019-03-06 23:49
# Stop condition is satisfied, Clay_Placement_S01_B02 transporting from Clay_Stock to Clay_Layer_00 completed.
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-07 15:16
# Stop condition is satisfied, Clay_Placement_S02_B02 transporting from Clay_Stock to Clay_Layer_01 completed.
#
# Time = 2019-03-07 15:29
# Stop condition is satisfied, Clay_Placement_S02_B01 transporting from Clay_Stock to Clay_Layer_01 completed.
#
# Time = 2019-03-07 15:30
# Start condition is satisfied, Clay_Placement_S03_B01 transporting from Clay_Stock to Clay_Layer_02 started.
#
# Time = 2019-03-07 15:30
# Start condition is satisfied, Clay_Placement_S03_B02 transporting from Clay_Stock to Clay_Layer_02 started.
#
# Time = 2019-03-08 01:24
# Stop condition is satisfied, Sand_Placement_S01 transporting from Sand_Stock to Sand_Layer_00 completed.
#
# Time = 2019-03-08 01:30
# Start condition is satisfied, Sand_Placement_S02 transporting from Sand_Stock to Sand_Layer_01 started.
#
# Time = 2019-03-08 01:30
# Start condition is satisfied, Armour_Placement_S01_B01 transporting from Armour_Stock to Armour_Layer_00 started.
# Nothing to move
#
# Time = 2019-03-08 01:30
# Start condition is satisfied, Armour_Placement_S01_B02 transporting from Armour_Stock to Armour_Layer_00 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-08 07:30
# Start condition is satisfied, Clay_Placement_S04_B01 transporting from Clay_Stock to Clay_Layer_03 started.
#
# Time = 2019-03-08 07:30
# Start condition is satisfied, Clay_Placement_S04_B02 transporting from Clay_Stock to Clay_Layer_03 started.
#
# Time = 2019-03-08 07:43
# Stop condition is satisfied, Clay_Placement_S03_B01 transporting from Clay_Stock to Clay_Layer_02 completed.
#
# Time = 2019-03-08 07:56
# Stop condition is satisfied, Clay_Placement_S03_B02 transporting from Clay_Stock to Clay_Layer_02 completed.
#
# Time = 2019-03-09 02:09
# Stop condition is satisfied, Sand_Placement_S02 transporting from Sand_Stock to Sand_Layer_01 completed.
#
# Time = 2019-03-09 02:30
# Start condition is satisfied, Sand_Placement_S03 transporting from Sand_Stock to Sand_Layer_02 started.
#
# Time = 2019-03-10 01:40
# Stop condition is satisfied, Sand_Placement_S03 transporting from Sand_Stock to Sand_Layer_02 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-15 23:29
# Stop condition is satisfied, Armour_Placement_S01_B01 transporting from Armour_Stock to Armour_Layer_00 completed.
#
# Time = 2019-03-15 23:30
# Start condition is satisfied, Armour_Placement_S02_B01 transporting from Armour_Stock to Armour_Layer_01 started.
#
# Time = 2019-03-15 23:30
# Start condition is satisfied, Armour_Placement_S02_B02 transporting from Armour_Stock to Armour_Layer_01 started.
#
# Time = 2019-03-15 23:30
# Start condition is satisfied, Levvel_Placement_S01_B01 transporting from Levvel_Stock to Levvel_Layer_00 started.
#
# Time = 2019-03-15 23:30
# Start condition is satisfied, Levvel_Placement_S01_B02 transporting from Levvel_Stock to Levvel_Layer_00 started.
#
# Time = 2019-03-15 23:34
# Stop condition is satisfied, Armour_Placement_S01_B02 transporting from Armour_Stock to Armour_Layer_00 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-16 22:25
# Stop condition is satisfied, Clay_Placement_S04_B01 transporting from Clay_Stock to Clay_Layer_03 completed.
#
# Time = 2019-03-16 22:30
# Start condition is satisfied, Clay_Placement_S05_B01 transporting from Clay_Stock to Clay_Layer_04 started.
# Nothing to move
#
# Time = 2019-03-16 22:30
# Start condition is satisfied, Clay_Placement_S05_B02 transporting from Clay_Stock to Clay_Layer_04 started.
#
# Time = 2019-03-16 22:30
# Start condition is satisfied, Sand_Placement_S04 transporting from Sand_Stock to Sand_Layer_03 started.
#
# Time = 2019-03-16 22:30
# Stop condition is satisfied, Clay_Placement_S04_B02 transporting from Clay_Stock to Clay_Layer_03 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-17 20:14
# Stop condition is satisfied, Sand_Placement_S04 transporting from Sand_Stock to Sand_Layer_03 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-24 12:19
# Stop condition is satisfied, Armour_Placement_S02_B01 transporting from Armour_Stock to Armour_Layer_01 completed.
# Nothing to move
#
# Time = 2019-03-24 12:30
# Start condition is satisfied, Armour_Placement_S03_B01 transporting from Armour_Stock to Armour_Layer_02 started.
#
# Time = 2019-03-24 12:30
# Start condition is satisfied, Armour_Placement_S03_B02 transporting from Armour_Stock to Armour_Layer_02 started.
#
# Time = 2019-03-24 12:44
# Stop condition is satisfied, Armour_Placement_S02_B02 transporting from Armour_Stock to Armour_Layer_01 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-27 09:21
# Stop condition is satisfied, Levvel_Placement_S01_B01 transporting from Levvel_Stock to Levvel_Layer_00 completed.
#
# Time = 2019-03-27 09:22
# Stop condition is satisfied, Levvel_Placement_S01_B02 transporting from Levvel_Stock to Levvel_Layer_00 completed.
#
# Time = 2019-03-27 09:30
# Start condition is satisfied, Levvel_Placement_S02_B01 transporting from Levvel_Stock to Levvel_Layer_01 started.
#
# Time = 2019-03-27 09:30
# Start condition is satisfied, Levvel_Placement_S02_B02 transporting from Levvel_Stock to Levvel_Layer_01 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-28 04:30
# Start condition is satisfied, Clay_Placement_S06_B01 transporting from Clay_Stock to Clay_Layer_05 started.
# Nothing to move
#
# Time = 2019-03-28 04:30
# Start condition is satisfied, Clay_Placement_S06_B02 transporting from Clay_Stock to Clay_Layer_05 started.
#
# Time = 2019-03-28 04:30
# Start condition is satisfied, Sand_Placement_S05 transporting from Sand_Stock to Sand_Layer_04 started.
#
# Time = 2019-03-28 04:42
# Stop condition is satisfied, Clay_Placement_S05_B02 transporting from Clay_Stock to Clay_Layer_04 completed.
#
# Time = 2019-03-28 04:46
# Stop condition is satisfied, Clay_Placement_S05_B01 transporting from Clay_Stock to Clay_Layer_04 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-03-29 00:52
# Stop condition is satisfied, Sand_Placement_S05 transporting from Sand_Stock to Sand_Layer_04 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-04-03 06:08
# Stop condition is satisfied, Armour_Placement_S03_B01 transporting from Armour_Stock to Armour_Layer_02 completed.
#
# Time = 2019-04-03 06:17
# Stop condition is satisfied, Armour_Placement_S03_B02 transporting from Armour_Stock to Armour_Layer_02 completed.
#
# Time = 2019-04-03 06:30
# Start condition is satisfied, Armour_Placement_S04_B01 transporting from Armour_Stock to Armour_Layer_03 started.
# Nothing to move
#
# Time = 2019-04-03 06:30
# Start condition is satisfied, Armour_Placement_S04_B02 transporting from Armour_Stock to Armour_Layer_03 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-04-07 20:25
# Stop condition is satisfied, Levvel_Placement_S02_B01 transporting from Levvel_Stock to Levvel_Layer_01 completed.
# Nothing to move
#
# Time = 2019-04-07 20:30
# Start condition is satisfied, Levvel_Placement_S03_B01 transporting from Levvel_Stock to Levvel_Layer_02 started.
#
# Time = 2019-04-07 20:30
# Start condition is satisfied, Levvel_Placement_S03_B02 transporting from Levvel_Stock to Levvel_Layer_02 started.
# Nothing to move
#
# Time = 2019-04-07 20:32
# Stop condition is satisfied, Levvel_Placement_S02_B02 transporting from Levvel_Stock to Levvel_Layer_01 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-04-08 19:28
# Stop condition is satisfied, Clay_Placement_S06_B02 transporting from Clay_Stock to Clay_Layer_05 completed.
#
# Time = 2019-04-08 19:30
# Start condition is satisfied, Clay_Placement_S07_B01 transporting from Clay_Stock to Clay_Layer_06 started.
#
# Time = 2019-04-08 19:30
# Start condition is satisfied, Clay_Placement_S07_B02 transporting from Clay_Stock to Clay_Layer_06 started.
# Nothing to move
#
# Time = 2019-04-08 19:30
# Start condition is satisfied, Sand_Placement_S06 transporting from Sand_Stock to Sand_Layer_05 started.
#
# Time = 2019-04-08 19:47
# Stop condition is satisfied, Clay_Placement_S06_B01 transporting from Clay_Stock to Clay_Layer_05 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-04-09 14:35
# Stop condition is satisfied, Sand_Placement_S06 transporting from Sand_Stock to Sand_Layer_05 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-04-11 02:06
# Stop condition is satisfied, Armour_Placement_S04_B02 transporting from Armour_Stock to Armour_Layer_03 completed.
#
# Time = 2019-04-11 02:10
# Stop condition is satisfied, Armour_Placement_S04_B01 transporting from Armour_Stock to Armour_Layer_03 completed.
#
# Time = 2019-04-11 02:30
# Start condition is satisfied, Armour_Placement_S05_B01 transporting from Armour_Stock to Armour_Layer_04 started.
#
# Time = 2019-04-11 02:30
# Start condition is satisfied, Armour_Placement_S05_B02 transporting from Armour_Stock to Armour_Layer_04 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-04-18 04:45
# Stop condition is satisfied, Levvel_Placement_S03_B01 transporting from Levvel_Stock to Levvel_Layer_02 completed.
# Nothing to move
#
# Time = 2019-04-18 05:11
# Stop condition is satisfied, Levvel_Placement_S03_B02 transporting from Levvel_Stock to Levvel_Layer_02 completed.
#
# Time = 2019-04-18 05:30
# Start condition is satisfied, Levvel_Placement_S04_B01 transporting from Levvel_Stock to Levvel_Layer_03 started.
# Nothing to move
#
# Time = 2019-04-18 05:30
# Start condition is satisfied, Levvel_Placement_S04_B02 transporting from Levvel_Stock to Levvel_Layer_03 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-04-20 09:58
# Stop condition is satisfied, Clay_Placement_S07_B01 transporting from Clay_Stock to Clay_Layer_06 completed.
#
# Time = 2019-04-20 10:19
# Stop condition is satisfied, Clay_Placement_S07_B02 transporting from Clay_Stock to Clay_Layer_06 completed.
#
# Time = 2019-04-20 10:30
# Start condition is satisfied, Clay_Placement_S08_B01 transporting from Clay_Stock to Clay_Layer_07 started.
# Nothing to move
#
# Time = 2019-04-20 10:30
# Start condition is satisfied, Clay_Placement_S08_B02 transporting from Clay_Stock to Clay_Layer_07 started.
#
# Time = 2019-04-20 10:30
# Start condition is satisfied, Sand_Placement_S07 transporting from Sand_Stock to Sand_Layer_06 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-04-20 17:44
# Stop condition is satisfied, Armour_Placement_S05_B02 transporting from Armour_Stock to Armour_Layer_04 completed.
#
# Time = 2019-04-20 18:10
# Stop condition is satisfied, Armour_Placement_S05_B01 transporting from Armour_Stock to Armour_Layer_04 completed.
#
# Time = 2019-04-20 18:30
# Start condition is satisfied, Armour_Placement_S06_B01 transporting from Armour_Stock to Armour_Layer_05 started.
#
# Time = 2019-04-20 18:30
# Start condition is satisfied, Armour_Placement_S06_B02 transporting from Armour_Stock to Armour_Layer_05 started.
#
# Time = 2019-04-21 04:25
# Stop condition is satisfied, Sand_Placement_S07 transporting from Sand_Stock to Sand_Layer_06 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-04-26 15:30
# Start condition is satisfied, Levvel_Placement_S05_B01 transporting from Levvel_Stock to Levvel_Layer_04 started.
#
# Time = 2019-04-26 15:30
# Start condition is satisfied, Levvel_Placement_S05_B02 transporting from Levvel_Stock to Levvel_Layer_04 started.
#
# Time = 2019-04-26 15:35
# Stop condition is satisfied, Levvel_Placement_S04_B02 transporting from Levvel_Stock to Levvel_Layer_03 completed.
#
# Time = 2019-04-26 15:54
# Stop condition is satisfied, Levvel_Placement_S04_B01 transporting from Levvel_Stock to Levvel_Layer_03 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-05-01 13:30
# Start condition is satisfied, Clay_Placement_S09_B01 transporting from Clay_Stock to Clay_Layer_08 started.
# Nothing to move
#
# Time = 2019-05-01 13:30
# Start condition is satisfied, Clay_Placement_S09_B02 transporting from Clay_Stock to Clay_Layer_08 started.
#
# Time = 2019-05-01 13:30
# Start condition is satisfied, Sand_Placement_S08 transporting from Sand_Stock to Sand_Layer_07 started.
#
# Time = 2019-05-01 13:37
# Stop condition is satisfied, Clay_Placement_S08_B01 transporting from Clay_Stock to Clay_Layer_07 completed.
#
# Time = 2019-05-01 13:54
# Stop condition is satisfied, Clay_Placement_S08_B02 transporting from Clay_Stock to Clay_Layer_07 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-05-02 06:23
# Stop condition is satisfied, Sand_Placement_S08 transporting from Sand_Stock to Sand_Layer_07 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-05-03 10:30
# Start condition is satisfied, Armour_Placement_S07_B01 transporting from Armour_Stock to Armour_Layer_06 started.
# Nothing to move
#
# Time = 2019-05-03 10:30
# Start condition is satisfied, Armour_Placement_S07_B02 transporting from Armour_Stock to Armour_Layer_06 started.
#
# Time = 2019-05-03 10:33
# Stop condition is satisfied, Armour_Placement_S06_B02 transporting from Armour_Stock to Armour_Layer_05 completed.
#
# Time = 2019-05-03 10:57
# Stop condition is satisfied, Armour_Placement_S06_B01 transporting from Armour_Stock to Armour_Layer_05 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-05-04 14:30
# Start condition is satisfied, Levvel_Placement_S06_B01 transporting from Levvel_Stock to Levvel_Layer_05 started.
# Nothing to move
#
# Time = 2019-05-04 14:30
# Start condition is satisfied, Levvel_Placement_S06_B02 transporting from Levvel_Stock to Levvel_Layer_05 started.
#
# Time = 2019-05-04 14:42
# Stop condition is satisfied, Levvel_Placement_S05_B02 transporting from Levvel_Stock to Levvel_Layer_04 completed.
#
# Time = 2019-05-04 14:50
# Stop condition is satisfied, Levvel_Placement_S05_B01 transporting from Levvel_Stock to Levvel_Layer_04 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-05-11 20:24
# Stop condition is satisfied, Clay_Placement_S09_B02 transporting from Clay_Stock to Clay_Layer_08 completed.
#
# Time = 2019-05-11 20:30
# Start condition is satisfied, Clay_Placement_S10_B01 transporting from Clay_Stock to Clay_Layer_09 started.
#
# Time = 2019-05-11 20:30
# Start condition is satisfied, Clay_Placement_S10_B02 transporting from Clay_Stock to Clay_Layer_09 started.
#
# Time = 2019-05-11 20:30
# Start condition is satisfied, Sand_Placement_S09 transporting from Sand_Stock to Sand_Layer_08 started.
#
# Time = 2019-05-11 20:41
# Stop condition is satisfied, Clay_Placement_S09_B01 transporting from Clay_Stock to Clay_Layer_08 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-05-12 12:30
# Stop condition is satisfied, Sand_Placement_S09 transporting from Sand_Stock to Sand_Layer_08 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-05-13 05:30
# Start condition is satisfied, Armour_Placement_S08_B01 transporting from Armour_Stock to Armour_Layer_07 started.
# Nothing to move
#
# Time = 2019-05-13 05:30
# Start condition is satisfied, Armour_Placement_S08_B02 transporting from Armour_Stock to Armour_Layer_07 started.
#
# Time = 2019-05-13 05:56
# Stop condition is satisfied, Armour_Placement_S07_B02 transporting from Armour_Stock to Armour_Layer_06 completed.
#
# Time = 2019-05-13 06:06
# Stop condition is satisfied, Armour_Placement_S07_B01 transporting from Armour_Stock to Armour_Layer_06 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-05-14 09:16
# Stop condition is satisfied, Levvel_Placement_S06_B01 transporting from Levvel_Stock to Levvel_Layer_05 completed.
#
# Time = 2019-05-14 09:30
# Start condition is satisfied, Levvel_Placement_S07_B01 transporting from Levvel_Stock to Levvel_Layer_06 started.
#
# Time = 2019-05-14 09:30
# Start condition is satisfied, Levvel_Placement_S07_B02 transporting from Levvel_Stock to Levvel_Layer_06 started.
#
# Time = 2019-05-14 09:43
# Stop condition is satisfied, Levvel_Placement_S06_B02 transporting from Levvel_Stock to Levvel_Layer_05 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-05-22 23:05
# Stop condition is satisfied, Clay_Placement_S10_B01 transporting from Clay_Stock to Clay_Layer_09 completed.
#
# Time = 2019-05-22 23:25
# ...
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-08-12 16:10
# Stop condition is satisfied, Armour_Placement_S16_B01 transporting from Armour_Stock to Armour_Layer_15 completed.
#
# Time = 2019-08-12 16:25
# Stop condition is satisfied, Armour_Placement_S16_B02 transporting from Armour_Stock to Armour_Layer_15 completed.
#
# Time = 2019-08-12 16:30
# Start condition is satisfied, Armour_Placement_S17_B01 transporting from Armour_Stock to Armour_Layer_16 started.
#
# Time = 2019-08-12 16:30
# Start condition is satisfied, Armour_Placement_S17_B02 transporting from Armour_Stock to Armour_Layer_16 started.
# Nothing to move
#
# Time = 2019-08-12 16:30
# Start condition is satisfied, Levvel_Placement_S16_B01 transporting from Levvel_Stock to Levvel_Layer_15 started.
#
# Time = 2019-08-12 16:30
# Start condition is satisfied, Levvel_Placement_S16_B02 transporting from Levvel_Stock to Levvel_Layer_15 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-08-20 20:30
# Start condition is satisfied, Clay_Placement_S20_B01 transporting from Clay_Stock to Clay_Layer_19 started.
#
# Time = 2019-08-20 20:30
# Start condition is satisfied, Clay_Placement_S20_B02 transporting from Clay_Stock to Clay_Layer_19 started.
#
# Time = 2019-08-20 20:30
# Start condition is satisfied, Sand_Placement_S19 transporting from Sand_Stock to Sand_Layer_18 started.
#
# Time = 2019-08-20 20:38
# Stop condition is satisfied, Clay_Placement_S19_B01 transporting from Clay_Stock to Clay_Layer_18 completed.
# Nothing to move
#
# Time = 2019-08-20 20:59
# Stop condition is satisfied, Clay_Placement_S19_B02 transporting from Clay_Stock to Clay_Layer_18 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-08-21 16:00
# Stop condition is satisfied, Sand_Placement_S19 transporting from Sand_Stock to Sand_Layer_18 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-08-22 14:26
# Stop condition is satisfied, Armour_Placement_S17_B01 transporting from Armour_Stock to Armour_Layer_16 completed.
#
# Time = 2019-08-22 14:30
# Start condition is satisfied, Armour_Placement_S18_B01 transporting from Armour_Stock to Armour_Layer_17 started.
#
# Time = 2019-08-22 14:30
# Start condition is satisfied, Armour_Placement_S18_B02 transporting from Armour_Stock to Armour_Layer_17 started.
#
# Time = 2019-08-22 14:44
# Stop condition is satisfied, Armour_Placement_S17_B02 transporting from Armour_Stock to Armour_Layer_16 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-08-24 08:58
# Stop condition is satisfied, Levvel_Placement_S16_B01 transporting from Levvel_Stock to Levvel_Layer_15 completed.
#
# Time = 2019-08-24 09:20
# Stop condition is satisfied, Levvel_Placement_S16_B02 transporting from Levvel_Stock to Levvel_Layer_15 completed.
#
# Time = 2019-08-24 09:30
# Start condition is satisfied, Levvel_Placement_S17_B01 transporting from Levvel_Stock to Levvel_Layer_16 started.
# Nothing to move
#
# Time = 2019-08-24 09:30
# Start condition is satisfied, Levvel_Placement_S17_B02 transporting from Levvel_Stock to Levvel_Layer_16 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-08-26 06:24
# Stop condition is satisfied, Clay_Placement_S20_B01 transporting from Clay_Stock to Clay_Layer_19 completed.
#
# Time = 2019-08-26 06:30
# Start condition is satisfied, Sand_Placement_S20 transporting from Sand_Stock to Sand_Layer_19 started.
#
# Time = 2019-08-26 06:46
# Stop condition is satisfied, Clay_Placement_S20_B02 transporting from Clay_Stock to Clay_Layer_19 completed.
#
# Time = 2019-08-27 03:18
# Stop condition is satisfied, Sand_Placement_S20 transporting from Sand_Stock to Sand_Layer_19 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-08-29 22:58
# Stop condition is satisfied, Armour_Placement_S18_B02 transporting from Armour_Stock to Armour_Layer_17 completed.
#
# Time = 2019-08-29 23:19
# Stop condition is satisfied, Armour_Placement_S18_B01 transporting from Armour_Stock to Armour_Layer_17 completed.
#
# Time = 2019-08-29 23:30
# Start condition is satisfied, Armour_Placement_S19_B01 transporting from Armour_Stock to Armour_Layer_18 started.
#
# Time = 2019-08-29 23:30
# Start condition is satisfied, Armour_Placement_S19_B02 transporting from Armour_Stock to Armour_Layer_18 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-09-01 11:30
# Start condition is satisfied, Levvel_Placement_S18_B01 transporting from Levvel_Stock to Levvel_Layer_17 started.
# Nothing to move
#
# Time = 2019-09-01 11:30
# Start condition is satisfied, Levvel_Placement_S18_B02 transporting from Levvel_Stock to Levvel_Layer_17 started.
#
# Time = 2019-09-01 11:34
# Stop condition is satisfied, Levvel_Placement_S17_B01 transporting from Levvel_Stock to Levvel_Layer_16 completed.
#
# Time = 2019-09-01 11:55
# Stop condition is satisfied, Levvel_Placement_S17_B02 transporting from Levvel_Stock to Levvel_Layer_16 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-09-03 23:54
# Stop condition is satisfied, Armour_Placement_S19_B02 transporting from Armour_Stock to Armour_Layer_18 completed.
#
# Time = 2019-09-04 00:24
# Stop condition is satisfied, Armour_Placement_S19_B01 transporting from Armour_Stock to Armour_Layer_18 completed.
#
# Time = 2019-09-04 00:30
# Start condition is satisfied, Armour_Placement_S20_B01 transporting from Armour_Stock to Armour_Layer_19 started.
#
# Time = 2019-09-04 00:30
# Start condition is satisfied, Armour_Placement_S20_B02 transporting from Armour_Stock to Armour_Layer_19 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-09-05 12:22
# Stop condition is satisfied, Levvel_Placement_S18_B01 transporting from Levvel_Stock to Levvel_Layer_17 completed.
#
# Time = 2019-09-05 12:25
# Stop condition is satisfied, Levvel_Placement_S18_B02 transporting from Levvel_Stock to Levvel_Layer_17 completed.
#
# Time = 2019-09-05 12:30
# Start condition is satisfied, Levvel_Placement_S19_B01 transporting from Levvel_Stock to Levvel_Layer_18 started.
# Nothing to move
#
# Time = 2019-09-05 12:30
# Start condition is satisfied, Levvel_Placement_S19_B02 transporting from Levvel_Stock to Levvel_Layer_18 started.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-09-10 00:27
# Stop condition is satisfied, Armour_Placement_S20_B02 transporting from Armour_Stock to Armour_Layer_19 completed.
#
# Time = 2019-09-10 00:37
# Stop condition is satisfied, Armour_Placement_S20_B01 transporting from Armour_Stock to Armour_Layer_19 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-09-11 00:09
# Stop condition is satisfied, Levvel_Placement_S19_B02 transporting from Levvel_Stock to Levvel_Layer_18 completed.
#
# Time = 2019-09-11 00:30
# Start condition is satisfied, Levvel_Placement_S20_B01 transporting from Levvel_Stock to Levvel_Layer_19 started.
#
# Time = 2019-09-11 00:30
# Start condition is satisfied, Levvel_Placement_S20_B02 transporting from Levvel_Stock to Levvel_Layer_19 started.
#
# Time = 2019-09-11 00:39
# Stop condition is satisfied, Levvel_Placement_S19_B01 transporting from Levvel_Stock to Levvel_Layer_18 completed.
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
#
# Time = 2019-09-13 23:40
# Stop condition is satisfied, Levvel_Placement_S20_B02 transporting from Levvel_Stock to Levvel_Layer_19 completed.
#
# Time = 2019-09-13 23:51
# Stop condition is satisfied, Levvel_Placement_S20_B01 transporting from Levvel_Stock to Levvel_Layer_19 completed.
#
# *** Activity finished in 191 days, 14:21:35 ***

# %% [markdown]
# ### 3. Postprocessing

# %% [markdown]
# #### Vessel planning

# %%
vessels = [gantry_crane, 
           installation_crane, 
           transport_barge_01, 
           transport_barge_02, 
           hopper]

activities = ['loading', 'unloading', 'sailing full', 'sailing empty', 'processing']
colors = {0:'rgb(55,126,184)', 1:'rgb(255,150,0)', 2:'rgb(98, 192, 122)', 3:'rgb(98, 141, 122)', 4:'rgb(110, 141, 122)'}

plot.vessel_planning(vessels, activities, colors)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="fa8b6451-adc6-410f-93a0-edabbd201b81" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fa8b6451-adc6-410f-93a0-edabbd201b81", [{"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(55,126,184)", "width": 10}, "mode": "lines", "name": "loading", "x": ["2019-03-06 08:30:08", "2019-03-06 08:30:08", "2019-03-06 11:16:48", "2019-03-06 11:16:48", "2019-03-06 11:16:48", "2019-03-06 14:03:28", "2019-03-06 14:03:28", "2019-03-06 16:50:08", "2019-03-06 16:50:08", "2019-03-06 16:50:08", "2019-03-06 19:36:48", "2019-03-06 19:36:48", "2019-03-06 22:23:28", "2019-03-06 22:23:28", "2019-03-06 22:23:28", "2019-03-07 02:41:40.860315", "2019-03-07 02:41:40.860315", "2019-03-07 05:28:20.860315", "2019-03-07 05:28:20.860315", "2019-03-07 05:28:20.860315", "2019-03-07 08:15:00.860315", "2019-03-07 08:15:00.860315", "2019-03-07 11:01:40.860315", "2019-03-07 11:01:40.860315", "2019-03-07 11:01:40.860315", "2019-03-07 16:04:11.646641", "2019-03-07 16:04:11.646641", "2019-03-07 18:50:51.646641", "2019-03-07 18:50:51.646641", "2019-03-07 18:50:51.646641", "2019-03-07 21:38:34.735775", "2019-03-07 21:38:34.735775", "2019-03-08 00:25:14.735775", "2019-03-08 00:25:14.735775", "2019-03-08 00:25:14.735775", "2019-03-08 03:11:54.735775", "2019-03-08 03:11:54.735775", "2019-03-08 05:58:34.735775", "2019-03-08 05:58:34.735775", "2019-03-08 05:58:34.735775", "2019-03-09 10:19:16.570958", "2019-03-09 10:19:16.570958", "2019-03-09 13:05:56.570958", "2019-03-09 13:05:56.570958", "2019-03-09 13:05:56.570958", "2019-03-10 23:42:04.647856", "2019-03-10 23:42:04.647856", "2019-03-11 02:28:44.647856", "2019-03-11 02:28:44.647856", "2019-03-11 02:28:44.647856", "2019-03-12 07:55:22.807454", "2019-03-12 07:55:22.807454", "2019-03-12 10:42:02.807454", "2019-03-12 10:42:02.807454", "2019-03-12 10:42:02.807454", "2019-03-13 21:36:38.296555", "2019-03-13 21:36:38.296555", "2019-03-14 00:23:18.296555", "2019-03-14 00:23:18.296555", "2019-03-14 00:23:18.296555", "2019-03-16 09:09:18.035750", "2019-03-16 09:09:18.035750", "2019-03-16 11:55:58.035750", "2019-03-16 11:55:58.035750", "2019-03-16 11:55:58.035750", "2019-03-18 07:57:00.101621", "2019-03-18 07:57:00.101621", "2019-03-18 10:43:40.101621", "2019-03-18 10:43:40.101621", "2019-03-18 10:43:40.101621", "2019-03-19 14:05:35.383136", "2019-03-19 14:05:35.383136", "2019-03-19 16:52:15.383136", "2019-03-19 16:52:15.383136", "2019-03-19 16:52:15.383136", "2019-03-21 03:05:28.563061", "2019-03-21 03:05:28.563061", "2019-03-21 05:52:08.563061", "2019-03-21 05:52:08.563061", "2019-03-21 05:52:08.563061", "2019-03-22 10:31:03.098362", "2019-03-22 10:31:03.098362", "2019-03-22 13:17:43.098362", "2019-03-22 13:17:43.098362", "2019-03-22 13:17:43.098362", "2019-03-23 16:39:38.379878", "2019-03-23 16:39:38.379878", "2019-03-23 19:26:18.379878", "2019-03-23 19:26:18.379878", "2019-03-23 19:26:18.379878", "2019-03-25 05:39:31.559802", "2019-03-25 05:39:31.559802", "2019-03-25 08:26:11.559802", "2019-03-25 08:26:11.559802", "2019-03-25 08:26:11.559802", "2019-03-26 13:05:06.095104", "2019-03-26 13:05:06.095104", "2019-03-26 15:51:46.095104", "2019-03-26 15:51:46.095104", "2019-03-26 15:51:46.095104", "2019-03-27 19:32:11.468285", "2019-03-27 19:32:11.468285", "2019-03-27 22:18:51.468285", "2019-03-27 22:18:51.468285", "2019-03-27 22:18:51.468285", "2019-03-29 17:57:12.909863", "2019-03-29 17:57:12.909863", "2019-03-29 20:43:52.909863", "2019-03-29 20:43:52.909863", "2019-03-29 20:43:52.909863", "2019-03-30 23:42:54.441919", "2019-03-30 23:42:54.441919", "2019-03-31 03:29:34.441919", "2019-03-31 03:29:34.441919", "2019-03-31 03:29:34.441919", "2019-04-01 13:39:51.049412", "2019-04-01 13:39:51.049412", "2019-04-01 16:26:31.049412", "2019-04-01 16:26:31.049412", "2019-04-01 16:26:31.049412", "2019-04-02 21:15:10.282384", "2019-04-02  ...

# %% [markdown]
# #### KML visualisation

# %%
plot.vessel_kml(my_env, vessels[2:3], stepsize = 3600)

# %%
# open the file
if platform.system():
    # !start ./vessel_movements.kml
else:
    # !start explorer ./vessel_movements.kml
