# %% [markdown]
# ## Example 04 - Building a Layered Dike

# %% [markdown]
# **Example description:** Example of a construction challenge, with four separate activites, where each activity depends on the progress of the other activities.

# %% [markdown]
# * [**0. Import required libraries:**](#0.-Import-required-libraries)<br>
# * [**1. Define work method:**](#1.-Define-work-method)<br>
#    * [**1.1 Sites:**](#1.1-Define-the-project-sites)<br>
#    * [**1.2 Equipment:**](#1.2-Define-the-project-equipment)<br>
#    * [**1.3 Activities:**](#1.3-Define-the-activity)<br>
# * [**2. Run the simulation:**](#2.-Run-the-simulation)<br>
# * [**3. Post processing:**](#3.-Postprocessing)<br>

# %% [markdown]
# ## 0. Import required libraries

# %%
# package(s) related to time, space and id
import datetime, time
import platform

# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy

# spatial libraries 
import shapely.geometry
from simplekml import Kml, Style

# package(s) for data handling
import numpy as np

# digital twin package
import digital_twin.core as core
import digital_twin.model as model
import digital_twin.plot as plot

# %%
# Create simulation environment
simulation_start = datetime.datetime.now()

my_env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
my_env.epoch = time.mktime(simulation_start.timetuple())

# %% [markdown]
# ## 1. Define work method

# %% [markdown]
# ### 1.1 Define the project sites
# You can specify a project site object by entering mix-ins:
#
#     core.Identifiable - enables you to give the object a name
#     core.Log - enables you to log all discrete events in which the object is involved
#     core.Locatable - enables you to add coordinates to extract distance information and visualize
#     core.HasContainer - enables you to add information on the material available at the site
#     core.HasResource - enables you to add information on serving equipment
#     core.HasWeather - enables you to add weather conditions

# %% [markdown]
# #### First create objects with the desired properties

# %%
Site = type('Site', (core.Identifiable, 
                     core.Log, 
                     core.Locatable, 
                     core.HasContainer, 
                     core.HasResource), {})

# %% [markdown]
# #### Next specify the properties for sites you wish to create

# %%
# origin sites data
data_stock_clay = {"env": my_env,
                   "name": "Clay_Stock",
                   "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000}

data_stock_sand = {"env": my_env,
                   "name": "Sand_Stock",
                   "geometry": shapely.geometry.Point(5.271417603333632, 52.9638452897506),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000}

data_stock_armour = {"env": my_env,
                   "name": "Armour_Stock",
                   "geometry": shapely.geometry.Point(5.919298185633251, 52.94239823421129),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000}

data_stock_levvel = {"env": my_env,
                   "name": "Levvel_Stock",
                   "geometry": shapely.geometry.Point(5.919298185633251, 52.94239823421129),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000}

# %%
# destination sites data

# nr of bins to use
site_count = 20

data_clay = {"start": [5.054676856441372, 52.94042293840172], # Den Oever (lon, lat)
             "stop": [5.294877712236641, 53.06686424241725], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Clay_Layer"}

data_sand = {"start": [5.052051052879287,52.9421894472733], # Den Oever (lon, lat)
             "stop": [5.292216781509101,53.06886359869087], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Sand_Layer"}

data_armour = {"start": [5.049510554598302,52.94393628899332], # Den Oever (lon, lat)
             "stop": [5.289636346490858,53.07053144816584], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Armour_Layer"}

data_levvel = {"start": [5.046556507026805,52.94579445406793], # Den Oever (lon, lat)
             "stop": [5.286775240694118,53.07264015015531], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Levvel_Layer"}

# %% [markdown]
# #### Finally create specific instances of the predefined objects with the specified properties

# %%
# create the site objects
stocks = []
for data in [data_stock_clay, data_stock_sand, data_stock_armour, data_stock_levvel]:
    stock = Site(**data)
    stocks.append(stock)

# %%
sites = []
for data_layer in [data_clay, data_sand, data_armour, data_levvel]:
    start = data_layer['start']
    stop = data_layer['stop']

    # generate the evenly spaced locations between the selected start and stop points
    lons = np.linspace(start[0], stop[0], num=site_count)
    lats = np.linspace(start[1], stop[1], num=site_count)

    # create a Site object for each location
    layer_sites = []
    for i in range(site_count):
        data_site = {"env": my_env,
                     "name": data_layer["name"] + '_' + format(i, '02.0f'),
                     "geometry": shapely.geometry.Point(lons[i], lats[i]),
                     "capacity": data_layer["capacity"]}
        site = Site(**data_site)
        layer_sites.append(site)
    sites.append(layer_sites)

# %% [markdown]
# ### 1.2 Define the project equipment
# You can specify a vessel object by entering mix-ins:
#
#     core.Identifiable - enables you to give the object a name
#     core.Log - enables you to log all discrete events in which the object is involved
#     core.ContainerDependentMovable - A moving container, so capacity and location
#     core.Processor - Allow for loading and unloading
#     core.HasResource - Add information on serving equipment
#     core.HasDepthRestriction - Add information on depth restriction

# %% [markdown]
# #### First create objects with the desired properties

# %%
TransportResource = type('TransportResource', 
                         (core.Identifiable, 
                          core.Log, 
                          core.ContainerDependentMovable, 
                          core.HasResource), {})

TransportProcessingResource = type('TransportProcessingResource', 
                                   (core.Identifiable, 
                                    core.Log, 
                                    core.ContainerDependentMovable, 
                                    core.Processor, 
                                    core.HasResource), {})

ProcessingResource = type('ProcessingResource', 
                          (core.Identifiable, 
                           core.Log, 
                           core.Processor, 
                           core.HasResource, 
                           core.Locatable), {})

# %% [markdown]
# #### Next specify the properties for vessel(s) you wish to create

# %%
# For more realistic simulation you might want to have speed dependent on the volume carried by the vessel
def compute_v_provider(v_empty, v_full):
    return lambda x: x * (v_full - v_empty) + v_empty

def compute_loading(rate):
    return lambda x: x / rate

def compute_unloading(rate):
    return lambda x: x / rate

# %%
# equipment information in database
data_gantry_crane = {"env": my_env,
                     "name": "Gantry crane",
                     "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                     "loading_func": compute_loading(0.1),                # Loading rate
                     "unloading_func": compute_unloading(0.1)}            # Unloading rate


data_installation_crane = {"env": my_env,
                           "name": "Installation crane",
                           "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                           "loading_func": compute_loading(0.5),                # Loading rate
                           "unloading_func": compute_unloading(0.5)}            # Unloading rate


data_transport_barge_01 = {"env": my_env,
                           "name": "Transport barge 01",
                           "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                           "capacity": 1_000,
                           "compute_v": compute_v_provider(v_empty=1.6, v_full=1)}

data_transport_barge_02 = {"env": my_env,
                           "name": "Transport barge 02",
                           "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                           "capacity": 1_000,
                           "compute_v": compute_v_provider(v_empty=1.6, v_full=1)}

# TSHD variables
data_hopper = {"env": my_env,                                       # The simpy environment 
               "name": "Hopper",                                    # Name
               "geometry": shapely.geometry.Point(5.070195628786471, 52.93917167503315),                      # It starts at the "from site"
               "loading_func": compute_loading(1.5),                # Loading rate
               "unloading_func": compute_unloading(1.5),            # Unloading rate
               "capacity": 1_000,                                   # Capacity of the hopper - "Beunvolume"
               "compute_v": compute_v_provider(2, 1.5)}             # Variable speed

# %% [markdown]
# #### Finally create specific instances of the predefined objects with the specified properties

# %%
# create the processing resources
gantry_crane = ProcessingResource(**data_gantry_crane)
installation_crane = ProcessingResource(**data_installation_crane)

# create the transport resources
transport_barge_01 = TransportResource(**data_transport_barge_01)
transport_barge_02 = TransportResource(**data_transport_barge_02)

# create the transport processing resource
hopper = TransportProcessingResource(**data_hopper)

# %% [markdown]
# ### 1.3 Define the activity
# As can be seen in the code fragment above, the Activity class takes the Simpy environment and a name as its constructor arguments. This is because it is defined as a mixin of the SimpyObject and Identifiable core classes. To construct an activity we also needed to define the origin, destination, loader, mover and unloader. Finally, we can optionally define conditions that need to be satisfied for the transportation of materials to take place. These are separated in __start_condition__, __stop_condition__ and __condition__ arguments:
# * __start_condition__: The activity will start as soon as this condition is satisfied. If this condition is not yet satisfied at the start of the simulation the activity will be suspended untill the condition is satisfied at a later time. Since we do not want any clay to be transported to the later sites if the previous site has not yet been completed, we define this condition as a start_condition.
# * __stop_condition__: After the activity has started (the start_condition was satisfied), it will regularly check if the stop_condition has been satisfied. If so, the activity is considered complete and will terminate. A simulation will not terminate untill all of its activities have been completed. By default (with stop_condition=None), the stop_condition is set to either the origin container being empty, or the destination container being full. This is sufficient in our case, so we do not specify a stop_condition.
# * __condition__: After the activity has started (the start_condition was satisfied) and as long as the stop_condition is not satisfied, the activity will continuously check whether this condition is satisfied. If so, it will complete exactly one transportation of materials (loading the mover at the origin and unloading the mover at the destination). If not, the activity will wait untill the condition is satisfied again. Defining such a condition allows for the activity to be temporarily halted, for example due to bad weather or other working conditions, and resuming at a later time when the problem preventing work has passed.
#
# All of these condition arguments take a "Condition" object. This object should have a "satisfied" method which returns a boolean indicating whether the condition is satsified or not. The digital twin package provides a LevelCondition, allowing you to quickly construct a condition which will check if an object extending HasContainer has a certain minimum and/or maximum level. It also provides an AndCondition and OrCondition which allow for combining other condition objects into a single condition. You can also provide your own "Condition" class, for example you could program a "Condition" class which depending on the time in the simulation (the .now fixture of the Simpy environment), returns whether the weather is good enough for work to take place:

# %%
activities = []

# %%
# define the sand layer Activities
clay_layer_index = 0
clay_sites = sites[clay_layer_index]
for i, clay_site in enumerate(clay_sites):
    for barge_index, transport_barge in enumerate([transport_barge_01, transport_barge_02]):
        # for the first site we do not need to define any condition
        condition = None if i == 0 else model.LevelCondition(container=clay_sites[i-1], min_level=data_clay["capacity"])
        activity = model.Activity(env=my_env,
                                  name="Clay_Placement_S" + format(i+1, '02.0f') + "_B" + format(barge_index + 1, '02.0f'),
                                  origin=stocks[clay_layer_index],
                                  destination=clay_site,
                                  loader=gantry_crane,
                                  mover=transport_barge,
                                  unloader=installation_crane,
                                  start_condition=condition)
        activities.append(activity)

# %%
# define the sand layer Activities
sand_layer_index = 1
sand_sites = sites[sand_layer_index]
for i, sand_site in enumerate(sand_sites):
    # for the first site we do not need to define a condition on the previous site
    prev_site_condition = model.TrueCondition() if i == 0 else model.LevelCondition(container=sand_sites[i-1], 
                                                                          min_level=sand_sites[i-1].container.capacity)
    prev_layer_sites = sites[clay_layer_index]
    prev_layer_condition = model.LevelCondition(prev_layer_sites[i], min_level=prev_layer_sites[i].container.capacity)
    start_condition = model.AndCondition([prev_site_condition, prev_layer_condition])
    activity = model.Activity(env=my_env,
                              name="Sand_Placement_S" + format(i+1, '02.0f'),
                              origin=stocks[sand_layer_index],
                              destination=sand_site,
                              loader=hopper,
                              mover=hopper,
                              unloader=hopper,
                              start_condition=start_condition)
    activities.append(activity)

# %%
# define the armour and level layer activities
layer_names = ["Armour_Placement", "Levvel_Placement"]
layer_indices = [2, 3]
for layer_index in layer_indices:
    for barge_index, transport_barge in enumerate([transport_barge_01, transport_barge_02]):
        layer_sites = sites[layer_index]
        for site_index, site in enumerate(layer_sites):
            # for the first site we do not need to define a condition on the previous site
            prev_site_condition = model.TrueCondition() if site_index == 0 else \
                model.LevelCondition(container=layer_sites[site_index-1], 
                                     min_level=layer_sites[site_index-1].container.capacity)
            
            prev_layer_sites = sites[layer_index - 1]
            prev_layer_condition = model.LevelCondition(container=prev_layer_sites[site_index],
                                                        min_level=prev_layer_sites[site_index].container.capacity)
            start_condition = model.AndCondition([prev_site_condition, prev_layer_condition])
            
            activity = model.Activity(env=my_env,
                                      name=layer_names[layer_index-2] + "_S" + format(site_index+1, '02.0f')
                                           + "_B" + format(barge_index+1, '02.0f'),
                                      origin=stocks[layer_index],
                                      destination=site,
                                      loader=gantry_crane,
                                      mover=transport_barge,
                                      unloader=installation_crane,
                                      start_condition=start_condition)
            activities.append(activity)

# %% [markdown]
# ### 2. Run the simulation

# %%
simulation_start = datetime.datetime.now()
my_env.epoch = time.mktime(simulation_start.timetuple())

my_env.run()

print("\n*** Installation of dike finished in {} ***".format(datetime.timedelta(seconds=int(my_env.now - my_env.epoch))))
# Out:
# T=1549055132.00 Start condition is satisfied, Clay_Placement_S01_B01 transporting from Clay_Stock to Clay_Layer_00 started
# T=1549055132.00 Start condition is satisfied, Clay_Placement_S01_B02 transporting from Clay_Stock to Clay_Layer_00 started
# T=1549055132.00 Clay_Placement_S02_B01 to Clay_Layer_01 suspended
# T=1549055132.00 Clay_Placement_S02_B02 to Clay_Layer_01 suspended
# T=1549055132.00 Clay_Placement_S03_B01 to Clay_Layer_02 suspended
# T=1549055132.00 Clay_Placement_S03_B02 to Clay_Layer_02 suspended
# T=1549055132.00 Clay_Placement_S04_B01 to Clay_Layer_03 suspended
# T=1549055132.00 Clay_Placement_S04_B02 to Clay_Layer_03 suspended
# T=1549055132.00 Clay_Placement_S05_B01 to Clay_Layer_04 suspended
# T=1549055132.00 Clay_Placement_S05_B02 to Clay_Layer_04 suspended
# T=1549055132.00 Clay_Placement_S06_B01 to Clay_Layer_05 suspended
# T=1549055132.00 Clay_Placement_S06_B02 to Clay_Layer_05 suspended
# T=1549055132.00 Clay_Placement_S07_B01 to Clay_Layer_06 suspended
# T=1549055132.00 Clay_Placement_S07_B02 to Clay_Layer_06 suspended
# T=1549055132.00 Clay_Placement_S08_B01 to Clay_Layer_07 suspended
# T=1549055132.00 Clay_Placement_S08_B02 to Clay_Layer_07 suspended
# T=1549055132.00 Clay_Placement_S09_B01 to Clay_Layer_08 suspended
# T=1549055132.00 Clay_Placement_S09_B02 to Clay_Layer_08 suspended
# T=1549055132.00 Clay_Placement_S10_B01 to Clay_Layer_09 suspended
# T=1549055132.00 Clay_Placement_S10_B02 to Clay_Layer_09 suspended
# T=1549055132.00 Clay_Placement_S11_B01 to Clay_Layer_10 suspended
# T=1549055132.00 Clay_Placement_S11_B02 to Clay_Layer_10 suspended
# T=1549055132.00 Clay_Placement_S12_B01 to Clay_Layer_11 suspended
# T=1549055132.00 Clay_Placement_S12_B02 to Clay_Layer_11 suspended
# T=1549055132.00 Clay_Placement_S13_B01 to Clay_Layer_12 suspended
# T=1549055132.00 Clay_Placement_S13_B02 to Clay_Layer_12 suspended
# T=1549055132.00 Clay_Placement_S14_B01 to Clay_Layer_13 suspended
# T=1549055132.00 Clay_Placement_S14_B02 to Clay_Layer_13 suspended
# T=1549055132.00 Clay_Placement_S15_B01 to Clay_Layer_14 suspended
# T=1549055132.00 Clay_Placement_S15_B02 to Clay_Layer_14 suspended
# T=1549055132.00 Clay_Placement_S16_B01 to Clay_Layer_15 suspended
# T=1549055132.00 Clay_Placement_S16_B02 to Clay_Layer_15 suspended
# T=1549055132.00 Clay_Placement_S17_B01 to Clay_Layer_16 suspended
# T=1549055132.00 Clay_Placement_S17_B02 to Clay_Layer_16 suspended
# T=1549055132.00 Clay_Placement_S18_B01 to Clay_Layer_17 suspended
# T=1549055132.00 Clay_Placement_S18_B02 to Clay_Layer_17 suspended
# T=1549055132.00 Clay_Placement_S19_B01 to Clay_Layer_18 suspended
# T=1549055132.00 Clay_Placement_S19_B02 to Clay_Layer_18 suspended
# T=1549055132.00 Clay_Placement_S20_B01 to Clay_Layer_19 suspended
# T=1549055132.00 Clay_Placement_S20_B02 to Clay_Layer_19 suspended
# T=1549055132.00 Sand_Placement_S01 to Sand_Layer_00 suspended
# T=1549055132.00 Sand_Placement_S02 to Sand_Layer_01 suspended
# T=1549055132.00 Sand_Placement_S03 to Sand_Layer_02 suspended
# T=1549055132.00 Sand_Placement_S04 to Sand_Layer_03 suspended
# T=1549055132.00 Sand_Placement_S05 to Sand_Layer_04 suspended
# T=1549055132.00 Sand_Placement_S06 to Sand_Layer_05 suspended
# T=1549055132.00 Sand_Placement_S07 to Sand_Layer_06 suspended
# T=1549055132.00 Sand_Placement_S08 to Sand_Layer_07 suspended
# T=1549055132.00 Sand_Placement_S09 to Sand_Layer_08 suspended
# T=1549055132.00 Sand_Placement_S10 to Sand_Layer_09 suspended
# T=1549055132.00 Sand_Placement_S11 to Sand_Layer_10 suspended
# T=1549055132.00 Sand_Placement_S12 to Sand_Layer_11 suspended
# T=1549055132.00 Sand_Placement_S13 to Sand_Layer_12 suspended
# T=1549055132.00 Sand_Placement_S14 to Sand_Layer_13 suspended
# T=1549055132.00 Sand_Placement_S15 to Sand_Layer_14 suspended
# T=1549055132.00 Sand_Placement_S16 to Sand_Layer_15 suspended
# T=1549055132.00 Sand_Placement_S17 to Sand_Layer_16 suspended
# T=1549055132.00 Sand_Placement_S18 to Sand_Layer_17 suspended
# T=1549055132.00 Sand_Placement_S19 to Sand_Layer_18 suspended
# T=1549055132.00 Sand_Placement_S20 to Sand_Layer_19 suspended
# T=1549055132.00 Armour_Placement_S01_B01 to Armour_Layer_00 suspended
# T=1549055132.00 Armour_Placement_S02_B01 to Armour_Layer_01 suspended
# T=1549055132.00 Armour_Placement_S03_B01 to Armour_Layer_02 suspended
# T=1549055132.00 Armour_Placement_S04_B01 to Armour_Layer_03 suspended
# T=1549055132.00 Armour_Placement_S05_B01 to Armour_Layer_04 suspended
# T=1549055132.00 Armour_Placement_S06_B01 to Armour_Layer_05 suspended
# T=1549055132.00 Armour_Placement_S07_B01 to Armour_Layer_06 suspended
# T=1549055132.00 Armour_Placement_S08_B01 to Armour_Layer_07 suspended
# T=1549055132.00 Armour_Placement_S09_B01 to Armour_Layer_08 suspended
# T=1549055132.00 Armour_Placement_S10_B01 to Armour_Layer_09 suspended
# T=1549055132.00 Armour_Placement_S11_B01 to Armour_Layer_10 suspended
# T=1549055132.00 Armour_Placement_S12_B01 to Armour_Layer_11 suspended
# T=1549055132.00 Armour_Placement_S13_B01 to Armour_Layer_12 suspended
# T=1549055132.00 Armour_Placement_S14_B01 to Armour_Layer_13 suspended
# T=1549055132.00 Armour_Placement_S15_B01 to Armour_Layer_14 suspended
# T=1549055132.00 Armour_Placement_S16_B01 to Armour_Layer_15 suspended
# T=1549055132.00 Armour_Placement_S17_B01 to Armour_Layer_16 suspended
# T=1549055132.00 Armour_Placement_S18_B01 to Armour_Layer_17 suspended
# T=1549055132.00 Armour_Placement_S19_B01 to Armour_Layer_18 suspended
# T=1549055132.00 Armour_Placement_S20_B01 to Armour_Layer_19 suspended
# T=1549055132.00 Armour_Placement_S01_B02 to Armour_Layer_00 suspended
# T=1549055132.00 Armour_Placement_S02_B02 to Armour_Layer_01 suspended
# T=1549055132.00 Armour_Placement_S03_B02 to Armour_Layer_02 suspended
# T=1549055132.00 Armour_Placement_S04_B02 to Armour_Layer_03 suspended
# T=1549055132.00 Armour_Placement_S05_B02 to Armour_Layer_04 suspended
# T=1549055132.00 Armour_Placement_S06_B02 to Armour_Layer_05 suspended
# T=1549055132.00 Armour_Placement_S07_B02 to Armour_Layer_06 suspended
# T=1549055132.00 Armour_Placement_S08_B02 to Armour_Layer_07 suspended
# T=1549055132.00 Armour_Placement_S09_B02 to Armour_Layer_08 suspended
# T=1549055132.00 Armour_Placement_S10_B02 to Armour_Layer_09 suspended
# T=1549055132.00 Armour_Placement_S11_B02 to Armour_Layer_10 suspended
# T=1549055132.00 Armour_Placement_S12_B02 to Armour_Layer_11 suspended
# T=1549055132.00 Armour_Placement_S13_B02 to Armour_Layer_12 suspended
# T=1549055132.00 Armour_Placement_S14_B02 to Armour_Layer_13 suspended
# T=1549055132.00 Armour_Placement_S15_B02 to Armour_Layer_14 suspended
# T=1549055132.00 Armour_Placement_S16_B02 to Armour_Layer_15 suspended
# T=1549055132.00 Armour_Placement_S17_B02 to Armour_Layer_16 suspended
# T=1549055132.00 Armour_Placement_S18_B02 to Armour_Layer_17 suspended
# T=1549055132.00 Armour_Placement_S19_B02 to Armour_Layer_18 suspended
# T=1549055132.00 Armour_Placement_S20_B02 to Armour_Layer_19 suspended
# T=1549055132.00 Levvel_Placement_S01_B01 to Levvel_Layer_00 suspended
# T=1549055132.00 Levvel_Placement_S02_B01 to Levvel_Layer_01 suspended
# T=1549055132.00 Levvel_Placement_S03_B01 to Levvel_Layer_02 suspended
# T=1549055132.00 Levvel_Placement_S04_B01 to Levvel_Layer_03 suspended
# T=1549055132.00 Levvel_Placement_S05_B01 to Levvel_Layer_04 suspended
# T=1549055132.00 Levvel_Placement_S06_B01 to Levvel_Layer_05 suspended
# T=1549055132.00 Levvel_Placement_S07_B01 to Levvel_Layer_06 suspended
# T=1549055132.00 Levvel_Placement_S08_B01 to Levvel_Layer_07 suspended
# T=1549055132.00 Levvel_Placement_S09_B01 to Levvel_Layer_08 suspended
# T=1549055132.00 Levvel_Placement_S10_B01 to Levvel_Layer_09 suspended
# T=1549055132.00 Levvel_Placement_S11_B01 to Levvel_Layer_10 suspended
# T=1549055132.00 Levvel_Placement_S12_B01 to Levvel_Layer_11 suspended
# T=1549055132.00 Levvel_Placement_S13_B01 to Levvel_Layer_12 suspended
# T=1549055132.00 Levvel_Placement_S14_B01 to Levvel_Layer_13 suspended
# T=1549055132.00 Levvel_Placement_S15_B01 to Levvel_Layer_14 suspended
# T=1549055132.00 Levvel_Placement_S16_B01 to Levvel_Layer_15 suspended
# T=1549055132.00 Levvel_Placement_S17_B01 to Levvel_Layer_16 suspended
# T=1549055132.00 Levvel_Placement_S18_B01 to Levvel_Layer_17 suspended
# T=1549055132.00 Levvel_Placement_S19_B01 to Levvel_Layer_18 suspended
# T=1549055132.00 Levvel_Placement_S20_B01 to Levvel_Layer_19 suspended
# T=1549055132.00 Levvel_Placement_S01_B02 to Levvel_Layer_00 suspended
# T=1549055132.00 Levvel_Placement_S02_B02 to Levvel_Layer_01 suspended
# T=1549055132.00 Levvel_Placement_S03_B02 to Levvel_Layer_02 suspended
# T=1549055132.00 Levvel_Placement_S04_B02 to Levvel_Layer_03 suspended
# T=1549055132.00 Levvel_Placement_S05_B02 to Levvel_Layer_04 suspended
# T=1549055132.00 Levvel_Placement_S06_B02 to Levvel_Layer_05 suspended
# T=1549055132.00 Levvel_Placement_S07_B02 to Levvel_Layer_06 suspended
# T=1549055132.00 Levvel_Placement_S08_B02 to Levvel_Layer_07 suspended
# T=1549055132.00 Levvel_Placement_S09_B02 to Levvel_Layer_08 suspended
# T=1549055132.00 Levvel_Placement_S10_B02 to Levvel_Layer_09 suspended
# T=1549055132.00 Levvel_Placement_S11_B02 to Levvel_Layer_10 suspended
# T=1549055132.00 Levvel_Placement_S12_B02 to Levvel_Layer_11 suspended
# T=1549055132.00 Levvel_Placement_S13_B02 to Levvel_Layer_12 suspended
# T=1549055132.00 Levvel_Placement_S14_B02 to Levvel_Layer_13 suspended
# T=1549055132.00 Levvel_Placement_S15_B02 to Levvel_Layer_14 suspended
# T=1549055132.00 Levvel_Placement_S16_B02 to Levvel_Layer_15 suspended
# T=1549055132.00 Levvel_Placement_S17_B02 to Levvel_Layer_16 suspended
# T=1549055132.00 Levvel_Placement_S18_B02 to Levvel_Layer_17 suspended
# T=1549055132.00 Levvel_Placement_S19_B02 to Levvel_Layer_18 suspended
# T=1549055132.00 Levvel_Placement_S20_B02 to Levvel_Layer_19 suspended
# Nothing to move
# Nothing to move
# Nothing to move
# T=1549109132.00 Start condition is satisfied, Clay_Placement_S02_B01 transporting from Clay_Stock to Clay_Layer_01 started
# T=1549109132.00 Start condition is satisfied, Clay_Placement_S02_B02 transporting from Clay_Stock to Clay_Layer_01 started
# T=1549109132.00 Start condition is satisfied, Sand_Placement_S01 transporting from Sand_Stock to Sand_Layer_00 started
# T=1549109520.58 Stop condition is satisfied, Clay_Placement_S01_B01 transporting from Clay_Stock to Clay_Layer_00 complete
# T=1549110320.58 Stop condition is satisfied, Clay_Placement_S01_B02 transporting from Clay_Stock to Clay_Layer_00 complete
# Nothing to move
# Nothing to move
# Nothing to move
# T=1549165894.69 Stop condition is satisfied, Clay_Placement_S02_B02 transporting from Clay_Stock to Clay_Layer_01 complete
# T=1549166694.69 Stop condition is satisfied, Clay_Placement_S02_B01 transporting from Clay_Stock to Clay_Layer_01 complete
# T=1549166732.00 Start condition is satisfied, Clay_Placement_S03_B01 transporting from Clay_Stock to Clay_Layer_02 started
# T=1549166732.00 Start condition is satisfied, Clay_Placement_S03_B02 transporting from Clay_Stock to Clay_Layer_02 started
# T=1549202375.23 Stop condition is satisfied, Sand_Placement_S01 transporting from Sand_Stock to Sand_Layer_00 complete
# T=1549202732.00 Start condition is satisfied, Sand_Placement_S02 transporting from Sand_Stock to Sand_Layer_01 started
# T=1549202732.00 Start condition is satisfied, Armour_Placement_S01_B01 transporting from Armour_Stock to Armour_Layer_00 started
# Nothing to move
# T=1549202732.00 Start condition is satisfied, Armour_Placement_S01_B02 transporting from Armour_Stock to Armour_Layer_00 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1549224332.00 Start condition is satisfied, Clay_Placement_S04_B01 transporting from Clay_Stock to Clay_Layer_03 started
# T=1549224332.00 Start condition is satisfied, Clay_Placement_S04_B02 transporting from Clay_Stock to Clay_Layer_03 started
# T=1549225043.91 Stop condition is satisfied, Clay_Placement_S03_B01 transporting from Clay_Stock to Clay_Layer_02 complete
# T=1549225843.91 Stop condition is satisfied, Clay_Placement_S03_B02 transporting from Clay_Stock to Clay_Layer_02 complete
# T=1549291496.54 Stop condition is satisfied, Sand_Placement_S02 transporting from Sand_Stock to Sand_Layer_01 complete
# T=1549292732.00 Start condition is satisfied, Sand_Placement_S03 transporting from Sand_Stock to Sand_Layer_02 started
# T=1549376130.31 Stop condition is satisfied, Sand_Placement_S03 transporting from Sand_Stock to Sand_Layer_02 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1549568413.28 Stop condition is satisfied, Armour_Placement_S01_B02 transporting from Armour_Stock to Armour_Layer_00 complete
# T=1549569799.47 Stop condition is satisfied, Armour_Placement_S01_B01 transporting from Armour_Stock to Armour_Layer_00 complete
# T=1549569932.00 Start condition is satisfied, Armour_Placement_S02_B01 transporting from Armour_Stock to Armour_Layer_01 started
# T=1549569932.00 Start condition is satisfied, Armour_Placement_S02_B02 transporting from Armour_Stock to Armour_Layer_01 started
# Nothing to move
# T=1549569932.00 Start condition is satisfied, Levvel_Placement_S01_B01 transporting from Levvel_Stock to Levvel_Layer_00 started
# T=1549569932.00 Start condition is satisfied, Levvel_Placement_S01_B02 transporting from Levvel_Stock to Levvel_Layer_00 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1549587005.39 Stop condition is satisfied, Clay_Placement_S04_B02 transporting from Clay_Stock to Clay_Layer_03 complete
# T=1549587932.00 Start condition is satisfied, Clay_Placement_S05_B01 transporting from Clay_Stock to Clay_Layer_04 started
# T=1549587932.00 Start condition is satisfied, Clay_Placement_S05_B02 transporting from Clay_Stock to Clay_Layer_04 started
# T=1549587932.00 Start condition is satisfied, Sand_Placement_S04 transporting from Sand_Stock to Sand_Layer_03 started
# T=1549588391.58 Stop condition is satisfied, Clay_Placement_S04_B01 transporting from Clay_Stock to Clay_Layer_03 complete
# T=1549666168.62 Stop condition is satisfied, Sand_Placement_S04 transporting from Sand_Stock to Sand_Layer_03 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1550069870.96 Stop condition is satisfied, Clay_Placement_S05_B02 transporting from Clay_Stock to Clay_Layer_04 complete
# T=1550070266.08 Stop condition is satisfied, Clay_Placement_S05_B01 transporting from Clay_Stock to Clay_Layer_04 complete
# T=1550070332.00 Start condition is satisfied, Clay_Placement_S06_B01 transporting from Clay_Stock to Clay_Layer_05 started
# Nothing to move
# T=1550070332.00 Start condition is satisfied, Clay_Placement_S06_B02 transporting from Clay_Stock to Clay_Layer_05 started
# T=1550070332.00 Start condition is satisfied, Sand_Placement_S05 transporting from Sand_Stock to Sand_Layer_04 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1550134421.95 Stop condition is satisfied, Armour_Placement_S02_B02 transporting from Armour_Stock to Armour_Layer_01 complete
# T=1550134527.46 Stop condition is satisfied, Armour_Placement_S02_B01 transporting from Armour_Stock to Armour_Layer_01 complete
# T=1550135132.00 Start condition is satisfied, Armour_Placement_S03_B01 transporting from Armour_Stock to Armour_Layer_02 started
# T=1550135132.00 Start condition is satisfied, Armour_Placement_S03_B02 transporting from Armour_Stock to Armour_Layer_02 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1550143658.84 Stop condition is satisfied, Sand_Placement_S05 transporting from Sand_Stock to Sand_Layer_04 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1550239532.00 Start condition is satisfied, Levvel_Placement_S02_B01 transporting from Levvel_Stock to Levvel_Layer_01 started
# T=1550239532.00 Start condition is satisfied, Levvel_Placement_S02_B02 transporting from Levvel_Stock to Levvel_Layer_01 started
# Nothing to move
# T=1550241107.31 Stop condition is satisfied, Levvel_Placement_S01_B02 transporting from Levvel_Stock to Levvel_Layer_00 complete
# T=1550241212.82 Stop condition is satisfied, Levvel_Placement_S01_B01 transporting from Levvel_Stock to Levvel_Layer_00 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1550271867.39 Stop condition is satisfied, Clay_Placement_S06_B02 transporting from Clay_Stock to Clay_Layer_05 complete
# T=1550271932.00 Start condition is satisfied, Clay_Placement_S07_B01 transporting from Clay_Stock to Clay_Layer_06 started
# T=1550271932.00 Start condition is satisfied, Clay_Placement_S07_B02 transporting from Clay_Stock to Clay_Layer_06 started
# T=1550271932.00 Start condition is satisfied, Sand_Placement_S06 transporting from Sand_Stock to Sand_Layer_05 started
# T=1550272667.39 Stop condition is satisfied, Clay_Placement_S06_B01 transporting from Clay_Stock to Clay_Layer_05 complete
# T=1550340660.65 Stop condition is satisfied, Sand_Placement_S06 transporting from Sand_Stock to Sand_Layer_05 complete
# Nothing to move
# Nothing to move
# Nothing to move
# T=1550603132.00 Start condition is satisfied, Armour_Placement_S04_B01 transporting from Armour_Stock to Armour_Layer_03 started
# T=1550603132.00 Start condition is satisfied, Armour_Placement_S04_B02 transporting from Armour_Stock to Armour_Layer_03 started
# T=1550604124.45 Stop condition is satisfied, Armour_Placement_S03_B02 transporting from Armour_Stock to Armour_Layer_02 complete
# T=1550604924.45 Stop condition is satisfied, Armour_Placement_S03_B01 transporting from Armour_Stock to Armour_Layer_02 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1550927132.00 Start condition is satisfied, Levvel_Placement_S03_B01 transporting from Levvel_Stock to Levvel_Layer_02 started
# T=1550927132.00 Start condition is satisfied, Levvel_Placement_S03_B02 transporting from Levvel_Stock to Levvel_Layer_02 started
# Nothing to move
# T=1550927837.73 Stop condition is satisfied, Levvel_Placement_S02_B01 transporting from Levvel_Stock to Levvel_Layer_01 complete
# T=1550929041.97 Stop condition is satisfied, Levvel_Placement_S02_B02 transporting from Levvel_Stock to Levvel_Layer_01 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1550948732.00 Start condition is satisfied, Clay_Placement_S08_B01 transporting from Clay_Stock to Clay_Layer_07 started
# T=1550948732.00 Start condition is satisfied, Clay_Placement_S08_B02 transporting from Clay_Stock to Clay_Layer_07 started
# T=1550948732.00 Start condition is satisfied, Sand_Placement_S07 transporting from Sand_Stock to Sand_Layer_06 started
# T=1550950239.82 Stop condition is satisfied, Clay_Placement_S07_B01 transporting from Clay_Stock to Clay_Layer_06 complete
# T=1550951444.06 Stop condition is satisfied, Clay_Placement_S07_B02 transporting from Clay_Stock to Clay_Layer_06 complete
# T=1551013248.19 Stop condition is satisfied, Sand_Placement_S07 transporting from Sand_Stock to Sand_Layer_06 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1551143132.00 Start condition is satisfied, Armour_Placement_S05_B01 transporting from Armour_Stock to Armour_Layer_04 started
# Nothing to move
# T=1551143132.00 Start condition is satisfied, Armour_Placement_S05_B02 transporting from Armour_Stock to Armour_Layer_04 started
# T=1551143520.06 Stop condition is satisfied, Armour_Placement_S04_B02 transporting from Armour_Stock to Armour_Layer_03 complete
# T=1551145032.58 Stop condition is satisfied, Armour_Placement_S04_B01 transporting from Armour_Stock to Armour_Layer_03 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1551499532.00 Start condition is satisfied, Levvel_Placement_S04_B01 transporting from Levvel_Stock to Levvel_Layer_03 started
# Nothing to move
# T=1551499532.00 Start condition is satisfied, Levvel_Placement_S04_B02 transporting from Levvel_Stock to Levvel_Layer_03 started
# T=1551499982.21 Stop condition is satisfied, Levvel_Placement_S03_B01 transporting from Levvel_Stock to Levvel_Layer_02 complete
# T=1551500277.76 Stop condition is satisfied, Levvel_Placement_S03_B02 transporting from Levvel_Stock to Levvel_Layer_02 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1551611132.00 Start condition is satisfied, Armour_Placement_S06_B01 transporting from Armour_Stock to Armour_Layer_05 started
# T=1551611132.00 Start condition is satisfied, Armour_Placement_S06_B02 transporting from Armour_Stock to Armour_Layer_05 started
# Nothing to move
# T=1551613042.35 Stop condition is satisfied, Armour_Placement_S05_B01 transporting from Armour_Stock to Armour_Layer_04 complete
# T=1551613842.35 Stop condition is satisfied, Armour_Placement_S05_B02 transporting from Armour_Stock to Armour_Layer_04 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1551628569.36 Stop condition is satisfied, Clay_Placement_S08_B01 transporting from Clay_Stock to Clay_Layer_07 complete
# T=1551628651.89 Stop condition is satisfied, Clay_Placement_S08_B02 transporting from Clay_Stock to Clay_Layer_07 complete
# T=1551629132.00 Start condition is satisfied, Clay_Placement_S09_B01 transporting from Clay_Stock to Clay_Layer_08 started
# T=1551629132.00 Start condition is satisfied, Clay_Placement_S09_B02 transporting from Clay_Stock to Clay_Layer_08 started
# T=1551629132.00 Start condition is satisfied, Sand_Placement_S08 transporting from Sand_Stock to Sand_Layer_07 started
# T=1551689911.37 Stop condition is satisfied, Sand_Placement_S08 transporting from Sand_Stock to Sand_Layer_07 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1552107932.00 Start condition is satisfied, Clay_Placement_S10_B01 transporting from Clay_Stock to Clay_Layer_09 started
# Nothing to move
# T=1552107932.00 Start condition is satisfied, Clay_Placement_S10_B02 transporting from Clay_Stock to Clay_Layer_09 started
# T=1552107932.00 Start condition is satisfied, Sand_Placement_S09 transporting from Sand_Stock to Sand_Layer_08 started
# T=1552108274.92 Stop condition is satisfied, Clay_Placement_S09_B02 transporting from Clay_Stock to Clay_Layer_08 complete
# Nothing to move
# T=1552109815.58 Stop condition is satisfied, Clay_Placement_S09_B01 transporting from Clay_Stock to Clay_Layer_08 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1552165554.59 Stop condition is satisfied, Sand_Placement_S09 transporting from Sand_Stock to Sand_Layer_08 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1552172275.46 Stop condition is satisfied, Levvel_Placement_S04_B02 transporting from Levvel_Stock to Levvel_Layer_03 complete
# T=1552172732.00 Start condition is satisfied, Levvel_Placement_S05_B01 transporting from Levvel_Stock to Levvel_Layer_04 started
# T=1552172732.00 Start condition is satisfied, Levvel_Placement_S05_B02 transporting from Levvel_Stock to Levvel_Layer_04 started
# T=1552174239.72 Stop condition is satisfied, Levvel_Placement_S04_B01 transporting from Levvel_Stock to Levvel_Layer_03 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1552275261.97 Stop condition is satisfied, Armour_Placement_S06_B02 transporting from Armour_Stock to Armour_Layer_05 complete
# T=1552275685.07 Stop condition is satisfied, Armour_Placement_S06_B01 transporting from Armour_Stock to Armour_Layer_05 complete
# T=1552277132.00 Start condition is satisfied, Armour_Placement_S07_B01 transporting from Armour_Stock to Armour_Layer_06 started
# T=1552277132.00 Start condition is satisfied, Armour_Placement_S07_B02 transporting from Armour_Stock to Armour_Layer_06 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1552329411.13 Stop condition is satisfied, Clay_Placement_S10_B01 transporting from Clay_Stock to Clay_Layer_09 complete
# T=1552329643.24 Stop condition is satisfied, Clay_Placement_S10_B02 transporting from Clay_Stock to Clay_Layer_09 complete
# T=1552331132.00 Start condition is satisfied, Clay_Placement_S11_B01 transporting from Clay_Stock to Clay_Layer_10 started
# T=1552331132.00 Start condition is satisfied, Clay_Placement_S11_B02 transporting from Clay_Stock to Clay_Layer_10 started
# T=1552331132.00 Start condition is satisfied, Sand_Placement_S10 transporting from Sand_Stock to Sand_Layer_09 started
# T=1552386290.76 Stop condition is satisfied, Sand_Placement_S10 transporting from Sand_Stock to Sand_Layer_09 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1552657700.68 Stop condition is satisfied, Levvel_Placement_S05_B01 transporting from Levvel_Stock to Levvel_Layer_04 complete
# T=1552657932.79 Stop condition is satisfied, Levvel_Placement_S05_B02 transporting from Levvel_Stock to Levvel_Layer_04 complete
# T=1552658732.00 Start condition is satisfied, Levvel_Placement_S06_B01 transporting from Levvel_Stock to Levvel_Layer_05 started
# T=1552658732.00 Start condition is satisfied, Levvel_Placement_S06_B02 transporting from Levvel_Stock to Levvel_Layer_05 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1552959677.70 Stop condition is satisfied, Armour_Placement_S07_B02 transporting from Armour_Stock to Armour_Layer_06 complete
# T=1552960496.13 Stop condition is satisfied, Armour_Placement_S07_B01 transporting from Armour_Stock to Armour_Layer_06 complete
# T=1552961132.00 Start condition is satisfied, Armour_Placement_S08_B01 transporting from Armour_Stock to Armour_Layer_07 started
# T=1552961132.00 Start condition is satisfied, Armour_Placement_S08_B02 transporting from Armour_Stock to Armour_Layer_07 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1552989932.00 Start condition is satisfied, Clay_Placement_S12_B01 transporting from Clay_Stock to Clay_Layer_11 started
# T=1552989932.00 Start condition is satisfied, Clay_Placement_S12_B02 transporting from Clay_Stock to Clay_Layer_11 started
# T=1552989932.00 Start condition is satisfied, Sand_Placement_S11 transporting from Sand_Stock to Sand_Layer_10 started
# T=1552990015.16 Stop condition is satisfied, Clay_Placement_S11_B02 transporting from Clay_Stock to Clay_Layer_10 complete
# T=1552990833.59 Stop condition is satisfied, Clay_Placement_S11_B01 transporting from Clay_Stock to Clay_Layer_10 complete
# T=1553043428.72 Stop condition is satisfied, Sand_Placement_S11 transporting from Sand_Stock to Sand_Layer_10 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1553183978.38 Stop condition is satisfied, Levvel_Placement_S06_B01 transporting from Levvel_Stock to Levvel_Layer_05 complete
# T=1553184332.00 Start condition is satisfied, Levvel_Placement_S07_B01 transporting from Levvel_Stock to Levvel_Layer_06 started
# Nothing to move
# T=1553184332.00 Start condition is satisfied, Levvel_Placement_S07_B02 transporting from Levvel_Stock to Levvel_Layer_06 started
# T=1553185328.16 Stop condition is satisfied, Levvel_Placement_S06_B02 transporting from Levvel_Stock to Levvel_Layer_05 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1553537132.00 Start condition is satisfied, Armour_Placement_S09_B01 transporting from Armour_Stock to Armour_Layer_08 started
# Nothing to move
# T=1553537132.00 Start condition is satisfied, Armour_Placement_S09_B02 transporting from Armour_Stock to Armour_Layer_08 started
# T=1553537485.52 Stop condition is satisfied, Armour_Placement_S08_B02 transporting from Armour_Stock to Armour_Layer_07 complete
# Nothing to move
# T=1553538788.50 Stop condition is satisfied, Armour_Placement_S08_B01 transporting from Armour_Stock to Armour_Layer_07 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1553666732.00 Start condition is satisfied, Clay_Placement_S13_B01 transporting from Clay_Stock to Clay_Layer_12 started
# T=1553666732.00 Start condition is satisfied, Clay_Placement_S13_B02 transporting from Clay_Stock to Clay_Layer_12 started
# T=1553666732.00 Start condition is satisfied, Sand_Placement_S12 transporting from Sand_Stock to Sand_Layer_11 started
# T=1553667656.29 Stop condition is satisfied, Clay_Placement_S12_B02 transporting from Clay_Stock to Clay_Layer_11 complete
# T=1553668140.85 Stop condition is satisfied, Clay_Placement_S12_B01 transporting from Clay_Stock to Clay_Layer_11 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1553719454.64 Stop condition is satisfied, Sand_Placement_S12 transporting from Sand_Stock to Sand_Layer_11 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1553747828.69 Stop condition is satisfied, Levvel_Placement_S07_B02 transporting from Levvel_Stock to Levvel_Layer_06 complete
# T=1553748231.60 Stop condition is satisfied, Levvel_Placement_S07_B01 transporting from Levvel_Stock to Levvel_Layer_06 complete
# T=1553749532.00 Start condition is satisfied, Levvel_Placement_S08_B01 transporting from Levvel_Stock to Levvel_Layer_07 started
# T=1553749532.00 Start condition is satisfied, Levvel_Placement_S08_B02 transporting from Levvel_Stock to Levvel_Layer_07 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1554070904.65 Stop condition is satisfied, Armour_Placement_S09_B02 transporting from Armour_Stock to Armour_Layer_08 complete
# T=1554072322.42 Stop condition is satisfied, Armour_Placement_S09_B01 transporting from Armour_Stock to Armour_Layer_08 complete
# T=1554073532.00 Start condition is satisfied, Armour_Placement_S10_B01 transporting from Armour_Stock to Armour_Layer_09 started
# T=1554073532.00 Start condition is satisfied, Armour_Placement_S10_B02 transporting from Armour_Stock to Armour_Layer_09 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1554149132.00 Start condition is satisfied, Clay_Placement_S14_B01 transporting from Clay_Stock to Clay_Layer_13 started
# Nothing to move
# T=1554149132.00 Start condition is satisfied, Clay_Placement_S14_B02 transporting from Clay_Stock to Clay_Layer_13 started
# T=1554149132.00 Start condition is satisfied, Sand_Placement_S13 transporting from Sand_Stock to Sand_Layer_12 started
# T=1554149492.16 Stop condition is satisfied, Clay_Placement_S13_B01 transporting from Clay_Stock to Clay_Layer_12 complete
# T=1554150284.80 Stop condition is satisfied, Clay_Placement_S13_B02 transporting from Clay_Stock to Clay_Layer_12 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1554202012.54 Stop condition is satisfied, Sand_Placement_S13 transporting from Sand_Stock to Sand_Layer_12 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1554339932.00 Start condition is satisfied, Levvel_Placement_S09_B01 transporting from Levvel_Stock to Levvel_Layer_08 started
# T=1554339932.00 Start condition is satisfied, Levvel_Placement_S09_B02 transporting from Levvel_Stock to Levvel_Layer_08 started
# T=1554340963.52 Stop condition is satisfied, Levvel_Placement_S08_B02 transporting from Levvel_Stock to Levvel_Layer_07 complete
# T=1554342091.20 Stop condition is satisfied, Levvel_Placement_S08_B01 transporting from Levvel_Stock to Levvel_Layer_07 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1554652155.38 Stop condition is satisfied, Armour_Placement_S10_B02 transporting from Armour_Stock to Armour_Layer_09 complete
# Nothing to move
# T=1554652945.51 Stop condition is satisfied, Armour_Placement_S10_B01 transporting from Armour_Stock to Armour_Layer_09 complete
# T=1554653132.00 Start condition is satisfied, Armour_Placement_S11_B01 transporting from Armour_Stock to Armour_Layer_10 started
# T=1554653132.00 Start condition is satisfied, Armour_Placement_S11_B02 transporting from Armour_Stock to Armour_Layer_10 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1554688526.27 Stop condition is satisfied, Clay_Placement_S14_B02 transporting from Clay_Stock to Clay_Layer_13 complete
# T=1554688734.50 Stop condition is satisfied, Clay_Placement_S14_B01 transporting from Clay_Stock to Clay_Layer_13 complete
# T=1554689132.00 Start condition is satisfied, Clay_Placement_S15_B01 transporting from Clay_Stock to Clay_Layer_14 started
# T=1554689132.00 Start condition is satisfied, Clay_Placement_S15_B02 transporting from Clay_Stock to Clay_Layer_14 started
# Nothing to move
# T=1554689132.00 Start condition is satisfied, Sand_Placement_S14 transporting from Sand_Stock to Sand_Layer_13 started
# Nothing to move
# Nothing to move
# Nothing to move
# T=1554743092.77 Stop condition is satisfied, Sand_Placement_S14 transporting from Sand_Stock to Sand_Layer_13 complete
# Nothing to move
# Nothing to move
# ...
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1557302732.00 Start condition is satisfied, Clay_Placement_S20_B01 transporting from Clay_Stock to Clay_Layer_19 started
# T=1557302732.00 Start condition is satisfied, Clay_Placement_S20_B02 transporting from Clay_Stock to Clay_Layer_19 started
# Nothing to move
# T=1557302732.00 Start condition is satisfied, Sand_Placement_S19 transporting from Sand_Stock to Sand_Layer_18 started
# T=1557302819.10 Stop condition is satisfied, Clay_Placement_S19_B01 transporting from Clay_Stock to Clay_Layer_18 complete
# T=1557302929.31 Stop condition is satisfied, Clay_Placement_S19_B02 transporting from Clay_Stock to Clay_Layer_18 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1557338732.00 Start condition is satisfied, Levvel_Placement_S14_B01 transporting from Levvel_Stock to Levvel_Layer_13 started
# Nothing to move
# T=1557338732.00 Start condition is satisfied, Levvel_Placement_S14_B02 transporting from Levvel_Stock to Levvel_Layer_13 started
# T=1557340139.32 Stop condition is satisfied, Levvel_Placement_S13_B02 transporting from Levvel_Stock to Levvel_Layer_12 complete
# T=1557340191.59 Stop condition is satisfied, Levvel_Placement_S13_B01 transporting from Levvel_Stock to Levvel_Layer_12 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1557372949.73 Stop condition is satisfied, Sand_Placement_S19 transporting from Sand_Stock to Sand_Layer_18 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1557434318.10 Stop condition is satisfied, Armour_Placement_S15_B01 transporting from Armour_Stock to Armour_Layer_14 complete
# T=1557435825.08 Stop condition is satisfied, Armour_Placement_S15_B02 transporting from Armour_Stock to Armour_Layer_14 complete
# T=1557435932.00 Start condition is satisfied, Armour_Placement_S16_B01 transporting from Armour_Stock to Armour_Layer_15 started
# Nothing to move
# T=1557435932.00 Start condition is satisfied, Armour_Placement_S16_B02 transporting from Armour_Stock to Armour_Layer_15 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1557705932.00 Start condition is satisfied, Sand_Placement_S20 transporting from Sand_Stock to Sand_Layer_19 started
# T=1557706419.84 Stop condition is satisfied, Clay_Placement_S20_B02 transporting from Clay_Stock to Clay_Layer_19 complete
# T=1557707548.31 Stop condition is satisfied, Clay_Placement_S20_B01 transporting from Clay_Stock to Clay_Layer_19 complete
# T=1557780852.45 Stop condition is satisfied, Sand_Placement_S20 transporting from Sand_Stock to Sand_Layer_19 complete
# Nothing to move
# Nothing to move
# Nothing to move
# T=1557803132.00 Start condition is satisfied, Levvel_Placement_S15_B01 transporting from Levvel_Stock to Levvel_Layer_14 started
# T=1557803132.00 Start condition is satisfied, Levvel_Placement_S15_B02 transporting from Levvel_Stock to Levvel_Layer_14 started
# T=1557804630.84 Stop condition is satisfied, Levvel_Placement_S14_B01 transporting from Levvel_Stock to Levvel_Layer_13 complete
# T=1557805430.84 Stop condition is satisfied, Levvel_Placement_S14_B02 transporting from Levvel_Stock to Levvel_Layer_13 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1558062332.00 Start condition is satisfied, Armour_Placement_S17_B01 transporting from Armour_Stock to Armour_Layer_16 started
# Nothing to move
# T=1558062332.00 Start condition is satisfied, Armour_Placement_S17_B02 transporting from Armour_Stock to Armour_Layer_16 started
# T=1558062438.83 Stop condition is satisfied, Armour_Placement_S16_B02 transporting from Armour_Stock to Armour_Layer_15 complete
# T=1558063268.25 Stop condition is satisfied, Armour_Placement_S16_B01 transporting from Armour_Stock to Armour_Layer_15 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1558251706.19 Stop condition is satisfied, Levvel_Placement_S15_B01 transporting from Levvel_Stock to Levvel_Layer_14 complete
# T=1558252592.27 Stop condition is satisfied, Levvel_Placement_S15_B02 transporting from Levvel_Stock to Levvel_Layer_14 complete
# T=1558253132.00 Start condition is satisfied, Levvel_Placement_S16_B01 transporting from Levvel_Stock to Levvel_Layer_15 started
# T=1558253132.00 Start condition is satisfied, Levvel_Placement_S16_B02 transporting from Levvel_Stock to Levvel_Layer_15 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1558502083.36 Stop condition is satisfied, Armour_Placement_S17_B01 transporting from Armour_Stock to Armour_Layer_16 complete
# T=1558503852.68 Stop condition is satisfied, Armour_Placement_S17_B02 transporting from Armour_Stock to Armour_Layer_16 complete
# T=1558505132.00 Start condition is satisfied, Armour_Placement_S18_B01 transporting from Armour_Stock to Armour_Layer_17 started
# Nothing to move
# T=1558505132.00 Start condition is satisfied, Armour_Placement_S18_B02 transporting from Armour_Stock to Armour_Layer_17 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1558692332.00 Start condition is satisfied, Levvel_Placement_S17_B01 transporting from Levvel_Stock to Levvel_Layer_16 started
# T=1558692332.00 Start condition is satisfied, Levvel_Placement_S17_B02 transporting from Levvel_Stock to Levvel_Layer_16 started
# T=1558692489.38 Stop condition is satisfied, Levvel_Placement_S16_B01 transporting from Levvel_Stock to Levvel_Layer_15 complete
# T=1558692951.32 Stop condition is satisfied, Levvel_Placement_S16_B02 transporting from Levvel_Stock to Levvel_Layer_15 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1558938236.37 Stop condition is satisfied, Armour_Placement_S18_B01 transporting from Armour_Stock to Armour_Layer_17 complete
# T=1558940129.28 Stop condition is satisfied, Armour_Placement_S18_B02 transporting from Armour_Stock to Armour_Layer_17 complete
# T=1558940732.00 Start condition is satisfied, Armour_Placement_S19_B01 transporting from Armour_Stock to Armour_Layer_18 started
# Nothing to move
# T=1558940732.00 Start condition is satisfied, Armour_Placement_S19_B02 transporting from Armour_Stock to Armour_Layer_18 started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1559041532.00 Start condition is satisfied, Levvel_Placement_S18_B01 transporting from Levvel_Stock to Levvel_Layer_17 started
# T=1559041532.00 Start condition is satisfied, Levvel_Placement_S18_B02 transporting from Levvel_Stock to Levvel_Layer_17 started
# T=1559041803.38 Stop condition is satisfied, Levvel_Placement_S17_B02 transporting from Levvel_Stock to Levvel_Layer_16 complete
# T=1559042741.64 Stop condition is satisfied, Levvel_Placement_S17_B01 transporting from Levvel_Stock to Levvel_Layer_16 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1559458238.03 Stop condition is satisfied, Armour_Placement_S19_B02 transporting from Armour_Stock to Armour_Layer_18 complete
# T=1559459132.00 Start condition is satisfied, Armour_Placement_S20_B01 transporting from Armour_Stock to Armour_Layer_19 started
# T=1559459132.00 Start condition is satisfied, Armour_Placement_S20_B02 transporting from Armour_Stock to Armour_Layer_19 started
# Nothing to move
# T=1559459733.01 Stop condition is satisfied, Armour_Placement_S19_B01 transporting from Armour_Stock to Armour_Layer_18 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1559544519.07 Stop condition is satisfied, Levvel_Placement_S18_B02 transporting from Levvel_Stock to Levvel_Layer_17 complete
# T=1559545532.00 Start condition is satisfied, Levvel_Placement_S19_B01 transporting from Levvel_Stock to Levvel_Layer_18 started
# Nothing to move
# T=1559545532.00 Start condition is satisfied, Levvel_Placement_S19_B02 transporting from Levvel_Stock to Levvel_Layer_18 started
# T=1559546014.05 Stop condition is satisfied, Levvel_Placement_S18_B01 transporting from Levvel_Stock to Levvel_Layer_17 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1559896071.36 Stop condition is satisfied, Armour_Placement_S20_B01 transporting from Armour_Stock to Armour_Layer_19 complete
# Nothing to move
# T=1559897429.90 Stop condition is satisfied, Armour_Placement_S20_B02 transporting from Armour_Stock to Armour_Layer_19 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1559981132.00 Start condition is satisfied, Levvel_Placement_S20_B01 transporting from Levvel_Stock to Levvel_Layer_19 started
# T=1559981132.00 Start condition is satisfied, Levvel_Placement_S20_B02 transporting from Levvel_Stock to Levvel_Layer_19 started
# T=1559981392.11 Stop condition is satisfied, Levvel_Placement_S19_B01 transporting from Levvel_Stock to Levvel_Layer_18 complete
# T=1559982750.65 Stop condition is satisfied, Levvel_Placement_S19_B02 transporting from Levvel_Stock to Levvel_Layer_18 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1560236204.85 Stop condition is satisfied, Levvel_Placement_S20_B02 transporting from Levvel_Stock to Levvel_Layer_19 complete
# T=1560236900.74 Stop condition is satisfied, Levvel_Placement_S20_B01 transporting from Levvel_Stock to Levvel_Layer_19 complete
#
# *** Installation of dike finished in 129 days, 10:02:47 ***

# %% [markdown]
# ### 3. Postprocessing

# %% [markdown]
# #### Vessel planning

# %%
vessels = [gantry_crane, 
           installation_crane, 
           transport_barge_01, 
           transport_barge_02, 
           hopper]

activities = ['loading', 'unloading', 'sailing full', 'sailing empty', 'processing']
colors = {0:'rgb(55,126,184)', 1:'rgb(255,150,0)', 2:'rgb(98, 192, 122)', 3:'rgb(98, 141, 122)', 4:'rgb(110, 141, 122)'}

plot.vessel_planning(vessels, activities, colors)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="0caaa158-a039-4576-aaa2-effd7701db10" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0caaa158-a039-4576-aaa2-effd7701db10", [{"type": "scatter", "name": "loading", "x": ["2019-02-01 22:05:32", "2019-02-01 22:05:32", "2019-02-02 00:52:12", "2019-02-02 00:52:12", "2019-02-02 00:52:12", "2019-02-02 03:38:52", "2019-02-02 03:38:52", "2019-02-02 06:25:32", "2019-02-02 06:25:32", "2019-02-02 06:25:32", "2019-02-02 09:12:12", "2019-02-02 09:12:12", "2019-02-02 11:58:52", "2019-02-02 11:58:52", "2019-02-02 11:58:52", "2019-02-02 16:17:04.860315", "2019-02-02 16:17:04.860315", "2019-02-02 19:03:44.860315", "2019-02-02 19:03:44.860315", "2019-02-02 19:03:44.860315", "2019-02-02 21:50:24.860315", "2019-02-02 21:50:24.860315", "2019-02-03 00:37:04.860315", "2019-02-03 00:37:04.860315", "2019-02-03 00:37:04.860315", "2019-02-03 05:39:35.646641", "2019-02-03 05:39:35.646641", "2019-02-03 08:26:15.646641", "2019-02-03 08:26:15.646641", "2019-02-03 08:26:15.646641", "2019-02-03 11:12:55.646641", "2019-02-03 11:12:55.646641", "2019-02-03 13:59:35.646641", "2019-02-03 13:59:35.646641", "2019-02-03 13:59:35.646641", "2019-02-03 16:46:15.646641", "2019-02-03 16:46:15.646641", "2019-02-03 19:32:55.646641", "2019-02-03 19:32:55.646641", "2019-02-03 19:32:55.646641", "2019-02-04 07:05:13.988316", "2019-02-04 07:05:13.988316", "2019-02-04 09:51:53.988316", "2019-02-04 09:51:53.988316", "2019-02-04 09:51:53.988316", "2019-02-05 03:00:59.558841", "2019-02-05 03:00:59.558841", "2019-02-05 05:47:39.558841", "2019-02-05 05:47:39.558841", "2019-02-05 05:47:39.558841", "2019-02-05 17:28:47.799862", "2019-02-05 17:28:47.799862", "2019-02-05 20:15:27.799862", "2019-02-05 20:15:27.799862", "2019-02-05 20:15:27.799862", "2019-02-06 13:24:33.370386", "2019-02-06 13:24:33.370386", "2019-02-06 16:11:13.370386", "2019-02-06 16:11:13.370386", "2019-02-06 16:11:13.370386", "2019-02-08 06:44:42.035750", "2019-02-08 06:44:42.035750", "2019-02-08 09:31:22.035750", "2019-02-08 09:31:22.035750", "2019-02-08 09:31:22.035750", "2019-02-09 12:05:22.061262", "2019-02-09 12:05:22.061262", "2019-02-09 14:52:02.061262", "2019-02-09 14:52:02.061262", "2019-02-09 14:52:02.061262", "2019-02-10 08:02:41.391168", "2019-02-10 08:02:41.391168", "2019-02-10 10:49:21.391168", "2019-02-10 10:49:21.391168", "2019-02-10 10:49:21.391168", "2019-02-10 22:39:52.432962", "2019-02-10 22:39:52.432962", "2019-02-11 01:26:32.432962", "2019-02-11 01:26:32.432962", "2019-02-11 01:26:32.432962", "2019-02-12 04:00:32.458475", "2019-02-12 04:00:32.458475", "2019-02-12 06:47:12.458475", "2019-02-12 06:47:12.458475", "2019-02-12 06:47:12.458475", "2019-02-12 23:57:51.788380", "2019-02-12 23:57:51.788380", "2019-02-13 02:44:31.788380", "2019-02-13 02:44:31.788380", "2019-02-13 02:44:31.788380", "2019-02-13 14:35:02.830175", "2019-02-13 14:35:02.830175", "2019-02-13 17:21:42.830175", "2019-02-13 17:21:42.830175", "2019-02-13 17:21:42.830175", "2019-02-14 19:55:42.855688", "2019-02-14 19:55:42.855688", "2019-02-14 22:42:22.855688", "2019-02-14 22:42:22.855688", "2019-02-14 22:42:22.855688", "2019-02-15 15:53:02.185593", "2019-02-15 15:53:02.185593", "2019-02-15 18:39:42.185593", "2019-02-15 18:39:42.185593", "2019-02-15 18:39:42.185593", "2019-02-16 06:39:57.925058", "2019-02-16 06:39:57.925058", "2019-02-16 09:26:37.925058", "2019-02-16 09:26:37.925058", "2019-02-16 09:26:37.925058", "2019-02-17 11:37:57.792133", "2019-02-17 11:37:57.792133", "2019-02-17 14:24:37.792133", "2019-02-17 14:24:37.792133", "2019-02-17 14:24:37.792133", "2019-02-18 07:31:59.878646", "2019-02-18 07:31:59.878646", "2019-02-18 10:18:39.878646", "2019-02-18 10:18:39.878646", "2019-02-18 10:18:39.878646", "2019-02-18 22:28:56.841624", "2019-02-18 22:28:56.841624", "2019-02-19 01:15:36.841624", "2019-02-19 01:15:36.841624", "2019-02-19 01:1 ...

# %% [markdown]
# #### KML visualisation

# %%
plot.vessel_kml(my_env, vessels, stepsize = 3600)

# %%
# open the file
if platform.system():
    # !start ./vessel_movements.kml
else:
    # !start explorer ./vessel_movements.kml
