# %% [markdown]
# ## Example 05 - Container hub

# %% [markdown]
# **Example description:** Example of a large container vessel that brings containers to a stock yard, and smaller inland container vessels that ship them further inland.

# %% [markdown]
# * [**0. Import required libraries:**](#0.-Import-required-libraries)<br>
# * [**1. Define work method:**](#1.-Define-work-method)<br>
#    * [**1.1 Sites:**](#1.1-Define-the-project-sites)<br>
#    * [**1.2 Equipment:**](#1.2-Define-the-project-equipment)<br>
#    * [**1.3 Activities:**](#1.3-Define-the-activity)<br>
# * [**2. Run the simulation:**](#2.-Run-the-simulation)<br>
# * [**3. Post processing:**](#3.-Postprocessing)<br>

# %% [markdown]
# ## 0. Import required libraries

# %%
# package(s) related to time, space and id
import datetime, time
import platform

# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy

# spatial libraries 
import shapely.geometry
from simplekml import Kml, Style

# package(s) for data handling
import numpy as np

# digital twin package
import digital_twin.core as core
import digital_twin.model as model
import digital_twin.plot as plot

# %%
# Create simulation environment
simulation_start = datetime.datetime(2019, 1, 1)

my_env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
my_env.epoch = time.mktime(simulation_start.timetuple())

# %% [markdown]
# ## 1. Define work method

# %% [markdown]
# ### 1.1 Define the project sites
# You can specify a project site object by entering mix-ins:
#
#     core.Identifiable - enables you to give the object a name
#     core.Log - enables you to log all discrete events in which the object is involved
#     core.Locatable - enables you to add coordinates to extract distance information and visualize
#     core.HasContainer - enables you to add information on the material available at the site
#     core.HasResource - enables you to add information on serving equipment
#     core.HasWeather - enables you to add weather conditions

# %% [markdown]
# #### First create objects with the desired properties

# %%
# The generic site class
Site = type('Site', (core.Identifiable, # Give it a name
                     core.Log,          # Allow logging of all discrete events
                     core.Locatable,    # Add coordinates to extract distance information and visualize
                     core.HasContainer, # Add information on the material available at the site
                     core.HasResource), # Add information on serving equipment
            {})                         # The dictionary is empty because the site type is generic

# %% [markdown]
# #### Next specify the properties for sites you wish to create

# %%
# Information on the origin site
location_from_site = shapely.geometry.Point(0.4958561848972654,51.50427537860759)  # lon, lat

data_from_site = {"env": my_env,                  # The simpy environment defined in the first cel
                  "name": "Origin locatie",       # The name of the site
                  "geometry": location_from_site, # The coordinates of the project site
                  "capacity": 1_000_000,          # The capacity of the site
                  "level": 1_000_000}             # The actual volume of the site

# %%
# Information on the intermediate site
location_inter_site = shapely.geometry.Point(4.067560378249368,51.95173269362142)     # lon, lat

data_inter_site = {"env": my_env,                 # The simpy environment defined in the first cel
                "name": "Overslag locatie",       # The name of the site
                "geometry": location_inter_site,     # The coordinates of the project site
                "capacity": 1_000_000,            # The capacity of the site
                "level": 0}                       # The actual volume of the site (empty of course)

# %%
# Information on the destination site 
location_to_site = shapely.geometry.Point(5.83042471825503, 51.86058245744734)     # lon, lat

data_to_site = {"env": my_env,                    # The simpy environment defined in the first cel
                "name": "Destination locatie",    # The name of the site
                "geometry": location_to_site,     # The coordinates of the project site
                "capacity": 1_000_000,              # The capacity of the site
                "level": 0}                       # The actual volume of the site (empty of course)

# %% [markdown]
# #### Finally create specific instances of the predefined objects with the specified properties

# %%
# The two objects used for the simulation
from_site = Site(**data_from_site)
inter_site = Site(**data_inter_site)
to_site   = Site(**data_to_site)

# %% [markdown]
# ### 1.2 Define the project equipment
# You can specify a vessel object by entering mix-ins:
#
#     core.Identifiable - enables you to give the object a name
#     core.Log - enables you to log all discrete events in which the object is involved
#     core.ContainerDependentMovable - A moving container, so capacity and location
#     core.Processor - Allow for loading and unloading
#     core.HasResource - Add information on serving equipment
#     core.HasDepthRestriction - Add information on depth restriction

# %% [markdown]
# #### First create objects with the desired properties

# %%
# The generic class for an object that can move and transport (a TSHD for example)
TransportProcessingResource = type('TransportProcessingResource', 
                                   (core.Identifiable,              # Give it a name
                                    core.Log,                       # Allow logging of all discrete events
                                    core.ContainerDependentMovable, # A moving container, so capacity and location
                                    core.Processor,                 # Allow for loading and unloading
                                    core.HasResource,               # Add information on serving equipment
                                    core.HasSoil,                   # Add soil object, because it moves soil
                                    core.HasPlume),                 # Initialize spill terms
                                   {})

# %% [markdown]
# #### Next specify the properties for vessel(s) you wish to create

# %%
# For more realistic simulation you might want to have speed dependent on the volume carried by the vessel
def compute_v_provider(v_empty, v_full):
    return lambda x: x * (v_full - v_empty) + v_empty

def compute_loading(rate):
    return lambda x: x / rate

def compute_unloading(rate):
    return lambda x: x / rate

# %%
# TSHD variables
data_container_large = {"env": my_env,                              # The simpy environment 
               "name": "Container large",                           # Name
               "geometry": location_from_site,                      # It starts at the "from site"
               "loading_func": compute_loading(1.5),                # Loading rate
               "unloading_func": compute_unloading(1.5),            # Unloading rate
               "capacity": 20_000,                                  # Capacity of the container vessel - TEU
               "compute_v": compute_v_provider(5, 4.5)}             # Variable speed

# %%
# TSHD variables
data_container_small = {"env": my_env,                              # The simpy environment 
               "name": "Container small",                           # Name
               "geometry": location_from_site,                      # It starts at the "from site"
               "loading_func": compute_loading(1.5),                # Loading rate
               "unloading_func": compute_unloading(1.5),            # Unloading rate
               "capacity": 600,                                     # Capacity of the container vessel - TEU
               "compute_v": compute_v_provider(5, 4.5)}             # Variable speed

# %% [markdown]
# #### Finally create specific instances of the predefined objects with the specified properties

# %%
# The simulation object
container_large = TransportProcessingResource(**data_container_large)
container_small = TransportProcessingResource(**data_container_small)

# %% [markdown]
# ### 1.3 Define the activity

# %%
# Continuous simulation, stop after one year
stop_condition = model.TimeCondition(my_env, datetime.datetime(2019, 1, 1), 
                                             datetime.datetime(2020, 1, 1))

# %%
# Create activity
activity_1 = model.Activity(env = my_env,                     #    The simpy environment defined in the first cel
                          name = "International transport", # We are moving soil
                          origin = from_site,               # We originate from the from_site
                          destination = inter_site,         # And therefore travel to the to_site
                          loader = container_large,         # The benefit of a TSHD, all steps can be done
                          mover = container_large,          # The benefit of a TSHD, all steps can be done
                          unloader = container_large,       # The benefit of a TSHD, all steps can be done
                          start_condition = None,           # We can start right away and do not stop
                          stop_condition = stop_condition)  # stop after 1 year simulation

# %%
# Create activity                      
activity_2 = model.Activity(env = my_env,                     # The simpy environment defined in the first cel
                          name = "Hinterland transport",    # We are moving soil
                          origin = inter_site,              # We originate from the from_site
                          destination = to_site,            # And therefore travel to the to_site
                          loader = container_small,         # The benefit of a TSHD, all steps can be done
                          mover = container_small,          # The benefit of a TSHD, all steps can be done
                          unloader = container_small,       # The benefit of a TSHD, all steps can be done
                          start_condition = None,           # We can start right away and do not stop
                          stop_condition = stop_condition)  # stop after 1 year simulation

# %% [markdown]
# ### 2. Run the simulation

# %%
my_env.run()

print("\n*** Installation of dike finished in {} ***".format(datetime.timedelta(seconds=int(my_env.now - my_env.epoch))))
# Out:
# T=1546297200.00 Start condition is satisfied, International transport transporting from Origin locatie to Overslag locatie started
# T=1546297200.00 Start condition is satisfied, Hinterland transport transporting from Overslag locatie to Destination locatie started
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# ...
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# T=1577834015.31 Stop condition is satisfied, International transport transporting from Origin locatie to Overslag locatie complete
# T=1577835241.97 Stop condition is satisfied, Hinterland transport transporting from Overslag locatie to Destination locatie complete
#
# *** Installation of dike finished in 365 days, 0:34:01 ***

# %% [markdown]
# ### 3. Postprocessing

# %% [markdown]
# #### Vessel planning

# %%
container_small.__dict__
# Out:
# {'geometry': <shapely.geometry.point.PointAdapter at 0x21a447e6b38>,
#  'env': <simpy.core.Environment at 0x21a447c6b00>,
#  'sigma_d': 0.015,
#  'sigma_o': 0.1,
#  'sigma_p': 0.05,
#  'f_sett': 0.5,
#  'f_trap': 0.01,
#  'm_r': 0,
#  'soil': {},
#  'resource': <simpy.resources.resource.Resource at 0x21a44800cc0>,
#  'loading_func': <function __main__.compute_loading.<locals>.<lambda>(x)>,
#  'unloading_func': <function __main__.compute_unloading.<locals>.<lambda>(x)>,
#  'container': <simpy.resources.container.Container at 0x21a44800c50>,
#  'total_requested': 0,
#  'v': 1,
#  'wgs84': <pyproj.Geod at 0x21a447e0220>,
#  'compute_v': <function __main__.compute_v_provider.<locals>.<lambda>(x)>,
#  'log': {'Message': ['sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop',
#    'sailing empty start',
#    'sailing empty stop',
#    'loading start',
#    'loading stop',
#    'sailing full start',
#    'sailing full stop',
#    'unloading start',
#    'unloading stop'],
#   'Timestamp': [datetime.datetime(2019, 1, 1, 20, 0),
#    datetime.datetime(2019, 1, 2, 9, 59, 5, 76756),
#    datetime.datetime(2019, 1, 2, 9, 59, 5, 76756),
#    datetime.datetime(2019, 1, 2, 10, 5, 45, 76756),
#    datetime.datetime(2019, 1, 2, 10, 5, 45, 76756),
#    datetime.datetime(2019, 1, 2, 17, 36, 39, 111253),
#    datetime.datetime(2019, 1, 2, 17, 36, 39, 111253),
#    datetime.datetime(2019, 1, 2, 17, 43, 19, 111253),
#    datetime.datetime(2019, 1, 2, 17, 43, 19, 111253),
#    datetime.datetime(2019, 1, 3, 0, 29, 7, 742300),
#    datetime.datetime(2019, 1, 3, 0, 29, 7, 742300),
#    datetime.datetime(2019, 1, 3, 0, 35, 47, 742300),
#    datetime.datetime(2019, 1, 3, 0, 35, 47, 742300),
#    datetime.datetime(2019, 1, 3, 8, 6, 41, 776797),
#    datetime.datetime(2019, 1, 3, 8, 6, 41, 776797),
#    datetime.datetime(2019, 1, 3, 8, 13, 21, 776797),
#    datetime.datetime(2019, 1, 3, 8, 13, 21, 776797),
#    datetime.datetime(2019, 1, 3, 14, 59, 10, 407844),
#    datetime.datetime(2019, 1, 3, 14, 59, 10, 407844),
#    datetime.datetime(2019, 1, 3, 15, 5, 50, 407844),
#    datetime.datetime(2019, 1, 3, 15, 5, 50, 407844),
#    datetime.datetime(2019, 1, 3, 22, 36, 44, 442340),
#    datetime.datetime(2019, 1, 3, 22, 36, 44, 442340),
#    datetime.datetime(2019, 1, 3, 22, 43, 24, 442340),
#    datetime.datetime(2019, 1, 3, 22, 43, 24, 442340),
#    datetime.datetime(2019, 1, 4, 5, 29, 13, 73387),
#    datetime.datetime(2019, 1, 4, 5, 29, 13, 73387),
#    datetime.datetime(2019, 1, 4, 5, 35, 53, 73387),
#    datetime.datetime(2019, 1, 4, 5, 35, 53, 73387),
#    datetime.datetime(2019, 1, 4, 13, 6, 47, 107884),
#    datetime.datetime(2019, 1, 4, 13, 6, 47, 107884),
#    datetime.datetime(2019, 1, 4, 13, 13, 27, 107884),
#    datetime.datetime(2019, 1, 4, 13, 13, 27, 107884),
#    datetime.datetime(2019, 1, 4, 19, 59, 15, 738931),
#    datetime.datetime(2019, 1, 4, 19, 59, 15, 738931),
#    datetime.datetime(2019, 1, 4, 20, 5, 55, 738931),
#    datetime.datetime(2019, 1, 4, 20, 5, 55, 738931),
#    datetime.datetime(2019, 1, 5, 3, 36, 49, 773427),
#    datetime.datetime(2019, 1, 5, 3, 36, 49, 773427),
#    datetime.datetime(2019, 1, 5, 3, 43, 29, 773427),
#    datetime.datetime(2019, 1, 5, 3, 43, 29, 773427),
#    datetime.datetime(2019, 1, 5, 10, 29, 18, 404474),
#    datetime.datetime(2019, 1, 5, 10, 29, 18, 404474),
#    datetime.datetime(2019, 1, 5, 10, 35, 58, 404474),
#    datetime.datetime(2019, 1, 5, 10, 35, 58, 404474),
#    datetime.datetime(2019, 1, 5, 18, 6, 52, 438971),
#    datetime.datetime(2019, 1, 5, 18, 6, 52, 438971),
#    datetime.datetime(2019, 1, 5, 18, 13, 32, 438971),
#    datetime.datetime(2019, 1, 5, 18, 13, 32, 438971),
#    datetime.datetime(2019, 1, 6, 0, 59, 21, 70018),
#    datetime.datetime(2019, 1, 6, 0, 59, 21, 70018),
#    datetime.datetime(2019, 1, 6, 1, 6, 1, 70018),
#    datetime.datetime(2019, 1, 6, 1, 6, 1, 70018),
#    datetime.datetime(2019, 1, 6, 8, 36, 55, 104514),
#    datetime.datetime(2019, 1, 6, 8, 36, 55, 104514),
#    datetime.datetime(2019, 1, 6, 8, 43, 35, 104514),
#    datetime.datetime(2019, 1, 6, 8, 43, 35, 104514),
#    datetime.datetime(2019, 1, 6, 15, 29, 23, 735561),
#    datetime.datetime(2019, 1, 6, 15, 29, 23, 735561),
#    datetime.datetime(2019, 1, 6, 15, 36, 3, 735561),
#    datetime.datetime(2019, 1, 6, 15, 36, 3, 735561),
#    datetime.datetime(2019, 1, 6, 23, 6, 57, 770058),
#    datetime.datetime(2019, 1, 6, 23, 6, 57, 770058),
#    datetime.datetime(2019, 1, 6, 23, 13, 37, 770058),
#    datetime.datetime(2019, 1, 6, 23, 13, 37, 770058),
#    datetime.datetime(2019, 1, 7, 5, 59, 26, 401105),
#    datetime.datetime(2019, 1, 7, 5, 59, 26, 401105),
#    datetime.datetime(2019, 1, 7, 6, 6, 6, 401105),
#    datetime.datetime(2019, 1, 7, 6, 6, 6, 401105),
#    datetime.datetime(2019, 1, 7, 13, 37, 0, 435601),
#    datetime.datetime(2019, 1, 7, 13, 37, 0, 435601),
#    datetime.datetime(2019, 1, 7, 13, 43, 40, 435601),
#    datetime.datetime(2019, 1, 7, 13, 43, 40, 435601),
#    datetime.datetime(2019, 1, 7, 20, 29, 29, 66648),
#    datetime.datetime(2019, 1, 7, 20, 29, 29, 66648),
#    datetime.datetime(2019, 1, 7, 20, 36, 9, 66648),
#    datetime.datetime(2019, 1, 7, 20, 36, 9, 66648),
#    datetime.datetime(2019, 1, 8, 4, 7, 3, 101145),
#    datetime.datetime(2019, 1, 8, 4, 7, 3, 101145),
#    datetime.datetime(2019, 1, 8, 4, 13, 43, 101145),
#    datetime.datetime(2019, 1, 8, 4, 13, 43, 101145),
#    datetime.datetime(2019, 1, 8, 10, 59, 31, 732192),
#    datetime.datetime(2019, 1, 8, 10, 59, 31, 732192),
#    datetime.datetime(2019, 1, 8, 11, 6, 11, 732192),
#    datetime.datetime(2019, 1, 8, 11, 6, 11, 732192),
#    datetime.datetime(2019, 1, 8, 18, 37, 5, 766689),
#    datetime.datetime(2019, 1, 8, 18, 37, 5, 766689),
#    datetime.datetime(2019, 1, 8, 18, 43, 45, 766689),
#    datetime.datetime(2019, 1, 8, 18, 43, 45, 766689),
#    datetime.datetime(2019, 1, 9, 1, 29, 34, 397736),
#    datetime.datetime(2019, 1, 9, 1, 29, 34, 397736),
#    datetime.datetime(2019, 1, 9, 1, 36, 14, 397736),
#    datetime.datetime(2019, 1, 9, 1, 36, 14, 397736),
#    datetime.datetime(2019, 1, 9, 9, 7, 8, 432232),
#    datetime.datetime(2019, 1, 9, 9, 7, 8, 432232),
#    datetime.datetime(2019, 1, 9, 9, 13, 48, 432232),
#    datetime.datetime(2019, 1, 9, 9, 13, 48, 432232),
#    datetime.datetime(2019, 1, 9, 15, 59, 37, 63279),
#    datetime.datetime(2019, 1, 9, 15, 59, 37, 63279),
#    datetime.datetime(2019, 1, 9, 16, 6, 17, 63279),
#    datetime.datetime(2019, 1, 9, 16, 6, 17, 63279),
#    datetime.datetime(2019, 1, 9, 23, 37, 11, 97776),
#    datetime.datetime(2019, 1, 9, 23, 37, 11, 97776),
#    datetime.datetime(2019, 1, 9, 23, 43, 51, 97776),
#    datetime.datetime(2019, 1, 9, 23, 43, 51, 97776),
#    datetime.datetime(2019, 1, 10, 6, 29, 39, 728823),
#    datetime.datetime(2019, 1, 10, 6, 29, 39, 728823),
#    datetime.datetime(2019, 1, 10, 6, 36, 19, 728823),
#    datetime.datetime(2019, 1, 10, 6, 36, 19, 728823),
#    datetime.datetime(2019, 1, 10, 14, 7, 13, 763319),
#    datetime.datetime(2019, 1, 10, 14, 7, 13, 763319),
#    datetime.datetime(2019, 1, 10, 14, 13, 53, 763319),
#    datetime.datetime(2019, 1, 10, 14, 13, 53, 763319),
#    datetime.datetime(2019, 1, 10, 20, 59, 42, 394366),
#    datetime.datetime(2019, 1, 10, 20, 59, 42, 394366),
#    datetime.datetime(2019, 1, 10, 21, 6, 22, 394366),
#    datetime.datetime(2019, 1, 10, 21, 6, 22, 394366),
#    datetime.datetime(2019, 1, 11, 4, 37, 16, 428863),
#    datetime.datetime(2019, 1, 11, 4, 37, 16, 428863),
#    datetime.datetime(2019, 1, 11, 4, 43, 56, 428863),
#    datetime.datetime(2019, 1, 11, 4, 43, 56, 428863),
#    datetime.datetime(2019, 1, 11, 11, 29, 45, 59910),
#    datetime.datetime(2019, 1, 11, 11, 29, 45, 59910),
#    datetime.datetime(2019, 1, 11, 11, 36, 25, 59910),
#    datetime.datetime(2019, 1, 11, 11, 36, 25, 59910),
#    datetime.datetime(2019, 1, 11, 19, 7, 19, 94406),
#    datetime.datetime(2019, 1, 11, 19, 7, 19, 94406),
#    datetime.datetime(2019, 1, 11, 19, 13, 59, 94406),
#    datetime.datetime(2019, 1, 11, 19, 13, 59, 94406),
#    datetime.datetime(2019, 1, 12, 1, 59, 47, 725453),
#    datetime.datetime(2019, 1, 12, 1, 59, 47, 725453),
#    datetime.datetime(2019, 1, 12, 2, 6, 27, 725453),
#    datetime.datetime(2019, 1, 12, 2, 6, 27, 725453),
#    datetime.datetime(2019, 1, 12, 9, 37, 21, 759950),
#    datetime.datetime(2019, 1, 12, 9, 37, 21, 759950),
#    datetime.datetime(2019, 1, 12, 9, 44, 1, 759950),
#    datetime.datetime(2019, 1, 12, 9, 44, 1, 759950),
#    datetime.datetime(2019, 1, 12, 16, 29, 50, 390997),
#    datetime.datetime(2019, 1, 12, 17, 27, 40, 664020),
#    datetime.datetime(2019, 1, 12, 17, 34, 20, 664020),
#    datetime.datetime(2019, 1, 12, 17, 34, 20, 664020),
#    datetime.datetime(2019, 1, 13, 1, 5, 14, 698516),
#    datetime.datetime(2019, 1, 13, 1, 5, 14, 698516),
#    datetime.datetime(2019, 1, 13, 1, 11, 54, 698516),
#    datetime.datetime(2019, 1, 13, 1, 11, 54, 698516),
#    datetime.datetime(2019, 1, 13, 7, 57, 43, 329563),
#    datetime.datetime(2019, 1, 13, 7, 57, 43, 329563),
#    datetime.datetime(2019, 1, 13, 8, 4, 23, 329563),
#    datetime.datetime(2019, 1, 13, 8, 4, 23, 329563),
#    datetime.datetime(2019, 1, 13, 15, 35, 17, 364060),
#    datetime.datetime(2019, 1, 13, 15, 35, 17, 364060),
#    datetime.datetime(2019, 1, 13, 15, 41, 57, 364060),
#    datetime.datetime(2019, 1, 13, 15, 41, 57, 364060),
#    datetime.datetime(2019, 1, 13, 22, 27, 45, 995107),
#    datetime.datetime(2019, 1, 13, 22, 27, 45, 995107),
#    datetime.datetime(2019, 1, 13, 22, 34, 25, 995107),
#    datetime.datetime(2019, 1, 13, 22, 34, 25, 995107),
#    datetime.datetime(2019, 1, 14, 6, 5, 20, 29603),
#    datetime.datetime(2019, 1, 14, 6, 5, 20, 29603),
#    datetime.datetime(2019, 1, 14, 6, 12, 0, 29603),
#    datetime.datetime(2019, 1, 14, 6, 12, 0, 29603),
#    datetime.datetime(2019, 1, 14, 12, 57, 48, 660650),
#    datetime.datetime(2019, 1, 14, 12, 57, 48, 660650),
#    datetime.datetime(2019, 1, 14, 13, 4, 28, 660650),
#    datetime.datetime(2019, 1, 14, 13, 4, 28, 660650),
#    datetime.datetime(2019, 1, 14, 20, 35, 22, 695147),
#    datetime.datetime(2019, 1, 14, 20, 35, 22, 695147),
#    datetime.datetime(2019, 1, 14, 20, 42, 2, 695147),
#    datetime.datetime(2019, 1, 14, 20, 42, 2, 695147),
#    datetime.datetime(2019, 1, 15, 3, 27, 51, 326194),
#    datetime.datetime(2019, 1, 15, 3, 27, 51, 326194),
#    datetime.datetime(2019, 1, 15, 3, 34, 31, 326194),
#    datetime.datetime(2019, 1, 15, 3, 34, 31, 326194),
#    datetime.datetime(2019, 1, 15, 11, 5, 25, 360690),
#    datetime.datetime(2019, 1, 15, 11, 5, 25, 360690),
#    datetime.datetime(2019, 1, 15, 11, 12, 5, 360690),
#    datetime.datetime(2019, 1, 15, 11, 12, 5, 360690),
#    datetime.datetime(2019, 1, 15, 17, 57, 53, 991737),
#    datetime.datetime(2019, 1, 15, 19, 19, 22, 99214),
#    datetime.datetime(2019, 1, 15, 19, 26, 2, 99214),
#    datetime.datetime(2019, 1, 15, 19, 26, 2, 99214),
#    datetime.datetime(2019, 1, 16, 2, 56, 56, 133710),
#    datetime.datetime(2019, 1, 16, 2, 56, 56, 133710),
#    datetime.datetime(2019, 1, 16, 3, 3, 36, 133710),
#    datetime.datetime(2019, 1, 16, 3, 3, 36, 133710),
#    datetime.datetime(2019, 1, 16, 9, 49, 24, 764757),
#    datetime.datetime(2019, 1, 16, 9, 49, 24, 764757),
#    datetime.datetime(2019, 1, 16, 9, 56, 4, 764757),
#    datetime.datetime(2019, 1, 16, 9, 56, 4, 764757),
#    datetime.datetime(2019, 1, 16, 17, 26, 58, 799254),
#    datetime.datetime(2019, 1, 16, 17, 26, 58, 799254),
#    datetime.datetime(2019, 1, 16, 17, 33, 38, 799254),
#    datetime.datetime(2019, 1, 16, 17, 33, 38, 799254),
#    datetime.datetime(2019, 1, 17, 0, 19, 27, 430301),
#    datetime.datetime(2019, 1, 17, 0, 19, 27, 430301),
#    datetime.datetime(2019, 1, 17, 0, 26, 7, 430301),
#    datetime.datetime(2019, 1, 17, 0, 26, 7, 430301),
#    datetime.datetime(2019, 1, 17, 7, 57, 1, 464797),
#    datetime.datetime(2019, 1, 17, 7, 57, 1, 464797),
#    datetime.datetime(2019, 1, 17, 8, 3, 41, 464797),
#    datetime.datetime(2019, 1, 17, 8, 3, 41, 464797),
#    datetime.datetime(2019, 1, 17, 14, 49, 30, 95844),
#    datetime.datetime(2019, 1, 17, 14, 49, 30, 95844),
#    datetime.datetime(2019, 1, 17, 14, 56, 10, 95844),
#    datetime.datetime(2019, 1, 17, 14, 56, 10, 95844),
#    datetime.datetime(2019, 1, 17, 22, 27, 4, 130341),
#    datetime.datetime(2019, 1, 17, 22, 27, 4, 130341),
#    datetime.datetime(2019, 1, 17, 22, 33, 44, 130341),
#    datetime.datetime(2019, 1, 17, 22, 33, 44, 130341),
#    datetime.datetime(2019, 1, 18, 5, 19, 32, 761388),
#    datetime.datetime(2019, 1, 18, 5, 19, 32, 761388),
#    datetime.datetime(2019, 1, 18, 5, 26, 12, 761388),
#    datetime.datetime(2019, 1, 18, 5, 26, 12, 761388),
#    datetime.datetime(2019, 1, 18, 12, 57, 6, 795884),
#    datetime.datetime(2019, 1, 18, 12, 57, 6, 795884),
#    datetime.datetime(2019, 1, 18, 13, 3, 46, 795884),
#    datetime.datetime(2019, 1, 18, 13, 3, 46, 795884),
#    datetime.datetime(2019, 1, 18, 19, 49, 35, 426931),
#    datetime.datetime(2019, 1, 18, 21, 11, 3, 534408),
#    datetime.datetime(2019, 1, 18, 21, 17, 43, 534408),
#    datetime.datetime(2019, 1, 18, 21, 17, 43, 534408),
#    datetime.datetime(2019, 1, 19, 4, 48, 37, 568904),
#    datetime.datetime(2019, 1, 19, 4, 48, 37, 568904),
#    datetime.datetime(2019, 1, 19, 4, 55, 17, 568904),
#    datetime.datetime(2019, 1, 19, 4, 55, 17, 568904),
#    datetime.datetime(2019, 1, 19, 11, 41, 6, 199951),
#    datetime.datetime(2019, 1, 19, 11, 41, 6, 199951),
#    datetime.datetime(2019, 1, 19, 11, 47, 46, 199951),
#    datetime.datetime(2019, 1, 19, 11, 47, 46, 199951),
#    datetime.datetime(2019, 1, 19, 19, 18, 40, 234448),
#    datetime.datetime(2019, 1, 19, 19, 18, 40, 234448),
#    datetime.datetime(2019, 1, 19, 19, 25, 20, 234448),
#    datetime.datetime(2019, 1, 19, 19, 25, 20, 234448),
#    datetime.datetime(2019, 1, 20, 2, 11, 8, 865495),
#    datetime.datetime(2019, 1, 20, 2, 11, 8, 865495),
#    datetime.datetime(2019, 1, 20, 2, 17, 48, 865495),
#    datetime.datetime(2019, 1, 20, 2, 17, 48, 865495),
#    datetime.datetime(2019, 1, 20, 9, 48, 42, 899991),
#    datetime.datetime(2019, 1, 20, 9, 48, 42, 899991),
#    datetime.datetime(2019, 1, 20, 9, 55, 22, 899991),
#    datetime.datetime(2019, 1, 20, 9, 55, 22, 899991),
#    datetime.datetime(2019, 1, 20, 16, 41, 11, 531038),
#    datetime.datetime(2019, 1, 20, 16, 41, 11, 531038),
#    datetime.datetime(2019, 1, 20, 16, 47, 51, 531038),
#    datetime.datetime(2019, 1, 20, 16, 47, 51, 531038),
#    datetime.datetime(2019, 1, 21, 0, 18, 45, 565535),
#    datetime.datetime(2019, 1, 21, 0, 18, 45, 565535),
#    datetime.datetime(2019, 1, 21, 0, 25, 25, 565535),
#    datetime.datetime(2019, 1, 21, 0, 25, 25, 565535),
#    datetime.datetime(2019, 1, 21, 7, 11, 14, 196582),
#    datetime.datetime(2019, 1, 21, 7, 11, 14, 196582),
#    datetime.datetime(2019, 1, 21, 7, 17, 54, 196582),
#    datetime.datetime(2019, 1, 21, 7, 17, 54, 196582),
#    datetime.datetime(2019, 1, 21, 14, 48, 48, 231078),
#    datetime.datetime(2019, 1, 21, 14, 48, 48, 231078),
#    datetime.datetime(2019, 1, 21, 14, 55, 28, 231078),
#    datetime.datetime(2019, 1, 21, 14, 55, 28, 231078),
#    datetime.datetime(2019, 1, 21, 21, 41, 16, 862125),
#    datetime.datetime(2019, 1, 21, 23, 2, 44, 969602),
#    datetime.datetime(2019, 1, 21, 23, 9, 24, 969602),
#    datetime.datetime(2019, 1, 21, 23, 9, 24, 969602),
#    datetime.datetime(2019, 1, 22, 6, 40, 19, 4098),
#    datetime.datetime(2019, 1, 22, 6, 40, 19, 4098),
#    datetime.datetime(2019, 1, 22, 6, 46, 59, 4098),
#    datetime.datetime(2019, 1, 22, 6, 46, 59, 4098),
#    datetime.datetime(2019, 1, 22, 13, 32, 47, 635145),
#    datetime.datetime(2019, 1, 22, 13, 32, 47, 635145),
#    datetime.datetime(2019, 1, 22, 13, 39, 27, 635145),
#    datetime.datetime(2019, 1, 22, 13, 39, 27, 635145),
#    datetime.datetime(2019, 1, 22, 21, 10, 21, 669642),
#    datetime.datetime(2019, 1, 22, 21, 10, 21, 669642),
#    datetime.datetime(2019, 1, 22, 21, 17, 1, 669642),
#    datetime.datetime(2019, 1, 22, 21, 17, 1, 669642),
#    datetime.datetime(2019, 1, 23, 4, 2, 50, 300689),
#    datetime.datetime(2019, 1, 23, 4, 2, 50, 300689),
#    datetime.datetime(2019, 1, 23, 4, 9, 30, 300689),
#    datetime.datetime(2019, 1, 23, 4, 9, 30, 300689),
#    datetime.datetime(2019, 1, 23, 11, 40, 24, 335185),
#    datetime.datetime(2019, 1, 23, 11, 40, 24, 335185),
#    datetime.datetime(2019, 1, 23, 11, 47, 4, 335185),
#    datetime.datetime(2019, 1, 23, 11, 47, 4, 335185),
#    datetime.datetime(2019, 1, 23, 18, 32, 52, 966232),
#    datetime.datetime(2019, 1, 23, 18, 32, 52, 966232),
#    datetime.datetime(2019, 1, 23, 18, 39, 32, 966232),
#    datetime.datetime(2019, 1, 23, 18, 39, 32, 966232),
#    datetime.datetime(2019, 1, 24, 2, 10, 27, 729),
#    datetime.datetime(2019, 1, 24, 2, 10, 27, 729),
#    datetime.datetime(2019, 1, 24, 2, 17, 7, 729),
#    datetime.datetime(2019, 1, 24, 2, 17, 7, 729),
#    datetime.datetime(2019, 1, 24, 9, 2, 55, 631776),
#    datetime.datetime(2019, 1, 24, 9, 2, 55, 631776),
#    datetime.datetime(2019, 1, 24, 9, 9, 35, 631776),
#    datetime.datetime(2019, 1, 24, 9, 9, 35, 631776),
#    datetime.datetime(2019, 1, 24, 16, 40, 29, 666272),
#    datetime.datetime(2019, 1, 24, 16, 40, 29, 666272),
#    datetime.datetime(2019, 1, 24, 16, 47, 9, 666272),
#    datetime.datetime(2019, 1, 24, 16, 47, 9, 666272),
#    datetime.datetime(2019, 1, 24, 23, 32, 58, 297319),
#    datetime.datetime(2019, 1, 25, 0, 54, 26, 404796),
#    datetime.datetime(2019, 1, 25, 1, 1, 6, 404796),
#    datetime.datetime(2019, 1, 25, 1, 1, 6, 404796),
#    datetime.datetime(2019, 1, 25, 8, 32, 0, 439292),
#    datetime.datetime(2019, 1, 25, 8, 32, 0, 439292),
#    datetime.datetime(2019, 1, 25, 8, 38, 40, 439292),
#    datetime.datetime(2019, 1, 25, 8, 38, 40, 439292),
#    datetime.datetime(2019, 1, 25, 15, 24, 29, 70339),
#    datetime.datetime(2019, 1, 25, 15, 24, 29, 70339),
#    datetime.datetime(2019, 1, 25, 15, 31, 9, 70339),
#    datetime.datetime(2019, 1, 25, 15, 31, 9, 70339),
#    datetime.datetime(2019, 1, 25, 23, 2, 3, 104836),
#    datetime.datetime(2019, 1, 25, 23, 2, 3, 104836),
#    datetime.datetime(2019, 1, 25, 23, 8, 43, 104836),
#    datetime.datetime(2019, 1, 25, 23, 8, 43, 104836),
#    datetime.datetime(2019, 1, 26, 5, 54, 31, 735883),
#    datetime.datetime(2019, 1, 26, 5, 54, 31, 735883),
#    datetime.datetime(2019, 1, 26, 6, 1, 11, 735883),
#    datetime.datetime(2019, 1, 26, 6, 1, 11, 735883),
#    datetime.datetime(2019, 1, 26, 13, 32, 5, 770379),
#    datetime.datetime(2019, 1, 26, 13, 32, 5, 770379),
#    datetime.datetime(2019, 1, 26, 13, 38, 45, 770379),
#    datetime.datetime(2019, 1, 26, 13, 38, 45, 770379),
#    datetime.datetime(2019, 1, 26, 20, 24, 34, 401426),
#    datetime.datetime(2019, 1, 26, 20, 24, 34, 401426),
#    datetime.datetime(2019, 1, 26, 20, 31, 14, 401426),
#    datetime.datetime(2019, 1, 26, 20, 31, 14, 401426),
#    datetime.datetime(2019, 1, 27, 4, 2, 8, 435923),
#    datetime.datetime(2019, 1, 27, 4, 2, 8, 435923),
#    datetime.datetime(2019, 1, 27, 4, 8, 48, 435923),
#    datetime.datetime(2019, 1, 27, 4, 8, 48, 435923),
#    datetime.datetime(2019, 1, 27, 10, 54, 37, 66970),
#    datetime.datetime(2019, 1, 27, 10, 54, 37, 66970),
#    datetime.datetime(2019, 1, 27, 11, 1, 17, 66970),
#    datetime.datetime(2019, 1, 27, 11, 1, 17, 66970),
#    datetime.datetime(2019, 1, 27, 18, 32, 11, 101466),
#    datetime.datetime(2019, 1, 27, 18, 32, 11, 101466),
#    datetime.datetime(2019, 1, 27, 18, 38, 51, 101466),
#    datetime.datetime(2019, 1, 27, 18, 38, 51, 101466),
#    datetime.datetime(2019, 1, 28, 1, 24, 39, 732513),
#    datetime.datetime(2019, 1, 28, 2, 46, 7, 839990),
#    datetime.datetime(2019, 1, 28, 2, 52, 47, 839990),
#    datetime.datetime(2019, 1, 28, 2, 52, 47, 839990),
#    datetime.datetime(2019, 1, 28, 10, 23, 41, 874486),
#    datetime.datetime(2019, 1, 28, 10, 23, 41, 874486),
#    datetime.datetime(2019, 1, 28, 10, 30, 21, 874486),
#    datetime.datetime(2019, 1, 28, 10, 30, 21, 874486),
#    datetime.datetime(2019, 1, 28, 17, 16, 10, 505533),
#    datetime.datetime(2019, 1, 28, 17, 16, 10, 505533),
#    datetime.datetime(2019, 1, 28, 17, 22, 50, 505533),
#    datetime.datetime(2019, 1, 28, 17, 22, 50, 505533),
#    datetime.datetime(2019, 1, 29, 0, 53, 44, 540030),
#    datetime.datetime(2019, 1, 29, 0, 53, 44, 540030),
#    datetime.datetime(2019, 1, 29, 1, 0, 24, 540030),
#    datetime.datetime(2019, 1, 29, 1, 0, 24, 540030),
#    datetime.datetime(2019, 1, 29, 7, 46, 13, 171077),
#    datetime.datetime(2019, 1, 29, 7, 46, 13, 171077),
#    datetime.datetime(2019, 1, 29, 7, 52, 53, 171077),
#    datetime.datetime(2019, 1, 29, 7, 52, 53, 171077),
#    datetime.datetime(2019, 1, 29, 15, 23, 47, 205573),
#    datetime.datetime(2019, 1, 29, 15, 23, 47, 205573),
#    datetime.datetime(2019, 1, 29, 15, 30, 27, 205573),
#    datetime.datetime(2019, 1, 29, 15, 30, 27, 205573),
#    datetime.datetime(2019, 1, 29, 22, 16, 15, 836620),
#    datetime.datetime(2019, 1, 29, 22, 16, 15, 836620),
#    datetime.datetime(2019, 1, 29, 22, 22, 55, 836620),
#    datetime.datetime(2019, 1, 29, 22, 22, 55, 836620),
#    datetime.datetime(2019, 1, 30, 5, 53, 49, 871117),
#    datetime.datetime(2019, 1, 30, 5, 53, 49, 871117),
#    datetime.datetime(2019, 1, 30, 6, 0, 29, 871117),
#    datetime.datetime(2019, 1, 30, 6, 0, 29, 871117),
#    datetime.datetime(2019, 1, 30, 12, 46, 18, 502164),
#    datetime.datetime(2019, 1, 30, 12, 46, 18, 502164),
#    datetime.datetime(2019, 1, 30, 12, 52, 58, 502164),
#    datetime.datetime(2019, 1, 30, 12, 52, 58, 502164),
#    datetime.datetime(2019, 1, 30, 20, 23, 52, 536660),
#    datetime.datetime(2019, 1, 30, 20, 23, 52, 536660),
#    datetime.datetime(2019, 1, 30, 20, 30, 32, 536660),
#    datetime.datetime(2019, 1, 30, 20, 30, 32, 536660),
#    datetime.datetime(2019, 1, 31, 3, 16, 21, 167707),
#    datetime.datetime(2019, 1, 31, 4, 37, 49, 275184),
#    datetime.datetime(2019, 1, 31, 4, 44, 29, 275184),
#    datetime.datetime(2019, 1, 31, 4, 44, 29, 275184),
#    datetime.datetime(2019, 1, 31, 12, 15, 23, 309680),
#    datetime.datetime(2019, 1, 31, 12, 15, 23, 309680),
#    datetime.datetime(2019, 1, 31, 12, 22, 3, 309680),
#    datetime.datetime(2019, 1, 31, 12, 22, 3, 309680),
#    datetime.datetime(2019, 1, 31, 19, 7, 51, 940727),
#    datetime.datetime(2019, 1, 31, 19, 7, 51, 940727),
#    datetime.datetime(2019, 1, 31, 19, 14, 31, 940727),
#    datetime.datetime(2019, 1, 31, 19, 14, 31, 940727),
#    datetime.datetime(2019, 2, 1, 2, 45, 25, 975224),
#    datetime.datetime(2019, 2, 1, 2, 45, 25, 975224),
#    datetime.datetime(2019, 2, 1, 2, 52, 5, 975224),
#    datetime.datetime(2019, 2, 1, 2, 52, 5, 975224),
#    datetime.datetime(2019, 2, 1, 9, 37, 54, 606271),
#    datetime.datetime(2019, 2, 1, 9, 37, 54, 606271),
#    datetime.datetime(2019, 2, 1, 9, 44, 34, 606271),
#    datetime.datetime(2019, 2, 1, 9, 44, 34, 606271),
#    datetime.datetime(2019, 2, 1, 17, 15, 28, 640767),
#    datetime.datetime(2019, 2, 1, 17, 15, 28, 640767),
#    datetime.datetime(2019, 2, 1, 17, 22, 8, 640767),
#    datetime.datetime(2019, 2, 1, 17, 22, 8, 640767),
#    datetime.datetime(2019, 2, 2, 0, 7, 57, 271814),
#    datetime.datetime(2019, 2, 2, 0, 7, 57, 271814),
#    datetime.datetime(2019, 2, 2, 0, 14, 37, 271814),
#    datetime.datetime(2019, 2, 2, 0, 14, 37, 271814),
#    datetime.datetime(2019, 2, 2, 7, 45, 31, 306311),
#    datetime.datetime(2019, 2, 2, 7, 45, 31, 306311),
#    datetime.datetime(2019, 2, 2, 7, 52, 11, 306311),
#    datetime.datetime(2019, 2, 2, 7, 52, 11, 306311),
#    datetime.datetime(2019, 2, 2, 14, 37, 59, 937358),
#    datetime.datetime(2019, 2, 2, 14, 37, 59, 937358),
#    datetime.datetime(2019, 2, 2, 14, 44, 39, 937358),
#    datetime.datetime(2019, 2, 2, 14, 44, 39, 937358),
#    datetime.datetime(2019, 2, 2, 22, 15, 33, 971854),
#    datetime.datetime(2019, 2, 2, 22, 15, 33, 971854),
#    datetime.datetime(2019, 2, 2, 22, 22, 13, 971854),
#    datetime.datetime(2019, 2, 2, 22, 22, 13, 971854),
#    datetime.datetime(2019, 2, 3, 5, 8, 2, 602901),
#    datetime.datetime(2019, 2, 3, 6, 29, 30, 710378),
#    datetime.datetime(2019, 2, 3, 6, 36, 10, 710378),
#    datetime.datetime(2019, 2, 3, 6, 36, 10, 710378),
#    datetime.datetime(2019, 2, 3, 14, 7, 4, 744874),
#    datetime.datetime(2019, 2, 3, 14, 7, 4, 744874),
#    datetime.datetime(2019, 2, 3, 14, 13, 44, 744874),
#    datetime.datetime(2019, 2, 3, 14, 13, 44, 744874),
#    datetime.datetime(2019, 2, 3, 20, 59, 33, 375921),
#    datetime.datetime(2019, 2, 3, 20, 59, 33, 375921),
#    datetime.datetime(2019, 2, 3, 21, 6, 13, 375921),
#    datetime.datetime(2019, 2, 3, 21, 6, 13, 375921),
#    datetime.datetime(2019, 2, 4, 4, 37, 7, 410418),
#    datetime.datetime(2019, 2, 4, 4, 37, 7, 410418),
#    datetime.datetime(2019, 2, 4, 4, 43, 47, 410418),
#    datetime.datetime(2019, 2, 4, 4, 43, 47, 410418),
#    datetime.datetime(2019, 2, 4, 11, 29, 36, 41465),
#    datetime.datetime(2019, 2, 4, 11, 29, 36, 41465),
#    datetime.datetime(2019, 2, 4, 11, 36, 16, 41465),
#    datetime.datetime(2019, 2, 4, 11, 36, 16, 41465),
#    datetime.datetime(2019, 2, 4, 19, 7, 10, 75961),
#    datetime.datetime(2019, 2, 4, 19, 7, 10, 75961),
#    datetime.datetime(2019, 2, 4, 19, 13, 50, 75961),
#    datetime.datetime(2019, 2, 4, 19, 13, 50, 75961),
#    datetime.datetime(2019, 2, 5, 1, 59, 38, 707008),
#    datetime.datetime(2019, 2, 5, 1, 59, 38, 707008),
#    datetime.datetime(2019, 2, 5, 2, 6, 18, 707008),
#    datetime.datetime(2019, 2, 5, 2, 6, 18, 707008),
#    datetime.datetime(2019, 2, 5, 9, 37, 12, 741505),
#    datetime.datetime(2019, 2, 5, 9, 37, 12, 741505),
#    datetime.datetime(2019, 2, 5, 9, 43, 52, 741505),
#    datetime.datetime(2019, 2, 5, 9, 43, 52, 741505),
#    datetime.datetime(2019, 2, 5, 16, 29, 41, 372552),
#    datetime.datetime(2019, 2, 5, 16, 29, 41, 372552),
#    datetime.datetime(2019, 2, 5, 16, 36, 21, 372552),
#    datetime.datetime(2019, 2, 5, 16, 36, 21, 372552),
#    datetime.datetime(2019, 2, 6, 0, 7, 15, 407048),
#    datetime.datetime(2019, 2, 6, 0, 7, 15, 407048),
#    datetime.datetime(2019, 2, 6, 0, 13, 55, 407048),
#    datetime.datetime(2019, 2, 6, 0, 13, 55, 407048),
#    datetime.datetime(2019, 2, 6, 6, 59, 44, 38095),
#    datetime.datetime(2019, 2, 6, 8, 21, 12, 145572),
#    datetime.datetime(2019, 2, 6, 8, 27, 52, 145572),
#    datetime.datetime(2019, 2, 6, 8, 27, 52, 145572),
#    datetime.datetime(2019, 2, 6, 15, 58, 46, 180068),
#    datetime.datetime(2019, 2, 6, 15, 58, 46, 180068),
#    datetime.datetime(2019, 2, 6, 16, 5, 26, 180068),
#    datetime.datetime(2019, 2, 6, 16, 5, 26, 180068),
#    datetime.datetime(2019, 2, 6, 22, 51, 14, 811115),
#    datetime.datetime(2019, 2, 6, 22, 51, 14, 811115),
#    datetime.datetime(2019, 2, 6, 22, 57, 54, 811115),
#    datetime.datetime(2019, 2, 6, 22, 57, 54, 811115),
#    datetime.datetime(2019, 2, 7, 6, 28, 48, 845612),
#    datetime.datetime(2019, 2, 7, 6, 28, 48, 845612),
#    datetime.datetime(2019, 2, 7, 6, 35, 28, 845612),
#    datetime.datetime(2019, 2, 7, 6, 35, 28, 845612),
#    datetime.datetime(2019, 2, 7, 13, 21, 17, 476659),
#    datetime.datetime(2019, 2, 7, 13, 21, 17, 476659),
#    datetime.datetime(2019, 2, 7, 13, 27, 57, 476659),
#    datetime.datetime(2019, 2, 7, 13, 27, 57, 476659),
#    datetime.datetime(2019, 2, 7, 20, 58, 51, 511155),
#    datetime.datetime(2019, 2, 7, 20, 58, 51, 511155),
#    datetime.datetime(2019, 2, 7, 21, 5, 31, 511155),
#    datetime.datetime(2019, 2, 7, 21, 5, 31, 511155),
#    datetime.datetime(2019, 2, 8, 3, 51, 20, 142202),
#    datetime.datetime(2019, 2, 8, 3, 51, 20, 142202),
#    datetime.datetime(2019, 2, 8, 3, 58, 0, 142202),
#    datetime.datetime(2019, 2, 8, 3, 58, 0, 142202),
#    datetime.datetime(2019, 2, 8, 11, 28, 54, 176699),
#    datetime.datetime(2019, 2, 8, 11, 28, 54, 176699),
#    datetime.datetime(2019, 2, 8, 11, 35, 34, 176699),
#    datetime.datetime(2019, 2, 8, 11, 35, 34, 176699),
#    datetime.datetime(2019, 2, 8, 18, 21, 22, 807746),
#    datetime.datetime(2019, 2, 8, 18, 21, 22, 807746),
#    datetime.datetime(2019, 2, 8, 18, 28, 2, 807746),
#    datetime.datetime(2019, 2, 8, 18, 28, 2, 807746),
#    datetime.datetime(2019, 2, 9, 1, 58, 56, 842242),
#    datetime.datetime(2019, 2, 9, 1, 58, 56, 842242),
#    datetime.datetime(2019, 2, 9, 2, 5, 36, 842242),
#    datetime.datetime(2019, 2, 9, 2, 5, 36, 842242),
#    datetime.datetime(2019, 2, 9, 8, 51, 25, 473289),
# ...
#    <shapely.geometry.point.PointAdapter at 0x21a447ed320>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed390>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed390>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed390>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed390>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed518>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed518>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed518>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed518>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed160>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed160>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed160>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed160>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed198>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed198>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed198>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed198>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed3c8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed3c8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed3c8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed3c8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed080>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed080>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed080>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed080>,
#    <shapely.geometry.point.PointAdapter at 0x21a447f3208>,
#    <shapely.geometry.point.PointAdapter at 0x21a447f3208>,
#    <shapely.geometry.point.PointAdapter at 0x21a447f3208>,
#    <shapely.geometry.point.PointAdapter at 0x21a447f3208>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed048>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed048>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed048>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed048>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8eb8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8eb8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8eb8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8eb8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8898>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8898>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8898>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8898>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e83c8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e83c8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e83c8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e83c8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8cf8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8cf8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8cf8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8cf8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8d30>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8d30>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8d30>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8d30>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed2b0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed2b0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed2b0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447ed2b0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b00>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b00>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b00>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b00>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8f60>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8f60>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8f60>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8f60>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8cc0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8cc0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8cc0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8cc0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8940>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8940>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8940>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8940>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8e48>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8e48>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8e48>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8e48>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8ef0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8ef0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8ef0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8ef0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8e80>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8e80>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8e80>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8e80>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8ba8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8ba8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8ba8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8ba8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8a20>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8a20>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8a20>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8a20>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b38>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b38>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b38>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b38>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8588>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8588>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8588>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8588>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8160>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8160>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8160>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8160>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8da0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8da0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8da0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8da0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8d68>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8d68>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8d68>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8d68>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b70>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b70>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b70>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8b70>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8860>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8860>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8860>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8860>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8908>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8908>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8908>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8908>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8c18>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8c18>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8c18>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8c18>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8c50>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8c50>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8c50>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8c50>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8710>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8710>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8710>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8710>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8a58>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8a58>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8a58>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8a58>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e85c0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e85c0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e85c0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e85c0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8780>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8780>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8780>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8780>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e88d0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e88d0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e88d0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e88d0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e86d8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e86d8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e86d8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e86d8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e89e8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e89e8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e89e8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e89e8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8978>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8978>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8978>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8978>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e87f0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e87f0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e87f0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e87f0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8828>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8828>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8828>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8828>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8390>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8390>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8390>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8390>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8550>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8550>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8550>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8550>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8208>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8208>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8208>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8208>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8400>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8400>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8400>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8400>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8518>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8518>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8518>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8518>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8320>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8320>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8320>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8320>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8668>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8668>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8668>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8668>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e85f8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e85f8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e85f8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e85f8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8470>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8470>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8470>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8470>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e84a8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e84a8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e84a8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e84a8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e80f0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e80f0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e80f0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e80f0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8198>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8198>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8198>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8198>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e82b0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e82b0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e82b0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e82b0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447f3240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447f3240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447f3240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447f3240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e8240>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6f60>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6f60>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6f60>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6f60>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6d68>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6d68>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6d68>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6d68>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6748>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6748>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6748>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6748>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6940>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6940>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6940>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6940>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6e10>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6e10>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6e10>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6e10>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e80b8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e80b8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e80b8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e80b8>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6cc0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6cc0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6cc0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6cc0>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6b38>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6b38>,
#    <shapely.geometry.point.PointAdapter at 0x21a447e6b38>]},
#  'name': 'Container small',
#  'id': '93f52215-2973-11e9-8cbb-b469212bff5b',
#  'rate': <function __main__.compute_unloading.<locals>.<lambda>(x)>}

# %%
vessels = [container_large, container_small]

activities = ['loading', 'unloading', 'sailing full', 'sailing empty']
colors = {0:'rgb(55,126,184)', 1:'rgb(255,150,0)', 2:'rgb(98, 192, 122)', 3:'rgb(98, 141, 122)'}

plot.vessel_planning(vessels, activities, colors)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="6ede1356-0a8f-4691-90e8-00f3e93c22af" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6ede1356-0a8f-4691-90e8-00f3e93c22af", [{"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(55,126,184)", "width": 10}, "mode": "lines", "name": "loading", "x": ["2019-01-01", "2019-01-01", "2019-01-01 03:42:13.333333", "2019-01-01 03:42:13.333333", "2019-01-01 03:42:13.333333", "2019-01-02 12:55:50.717597", "2019-01-02 12:55:50.717597", "2019-01-02 16:38:04.050930", "2019-01-02 16:38:04.050930", "2019-01-02 16:38:04.050930", "2019-01-04 01:51:41.435194", "2019-01-04 01:51:41.435194", "2019-01-04 05:33:54.768527", "2019-01-04 05:33:54.768527", "2019-01-04 05:33:54.768527", "2019-01-05 14:47:32.152791", "2019-01-05 14:47:32.152791", "2019-01-05 18:29:45.486124", "2019-01-05 18:29:45.486124", "2019-01-05 18:29:45.486124", "2019-01-07 03:43:22.870388", "2019-01-07 03:43:22.870388", "2019-01-07 07:25:36.203721", "2019-01-07 07:25:36.203721", "2019-01-07 07:25:36.203721", "2019-01-08 16:39:13.587985", "2019-01-08 16:39:13.587985", "2019-01-08 20:21:26.921318", "2019-01-08 20:21:26.921318", "2019-01-08 20:21:26.921318", "2019-01-10 05:35:04.305582", "2019-01-10 05:35:04.305582", "2019-01-10 09:17:17.638915", "2019-01-10 09:17:17.638915", "2019-01-10 09:17:17.638915", "2019-01-11 18:30:55.023179", "2019-01-11 18:30:55.023179", "2019-01-11 22:13:08.356512", "2019-01-11 22:13:08.356512", "2019-01-11 22:13:08.356512", "2019-01-13 07:26:45.740776", "2019-01-13 07:26:45.740776", "2019-01-13 11:08:59.074109", "2019-01-13 11:08:59.074109", "2019-01-13 11:08:59.074109", "2019-01-14 20:22:36.458373", "2019-01-14 20:22:36.458373", "2019-01-15 00:04:49.791706", "2019-01-15 00:04:49.791706", "2019-01-15 00:04:49.791706", "2019-01-16 09:18:27.175970", "2019-01-16 09:18:27.175970", "2019-01-16 13:00:40.509303", "2019-01-16 13:00:40.509303", "2019-01-16 13:00:40.509303", "2019-01-17 22:14:17.893567", "2019-01-17 22:14:17.893567", "2019-01-18 01:56:31.226900", "2019-01-18 01:56:31.226900", "2019-01-18 01:56:31.226900", "2019-01-19 11:10:08.611164", "2019-01-19 11:10:08.611164", "2019-01-19 14:52:21.944497", "2019-01-19 14:52:21.944497", "2019-01-19 14:52:21.944497", "2019-01-21 00:05:59.328761", "2019-01-21 00:05:59.328761", "2019-01-21 03:48:12.662094", "2019-01-21 03:48:12.662094", "2019-01-21 03:48:12.662094", "2019-01-22 13:01:50.046358", "2019-01-22 13:01:50.046358", "2019-01-22 16:44:03.379691", "2019-01-22 16:44:03.379691", "2019-01-22 16:44:03.379691", "2019-01-24 01:57:40.763955", "2019-01-24 01:57:40.763955", "2019-01-24 05:39:54.097288", "2019-01-24 05:39:54.097288", "2019-01-24 05:39:54.097288", "2019-01-25 14:53:31.481552", "2019-01-25 14:53:31.481552", "2019-01-25 18:35:44.814885", "2019-01-25 18:35:44.814885", "2019-01-25 18:35:44.814885", "2019-01-27 03:49:22.199149", "2019-01-27 03:49:22.199149", "2019-01-27 07:31:35.532482", "2019-01-27 07:31:35.532482", "2019-01-27 07:31:35.532482", "2019-01-28 16:45:12.916746", "2019-01-28 16:45:12.916746", "2019-01-28 20:27:26.250079", "2019-01-28 20:27:26.250079", "2019-01-28 20:27:26.250079", "2019-01-30 05:41:03.634343", "2019-01-30 05:41:03.634343", "2019-01-30 09:23:16.967676", "2019-01-30 09:23:16.967676", "2019-01-30 09:23:16.967676", "2019-01-31 18:36:54.351940", "2019-01-31 18:36:54.351940", "2019-01-31 22:19:07.685273", "2019-01-31 22:19:07.685273", "2019-01-31 22:19:07.685273", "2019-02-02 07:32:45.069537", "2019-02-02 07:32:45.069537", "2019-02-02 11:14:58.402870", "2019-02-02 11:14:58.402870", "2019-02-02 11:14:58.402870", "2019-02-03 20:28:35.787134", "2019-02-03 20:28:35.787134", "2019-02-04 00:10:49.120467", "2019-02-04 00:10:49.120467", "2019-02-04 00:10:49.120467", "2019-02-05 09:24:26.504731", "2019-02-05 09:24:26.504731", "2019-02-05 13:06:39.838064", "2019-02-05 13:06:39.838064", ...

# %% [markdown]
# #### KML visualisation

# %%
plot.vessel_kml(my_env, vessels, stepsize = 1200)

# %%
# open the file
if platform.system():
    # !start ./vessel_movements.kml
else:
    # !start explorer ./vessel_movements.kml
