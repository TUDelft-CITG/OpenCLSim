# %% [markdown]
# # Demo WhileActivity
# The while activity executes a **sub_processes** until a **condition_event** is fulfilled. The condition event can be formulated based on the expression language documented in the project.

# %%
import datetime, time
import simpy

import pandas as pd
import openclsim.core as core
import openclsim.model as model
import openclsim.plot as plot

simulation_start = 0
my_env = simpy.Environment(initial_time=simulation_start)
registry = {}

# %% [markdown]
# ## Definition of while activity with a nested basic activity
# This example has a constraint that the activity while has to be completed. Thus, the activity while is terminating after the activity while has been completed. This is impossible, thus this expression guarantees an infinte loop, which will be limited in the simulation run parameter below.

# %%
activity = model.BasicActivity(
    env=my_env,
    name="Basic activity",
    registry=registry,
    duration=14,
)

while_activity = model.WhileActivity(
    env=my_env,
    name="while",
    registry=registry,
    sub_processes=[activity],
    condition_event=[{"type": "activity", "name": "while", "state": "done"}],
)

# %% [markdown]
# ## Run simulation
# Since this is an endless loop the execution is constrained to a time limit of 100 time units.

# %%
model.register_processes([while_activity])
my_env.run(until=100)

# %%
display(plot.get_log_dataframe(while_activity, [activity, while_activity]))
# Out:
#    Activity           Timestamp ActivityState        type  \
# 0     while 1970-01-01 00:00:00         START         NaN
# 1     while 1970-01-01 00:00:00         START  subprocess
# 2     while 1970-01-01 00:00:14          STOP  subprocess
# 3     while 1970-01-01 00:00:14         START  subprocess
# 4     while 1970-01-01 00:00:28          STOP  subprocess
# 5     while 1970-01-01 00:00:28         START  subprocess
# 6     while 1970-01-01 00:00:42          STOP  subprocess
# 7     while 1970-01-01 00:00:42         START  subprocess
# 8     while 1970-01-01 00:00:56          STOP  subprocess
# 9     while 1970-01-01 00:00:56         START  subprocess
# 10    while 1970-01-01 00:01:10          STOP  subprocess
# 11    while 1970-01-01 00:01:10         START  subprocess
# 12    while 1970-01-01 00:01:24          STOP  subprocess
# 13    while 1970-01-01 00:01:24         START  subprocess
# 14    while 1970-01-01 00:01:38          STOP  subprocess
# 15    while 1970-01-01 00:01:38         START  subprocess
#
#                                      ref
# 0                                    NaN
# 1   d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 2   d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 3   d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 4   d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 5   d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 6   d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 7   d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 8   d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 9   d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 10  d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 11  d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 12  d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 13  d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 14  d40c4d4b-c18e-4cb1-966a-3c433ed08d71
# 15  d40c4d4b-c18e-4cb1-966a-3c433ed08d71
