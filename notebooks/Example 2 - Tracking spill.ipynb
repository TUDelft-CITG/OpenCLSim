# %% [markdown]
# # Example 1 - Building a Layered Dike
#
# This example defines a digital twin simulation in which several layers (from different materials) of a dike are constructed.
#
# ## Necessary Dependencies

# %%
# package(s) related to time, space and id
import datetime
import platform

# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy

# spatial libraries 
import shapely.geometry
from simplekml import Kml, Style

# package(s) for data handling
import numpy as np

# digital twin package
import digital_twin.core as core
import digital_twin.model as model

# %% [markdown]
# ## Create the necessary classes
#
# The Digital Twin core defines several classes which can be combined in mixin classes you can define yourself. For example, in this simulation we define a Site as:
# * Identifiable: an object that can be identified with a name
# * Log: an object which will contain a log of events that took place concerning this object after the simulation is complete
# * Locatable: an object that has a geographical location
# * HasContainer: an object which contains a storage for materials
# * HasResource: an object only a limited number of activities can interact with at the same time

# %%
Site = type('Site', (core.Identifiable, core.Log, core.Locatable, core.HasContainer, core.HasResource, 
                     core.HasSoil, core.HasSpill, core.HasSpillCondition), {})

# %% [markdown]
# Defining mixin classes for our ships and cranes is done similarly. A ship can either be a simple transport barge we will call a TransportResource, or can be a hopper capable of loading and unloading the materials itself (TransportProcessingResource). Finally we define a class for "crane" objects which can be used to load or unload material for a transport barge (ProcessingResource).

# %%
TransportResource = type('TransportResource', 
                         (core.Identifiable, core.Log, core.ContainerDependentMovable, 
                          core.HasResource, core.HasPlume), {})

TransportProcessingResource = type('TransportProcessingResource', 
                                   (core.Identifiable, core.Log, core.ContainerDependentMovable, 
                                    core.Processor, core.HasResource, core.HasPlume), {})
ProcessingResource = type('ProcessingResource', 
                          (core.Identifiable, core.Log, core.Processor, core.HasResource, core.HasPlume), {})

# %% [markdown]
# These mixin classes use a couple of core classes not yet introduced:
# * Processor: an object which can move materials from one container to another container
# * ContainerDependentMovable: this is in fact a combination (extension) of two other core classes:
#     * HasContainer: an object which contains a storage for materials
#     * Movable: an object which can move from one geographical location to another (extends Locatable, clearly a moving object must keep track of its current location)
#
# Defining a mixin class as a ContainerDependentMovable allows for specifying a speed function which depends on the fullness of the storage container. The more basic Movable class uses a fixed speed instead.

# %% [markdown]
# ## Defining a Simpy Environment
#
# Since the digital twin package uses the Simpy package for its backend, each object we create will need to be passed the same Simpy environment object. This Simpy environment is used during the simulation. In fact, it can be used to start the simulation later on. For now, we need to create the environment object, so we can pass it to each of our mixin objects when we create them.

# %%
my_env = simpy.Environment(initial_time = (datetime.datetime.now() - datetime.datetime(1970, 1, 1)).total_seconds())

# %% [markdown]
# ## Defining the Sites
#
# For our simulation we need to define Sites for the different material stockpiles, and sites along the length of the dike in which the material needs to be installed. This example includes four material layers: clay, sand, armour and levvel. We need to define a stockpile site for each of these materials. We will store each of the sites defined in this section in a "stocks" list to be used later.

# %%
start_1 = datetime.datetime.now()
end_1 = start_1 + datetime.timedelta(seconds = 14*24*3600)

start_2 = datetime.datetime.now() + datetime.timedelta(seconds = 14*24*3600)
end_2 = start_2 + datetime.timedelta(seconds = 28*24*3600)

# %%
condition_1 = core.SpillCondition(5_000, start_1, end_1)
condition_2 = core.SpillCondition(5_000, start_2, end_2)

# %%
# sites data in database
data_stock_clay = {"env": my_env,
                   "name": "Clay_Stock",
                   "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                   "capacity": 150000,
                   "level": 150000,
                   "material": "Clay",
                   "density": 1_500,
                   "fines": 0.30,
                   "conditions": condition_1}

data_stock_sand = {"env": my_env,
                   "name": "Sand_Stock",
                   "geometry": shapely.geometry.Point(5.271417603333632, 52.9638452897506),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000,
                   "material": "Sand",
                   "density": 1_800,
                   "fines": 0.45,
                   "conditions": [condition_1, condition_2]}

data_stock_armour = {"env": my_env,
                   "name": "Armour_Stock",
                   "geometry": shapely.geometry.Point(5.919298185633251, 52.94239823421129),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000,
                   "material": "Armour",
                   "density": 1_500,
                   "fines": 0.0,
                   "conditions": condition_1}

data_stock_levvel = {"env": my_env,
                   "name": "Levvel_Stock",
                   "geometry": shapely.geometry.Point(5.919298185633251, 52.94239823421129),  # lon, lat
                   "capacity": 150_000,
                   "level": 150_000,
                   "material": "Levvel",
                   "density": 1_500,
                   "fines": 0.0,
                   "conditions": condition_1}

# create the site objects
stocks = []
for data in [data_stock_clay, data_stock_sand, data_stock_armour, data_stock_levvel]:
    stock = Site(**data)
    stocks.append(stock)

# %% [markdown]
# The constructor parameters needed will differ depending on the core digital twin classes used in the mixin class you've defined. We can best explain each of the parameters we pass in turn:
# * __env__: Most core digital twin classes extend a class called SimpyObject and need an "env" construction parameter. These classes, such as HasContainer and HasResource, need you to pass the Simpy environment so they can create Simpy objects within the simulation environment.
# * __name__: An Identifiable object needs a name, which will be used to identify the object.
# * __geometry__: A Locatable object needs a geographical location. The object will initially be located at this location. In the case of a Movable object, the geographical location will be updated as it moves. If the object is not movable, the geometry should remain the same throughout the simulation.
# * __capacity__: A HasContainer object needs to know the maximum amount of materials it can store.
# * __level__: A HasContainer object can optionally be passed the initial level of the container. If no level is passed, the container is initially empty. In the case of our material stockpiles, we want them to be filled instead.
#
# We could also have passed a __nr_resources__ argument to the constructors to define the number of activities which can use one of these stockpiles at the same time. By default this is set to one, which means only one ship can be loaded at each stockpile at the same time during the simulation.
#
# In addition to the stockpiles, we also need to define the destination sites in which the material will be placed. To do so we will define several sites spaced evenly along the length of the dike for each of the layers.

# %%
site_count = 20

# layer data from database
data_clay = {"start": [5.054676856441372, 52.94042293840172], # Den Oever (lon, lat)
             "stop": [5.294877712236641, 53.06686424241725], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Clay_Layer",
                   "material": "Clay",
                   "density": 0,
                   "fines": 0.0,
                   "conditions": condition_1}
data_sand = {"start": [5.052051052879287,52.9421894472733], # Den Oever (lon, lat)
             "stop": [5.292216781509101,53.06886359869087], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Sand_Layer",
                   "material": "Sand",
                   "density": 0,
                   "fines": 0.0,
                   "conditions": condition_1}
data_armour = {"start": [5.049510554598302,52.94393628899332], # Den Oever (lon, lat)
             "stop": [5.289636346490858,53.07053144816584], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Armour_Layer",
                   "material": "Armour",
                   "density": 0,
                   "fines": 0.0,
                   "conditions": condition_1}
data_levvel = {"start": [5.046556507026805,52.94579445406793], # Den Oever (lon, lat)
             "stop": [5.286775240694118,53.07264015015531], # Kornwerderzand (lon, lat)
             "capacity": 5_000,
             "name": "Levvel_Layer",
                   "material": "Levvel",
                   "density": 0,
                   "fines": 0.0,
                   "conditions": condition_1}

sites = []
for data_layer in [data_clay, data_sand, data_armour, data_levvel]:
    start = data_layer['start']
    stop = data_layer['stop']

    # generate the evenly spaced locations between the selected start and stop points
    lons = np.linspace(start[0], stop[0], num=site_count)
    lats = np.linspace(start[1], stop[1], num=site_count)

    # create a Site object for each location
    layer_sites = []
    for i in range(site_count):
        data_site = {"env": my_env,
                     "name": data_layer["name"] + '_' + format(i, '02.0f'),
                     "geometry": shapely.geometry.Point(lons[i], lats[i]),
                     "capacity": data_layer["capacity"],
                     "density": data_layer["density"],
                     "fines": data_layer["fines"],
                     "material": data_layer["material"],
                     "conditions": data_layer["conditions"]}
        site = Site(**data_site)
        layer_sites.append(site)
    sites.append(layer_sites)

# %% [markdown]
# ## Defining the Equipment
#
# We need to create objects for the equipment used in the simulation. This is done similarly to creating the sites.

# %%
# define a simple linear function with which the speed of a ship can be calculated
def compute_v_provider(v_empty, v_full):
    return lambda x: x * (v_full - v_empty) + v_empty

# equipment information in database
data_gantry_crane = {"env": my_env,
                     "name": "Gantry crane",
                     "rate": 0.10}
data_installation_crane = {"env": my_env,
                           "name": "Installation crane",
                           "rate": 0.05}

data_transport_barge_01 = {"env": my_env,
                           "name": "Transport barge 01",
                           "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                           "capacity": 1_000,
                           "compute_v": compute_v_provider(v_empty=1.6, v_full=1)}
data_transport_barge_02 = {"env": my_env,
                           "name": "Transport barge 02",
                           "geometry": shapely.geometry.Point(5.019298185633251, 52.94239823421129),  # lon, lat
                           "capacity": 1_000,
                           "compute_v": compute_v_provider(v_empty=1.6, v_full=1)}

data_hopper = {"env": my_env,
               "name": "Hopper",
               "geometry": shapely.geometry.Point(5.070195628786471, 52.93917167503315),  # lon, lat
               "rate": 2,
               "capacity": 1_000,
               "compute_v": compute_v_provider(v_empty=2, v_full=1.5)}

# create the processing resources
gantry_crane = ProcessingResource(**data_gantry_crane)
installation_crane = ProcessingResource(**data_installation_crane)

# create the transport resources
transport_barge_01 = TransportResource(**data_transport_barge_01)
transport_barge_02 = TransportResource(**data_transport_barge_02)

# create the transport processing resource
hopper = TransportProcessingResource(**data_hopper)

# %% [markdown]
# To define our equipment we needed two new constructor arguments:
# * __rate__: The speed with which a Processor can process materials
# * __compute_v__: A function which given a value in the interval [0,1], representing the fullness of the container, returns the speed of the ContainerDependentMovable

# %% [markdown]
# ## Defining the Activities
#
# To complete the simulation we need to define which activities need to be completed to complete the simulation. An activity always consists of transporting materials from an origin container to a destination container. We need to define an activity for each origin, destination and the equipment used to transport the materials. For installing the clay layer we will use the transport barges, gantry and installation crane. Since we have two transport barges that could be used, we define two activities for each of the clay layer sites, one for each set of equipment. We also wish to install the clay layer in order, so for each site we need to define a condition that states that the previous site needs to be completed first.

# %%
activities = []

clay_layer_index = 0
clay_sites = sites[clay_layer_index]
for i, clay_site in enumerate(clay_sites):
    for barge_index, transport_barge in enumerate([transport_barge_01, transport_barge_02]):
        # for the first site we do not need to define any condition
        condition = None if i == 0 else model.LevelCondition(container=clay_sites[i-1], min_level=data_clay["capacity"])
        activity = model.Activity(env=my_env,
                                  name="Clay_Placement_S" + format(i+1, '02.0f') + "_B" + format(barge_index + 1, '02.0f'),
                                  origin=stocks[clay_layer_index],
                                  destination=clay_site,
                                  loader=gantry_crane,
                                  mover=transport_barge,
                                  unloader=installation_crane,
                                  start_condition=condition)
        activities.append(activity)

# %% [markdown]
# As can be seen in the code fragment above, the Activity class takes the Simpy environment and a name as its constructor arguments. This is because it is defined as a mixin of the SimpyObject and Identifiable core classes. To construct an activity we also needed to define the origin, destination, loader, mover and unloader. Finally, we can optionally define conditions that need to be satisfied for the transportation of materials to take place. These are separated in __start_condition__, __stop_condition__ and __condition__ arguments:
# * __start_condition__: The activity will start as soon as this condition is satisfied. If this condition is not yet satisfied at the start of the simulation the activity will be suspended untill the condition is satisfied at a later time. Since we do not want any clay to be transported to the later sites if the previous site has not yet been completed, we define this condition as a start_condition.
# * __stop_condition__: After the activity has started (the start_condition was satisfied), it will regularly check if the stop_condition has been satisfied. If so, the activity is considered complete and will terminate. A simulation will not terminate untill all of its activities have been completed. By default (with stop_condition=None), the stop_condition is set to either the origin container being empty, or the destination container being full. This is sufficient in our case, so we do not specify a stop_condition.
# * __condition__: After the activity has started (the start_condition was satisfied) and as long as the stop_condition is not satisfied, the activity will continuously check whether this condition is satisfied. If so, it will complete exactly one transportation of materials (loading the mover at the origin and unloading the mover at the destination). If not, the activity will wait untill the condition is satisfied again. Defining such a condition allows for the activity to be temporarily halted, for example due to bad weather or other working conditions, and resuming at a later time when the problem preventing work has passed.
#
# All of these condition arguments take a "Condition" object. This object should have a "satisfied" method which returns a boolean indicating whether the condition is satsified or not. The digital twin package provides a LevelCondition, allowing you to quickly construct a condition which will check if an object extending HasContainer has a certain minimum and/or maximum level. It also provides an AndCondition and OrCondition which allow for combining other condition objects into a single condition. You can also provide your own "Condition" class, for example you could program a "Condition" class which depending on the time in the simulation (the .now fixture of the Simpy environment), returns whether the weather is good enough for work to take place:

# %%
class WeatherCondition:
    def __init__(self, env, *args, **kwargs):
        super().__init__(*args, **kwargs)
        """Initialization"""
        self.env = env
    
    def satisfied(self):
        return self.env.now < 30_000 or self.env.now > 40_000  # between time step 30_000 and 40_000 a "storm" takes place

# %% [markdown]
# For our simple dike building example we do not define any advanced conditions. We do need to define Activities for the other layers (sand, armour and levvel). For each of these layers we again require that they are installed in order. We also require the previous layer to be completed, before the next layer can be installed. To achieve this we combine two LevelConditions with an AndCondition. We choose to install the sand layer using the hopper, and the armour and levvel layers using the transport barges and grantry and installation cranes.

# %%
# define the sand layer Activities
sand_layer_index = 1
sand_sites = sites[sand_layer_index]
for i, sand_site in enumerate(sand_sites):
    # for the first site we do not need to define a condition on the previous site
    prev_site_condition = model.TrueCondition() if i == 0 else model.LevelCondition(container=sand_sites[i-1], 
                                                                          min_level=sand_sites[i-1].container.capacity)
    prev_layer_sites = sites[clay_layer_index]
    prev_layer_condition = model.LevelCondition(prev_layer_sites[i], min_level=prev_layer_sites[i].container.capacity)
    start_condition = model.AndCondition([prev_site_condition, prev_layer_condition])
    activity = model.Activity(env=my_env,
                              name="Sand_Placement_S" + format(i+1, '02.0f'),
                              origin=stocks[sand_layer_index],
                              destination=sand_site,
                              loader=hopper,
                              mover=hopper,
                              unloader=hopper,
                              start_condition=start_condition)
    activities.append(activity)

# define the armour and level layer activities
layer_names = ["Armour_Placement", "Levvel_Placement"]
layer_indices = [2, 3]
for layer_index in layer_indices:
    for barge_index, transport_barge in enumerate([transport_barge_01, transport_barge_02]):
        layer_sites = sites[layer_index]
        for site_index, site in enumerate(layer_sites):
            # for the first site we do not need to define a condition on the previous site
            prev_site_condition = model.TrueCondition() if site_index == 0 else \
                model.LevelCondition(container=layer_sites[site_index-1], 
                                     min_level=layer_sites[site_index-1].container.capacity)
            
            prev_layer_sites = sites[layer_index - 1]
            prev_layer_condition = model.LevelCondition(container=prev_layer_sites[site_index],
                                                        min_level=prev_layer_sites[site_index].container.capacity)
            start_condition = model.AndCondition([prev_site_condition, prev_layer_condition])
            
            activity = model.Activity(env=my_env,
                                      name=layer_names[layer_index-2] + "_S" + format(site_index+1, '02.0f')
                                           + "_B" + format(barge_index+1, '02.0f'),
                                      origin=stocks[layer_index],
                                      destination=site,
                                      loader=gantry_crane,
                                      mover=transport_barge,
                                      unloader=installation_crane,
                                      start_condition=start_condition)
            activities.append(activity)

# %% [markdown]
# ## Running the Simulation
#
# To run the simulation, we now simply need to tell the Simpy environment to run. This will run all activities (most of which will first suspend themselved unstill the start_condition is satisfied) and terminate once every Activity has reached its stop_condition. To allow for the visualisation later, we record the start time in the environment.

# %%
#my_env.epoch = datetime.datetime.now()
my_env.run()

print("\n*** Installation of dike finished in {} ***".format(datetime.timedelta(seconds=int(my_env.now))))
# Out:
# T=1545126535.00 Start condition is satisfied, Clay_Placement_S01_B01 transporting from Clay_Stock to Clay_Layer_00 started
# Using Transport barge 01 to process 1000
# T=1545126535.00 Start condition is satisfied, Clay_Placement_S01_B02 transporting from Clay_Stock to Clay_Layer_00 started
# Using Transport barge 02 to process 1000
# T=1545126535.00 Clay_Placement_S02_B01 to Clay_Layer_01 suspended
# T=1545126535.00 Clay_Placement_S02_B02 to Clay_Layer_01 suspended
# T=1545126535.00 Clay_Placement_S03_B01 to Clay_Layer_02 suspended
# T=1545126535.00 Clay_Placement_S03_B02 to Clay_Layer_02 suspended
# T=1545126535.00 Clay_Placement_S04_B01 to Clay_Layer_03 suspended
# T=1545126535.00 Clay_Placement_S04_B02 to Clay_Layer_03 suspended
# T=1545126535.00 Clay_Placement_S05_B01 to Clay_Layer_04 suspended
# T=1545126535.00 Clay_Placement_S05_B02 to Clay_Layer_04 suspended
# T=1545126535.00 Clay_Placement_S06_B01 to Clay_Layer_05 suspended
# T=1545126535.00 Clay_Placement_S06_B02 to Clay_Layer_05 suspended
# T=1545126535.00 Clay_Placement_S07_B01 to Clay_Layer_06 suspended
# T=1545126535.00 Clay_Placement_S07_B02 to Clay_Layer_06 suspended
# T=1545126535.00 Clay_Placement_S08_B01 to Clay_Layer_07 suspended
# T=1545126535.00 Clay_Placement_S08_B02 to Clay_Layer_07 suspended
# T=1545126535.00 Clay_Placement_S09_B01 to Clay_Layer_08 suspended
# T=1545126535.00 Clay_Placement_S09_B02 to Clay_Layer_08 suspended
# T=1545126535.00 Clay_Placement_S10_B01 to Clay_Layer_09 suspended
# T=1545126535.00 Clay_Placement_S10_B02 to Clay_Layer_09 suspended
# T=1545126535.00 Clay_Placement_S11_B01 to Clay_Layer_10 suspended
# T=1545126535.00 Clay_Placement_S11_B02 to Clay_Layer_10 suspended
# T=1545126535.00 Clay_Placement_S12_B01 to Clay_Layer_11 suspended
# T=1545126535.00 Clay_Placement_S12_B02 to Clay_Layer_11 suspended
# T=1545126535.00 Clay_Placement_S13_B01 to Clay_Layer_12 suspended
# T=1545126535.00 Clay_Placement_S13_B02 to Clay_Layer_12 suspended
# T=1545126535.00 Clay_Placement_S14_B01 to Clay_Layer_13 suspended
# T=1545126535.00 Clay_Placement_S14_B02 to Clay_Layer_13 suspended
# T=1545126535.00 Clay_Placement_S15_B01 to Clay_Layer_14 suspended
# T=1545126535.00 Clay_Placement_S15_B02 to Clay_Layer_14 suspended
# T=1545126535.00 Clay_Placement_S16_B01 to Clay_Layer_15 suspended
# T=1545126535.00 Clay_Placement_S16_B02 to Clay_Layer_15 suspended
# T=1545126535.00 Clay_Placement_S17_B01 to Clay_Layer_16 suspended
# T=1545126535.00 Clay_Placement_S17_B02 to Clay_Layer_16 suspended
# T=1545126535.00 Clay_Placement_S18_B01 to Clay_Layer_17 suspended
# T=1545126535.00 Clay_Placement_S18_B02 to Clay_Layer_17 suspended
# T=1545126535.00 Clay_Placement_S19_B01 to Clay_Layer_18 suspended
# T=1545126535.00 Clay_Placement_S19_B02 to Clay_Layer_18 suspended
# T=1545126535.00 Clay_Placement_S20_B01 to Clay_Layer_19 suspended
# T=1545126535.00 Clay_Placement_S20_B02 to Clay_Layer_19 suspended
# T=1545126535.00 Sand_Placement_S01 to Sand_Layer_00 suspended
# T=1545126535.00 Sand_Placement_S02 to Sand_Layer_01 suspended
# T=1545126535.00 Sand_Placement_S03 to Sand_Layer_02 suspended
# T=1545126535.00 Sand_Placement_S04 to Sand_Layer_03 suspended
# T=1545126535.00 Sand_Placement_S05 to Sand_Layer_04 suspended
# T=1545126535.00 Sand_Placement_S06 to Sand_Layer_05 suspended
# T=1545126535.00 Sand_Placement_S07 to Sand_Layer_06 suspended
# T=1545126535.00 Sand_Placement_S08 to Sand_Layer_07 suspended
# T=1545126535.00 Sand_Placement_S09 to Sand_Layer_08 suspended
# T=1545126535.00 Sand_Placement_S10 to Sand_Layer_09 suspended
# T=1545126535.00 Sand_Placement_S11 to Sand_Layer_10 suspended
# T=1545126535.00 Sand_Placement_S12 to Sand_Layer_11 suspended
# T=1545126535.00 Sand_Placement_S13 to Sand_Layer_12 suspended
# T=1545126535.00 Sand_Placement_S14 to Sand_Layer_13 suspended
# T=1545126535.00 Sand_Placement_S15 to Sand_Layer_14 suspended
# T=1545126535.00 Sand_Placement_S16 to Sand_Layer_15 suspended
# T=1545126535.00 Sand_Placement_S17 to Sand_Layer_16 suspended
# T=1545126535.00 Sand_Placement_S18 to Sand_Layer_17 suspended
# T=1545126535.00 Sand_Placement_S19 to Sand_Layer_18 suspended
# T=1545126535.00 Sand_Placement_S20 to Sand_Layer_19 suspended
# T=1545126535.00 Armour_Placement_S01_B01 to Armour_Layer_00 suspended
# T=1545126535.00 Armour_Placement_S02_B01 to Armour_Layer_01 suspended
# T=1545126535.00 Armour_Placement_S03_B01 to Armour_Layer_02 suspended
# T=1545126535.00 Armour_Placement_S04_B01 to Armour_Layer_03 suspended
# T=1545126535.00 Armour_Placement_S05_B01 to Armour_Layer_04 suspended
# T=1545126535.00 Armour_Placement_S06_B01 to Armour_Layer_05 suspended
# T=1545126535.00 Armour_Placement_S07_B01 to Armour_Layer_06 suspended
# T=1545126535.00 Armour_Placement_S08_B01 to Armour_Layer_07 suspended
# T=1545126535.00 Armour_Placement_S09_B01 to Armour_Layer_08 suspended
# T=1545126535.00 Armour_Placement_S10_B01 to Armour_Layer_09 suspended
# T=1545126535.00 Armour_Placement_S11_B01 to Armour_Layer_10 suspended
# T=1545126535.00 Armour_Placement_S12_B01 to Armour_Layer_11 suspended
# T=1545126535.00 Armour_Placement_S13_B01 to Armour_Layer_12 suspended
# T=1545126535.00 Armour_Placement_S14_B01 to Armour_Layer_13 suspended
# T=1545126535.00 Armour_Placement_S15_B01 to Armour_Layer_14 suspended
# T=1545126535.00 Armour_Placement_S16_B01 to Armour_Layer_15 suspended
# T=1545126535.00 Armour_Placement_S17_B01 to Armour_Layer_16 suspended
# T=1545126535.00 Armour_Placement_S18_B01 to Armour_Layer_17 suspended
# T=1545126535.00 Armour_Placement_S19_B01 to Armour_Layer_18 suspended
# T=1545126535.00 Armour_Placement_S20_B01 to Armour_Layer_19 suspended
# T=1545126535.00 Armour_Placement_S01_B02 to Armour_Layer_00 suspended
# T=1545126535.00 Armour_Placement_S02_B02 to Armour_Layer_01 suspended
# T=1545126535.00 Armour_Placement_S03_B02 to Armour_Layer_02 suspended
# T=1545126535.00 Armour_Placement_S04_B02 to Armour_Layer_03 suspended
# T=1545126535.00 Armour_Placement_S05_B02 to Armour_Layer_04 suspended
# T=1545126535.00 Armour_Placement_S06_B02 to Armour_Layer_05 suspended
# T=1545126535.00 Armour_Placement_S07_B02 to Armour_Layer_06 suspended
# T=1545126535.00 Armour_Placement_S08_B02 to Armour_Layer_07 suspended
# T=1545126535.00 Armour_Placement_S09_B02 to Armour_Layer_08 suspended
# T=1545126535.00 Armour_Placement_S10_B02 to Armour_Layer_09 suspended
# T=1545126535.00 Armour_Placement_S11_B02 to Armour_Layer_10 suspended
# T=1545126535.00 Armour_Placement_S12_B02 to Armour_Layer_11 suspended
# T=1545126535.00 Armour_Placement_S13_B02 to Armour_Layer_12 suspended
# T=1545126535.00 Armour_Placement_S14_B02 to Armour_Layer_13 suspended
# T=1545126535.00 Armour_Placement_S15_B02 to Armour_Layer_14 suspended
# T=1545126535.00 Armour_Placement_S16_B02 to Armour_Layer_15 suspended
# T=1545126535.00 Armour_Placement_S17_B02 to Armour_Layer_16 suspended
# T=1545126535.00 Armour_Placement_S18_B02 to Armour_Layer_17 suspended
# T=1545126535.00 Armour_Placement_S19_B02 to Armour_Layer_18 suspended
# T=1545126535.00 Armour_Placement_S20_B02 to Armour_Layer_19 suspended
# T=1545126535.00 Levvel_Placement_S01_B01 to Levvel_Layer_00 suspended
# T=1545126535.00 Levvel_Placement_S02_B01 to Levvel_Layer_01 suspended
# T=1545126535.00 Levvel_Placement_S03_B01 to Levvel_Layer_02 suspended
# T=1545126535.00 Levvel_Placement_S04_B01 to Levvel_Layer_03 suspended
# T=1545126535.00 Levvel_Placement_S05_B01 to Levvel_Layer_04 suspended
# T=1545126535.00 Levvel_Placement_S06_B01 to Levvel_Layer_05 suspended
# T=1545126535.00 Levvel_Placement_S07_B01 to Levvel_Layer_06 suspended
# T=1545126535.00 Levvel_Placement_S08_B01 to Levvel_Layer_07 suspended
# T=1545126535.00 Levvel_Placement_S09_B01 to Levvel_Layer_08 suspended
# T=1545126535.00 Levvel_Placement_S10_B01 to Levvel_Layer_09 suspended
# T=1545126535.00 Levvel_Placement_S11_B01 to Levvel_Layer_10 suspended
# T=1545126535.00 Levvel_Placement_S12_B01 to Levvel_Layer_11 suspended
# T=1545126535.00 Levvel_Placement_S13_B01 to Levvel_Layer_12 suspended
# T=1545126535.00 Levvel_Placement_S14_B01 to Levvel_Layer_13 suspended
# T=1545126535.00 Levvel_Placement_S15_B01 to Levvel_Layer_14 suspended
# T=1545126535.00 Levvel_Placement_S16_B01 to Levvel_Layer_15 suspended
# T=1545126535.00 Levvel_Placement_S17_B01 to Levvel_Layer_16 suspended
# T=1545126535.00 Levvel_Placement_S18_B01 to Levvel_Layer_17 suspended
# T=1545126535.00 Levvel_Placement_S19_B01 to Levvel_Layer_18 suspended
# T=1545126535.00 Levvel_Placement_S20_B01 to Levvel_Layer_19 suspended
# T=1545126535.00 Levvel_Placement_S01_B02 to Levvel_Layer_00 suspended
# T=1545126535.00 Levvel_Placement_S02_B02 to Levvel_Layer_01 suspended
# T=1545126535.00 Levvel_Placement_S03_B02 to Levvel_Layer_02 suspended
# T=1545126535.00 Levvel_Placement_S04_B02 to Levvel_Layer_03 suspended
# T=1545126535.00 Levvel_Placement_S05_B02 to Levvel_Layer_04 suspended
# T=1545126535.00 Levvel_Placement_S06_B02 to Levvel_Layer_05 suspended
# T=1545126535.00 Levvel_Placement_S07_B02 to Levvel_Layer_06 suspended
# T=1545126535.00 Levvel_Placement_S08_B02 to Levvel_Layer_07 suspended
# T=1545126535.00 Levvel_Placement_S09_B02 to Levvel_Layer_08 suspended
# T=1545126535.00 Levvel_Placement_S10_B02 to Levvel_Layer_09 suspended
# T=1545126535.00 Levvel_Placement_S11_B02 to Levvel_Layer_10 suspended
# T=1545126535.00 Levvel_Placement_S12_B02 to Levvel_Layer_11 suspended
# T=1545126535.00 Levvel_Placement_S13_B02 to Levvel_Layer_12 suspended
# T=1545126535.00 Levvel_Placement_S14_B02 to Levvel_Layer_13 suspended
# T=1545126535.00 Levvel_Placement_S15_B02 to Levvel_Layer_14 suspended
# T=1545126535.00 Levvel_Placement_S16_B02 to Levvel_Layer_15 suspended
# T=1545126535.00 Levvel_Placement_S17_B02 to Levvel_Layer_16 suspended
# T=1545126535.00 Levvel_Placement_S18_B02 to Levvel_Layer_17 suspended
# T=1545126535.00 Levvel_Placement_S19_B02 to Levvel_Layer_18 suspended
# T=1545126535.00 Levvel_Placement_S20_B02 to Levvel_Layer_19 suspended
# Processed 1000:
#   from:        Clay_Stock contains: 149000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.05468 52.94042
# Processed 1000:
#   from:        Clay_Stock contains: 148000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.05468 52.94042
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_00 contains: 1000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.05468 52.94042
#   to:          5.01930 52.94240
# Processed 1000:
#   from:        Clay_Stock contains: 147000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.05468 52.94042
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_00 contains: 2000
# Using Transport barge 02 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.05468 52.94042
#   to:          5.01930 52.94240
# Processed 1000:
#   from:        Clay_Stock contains: 146000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.05468 52.94042
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_00 contains: 3000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.05468 52.94042
#   to:          5.01930 52.94240
# Processed 1000:
#   from:        Clay_Stock contains: 145000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.05468 52.94042
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_00 contains: 4000
# Nothing to move
# T=1546418935.00 Start condition is satisfied, Clay_Placement_S02_B01 transporting from Clay_Stock to Clay_Layer_01 started
# Using Transport barge 01 to process 1000
# T=1546418935.00 Start condition is satisfied, Clay_Placement_S02_B02 transporting from Clay_Stock to Clay_Layer_01 started
# Using Transport barge 02 to process 1000
# T=1546418935.00 Start condition is satisfied, Sand_Placement_S01 transporting from Sand_Stock to Sand_Layer_00 started
# Using Hopper to process 1000
# T=1546419735.01 Stop condition is satisfied, Clay_Placement_S01_B02 transporting from Clay_Stock to Clay_Layer_00 complete
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.05468 52.94042
#   to:          5.01930 52.94240
# Moved:
#   object:      Hopper contains: 0
#   from:        5.07020 52.93917
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 149000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Clay_Stock contains: 144000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.06732 52.94708
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_00 contains: 5000
# T=1546436135.01 Stop condition is satisfied, Clay_Placement_S01_B01 transporting from Clay_Stock to Clay_Layer_00 complete
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.05205 52.94219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_00 contains: 1000
# Using Hopper to process 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.05468 52.94042
#   to:          5.01930 52.94240
# Moved:
#   object:      Hopper contains: 0
#   from:        5.05205 52.94219
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 148000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Clay_Stock contains: 143000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.06732 52.94708
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.05205 52.94219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_00 contains: 2000
# Using Hopper to process 1000
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_01 contains: 1000
# Using Transport barge 02 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.06732 52.94708
#   to:          5.01930 52.94240
# Moved:
#   object:      Hopper contains: 0
#   from:        5.05205 52.94219
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 147000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Clay_Stock contains: 142000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.06732 52.94708
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.05205 52.94219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_00 contains: 3000
# Using Hopper to process 1000
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_01 contains: 2000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.06732 52.94708
#   to:          5.01930 52.94240
# Moved:
#   object:      Hopper contains: 0
#   from:        5.05205 52.94219
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 146000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Clay_Stock contains: 141000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.06732 52.94708
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.05205 52.94219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_00 contains: 4000
# Using Hopper to process 1000
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_01 contains: 3000
# Using Transport barge 02 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.06732 52.94708
#   to:          5.01930 52.94240
# Moved:
#   object:      Hopper contains: 0
#   from:        5.05205 52.94219
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 145000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Clay_Stock contains: 140000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.05205 52.94219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_00 contains: 5000
# T=1546510511.57 Stop condition is satisfied, Sand_Placement_S01 transporting from Sand_Stock to Sand_Layer_00 complete
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.06732 52.94708
# T=1546512535.00 Start condition is satisfied, Armour_Placement_S01_B01 transporting from Armour_Stock to Armour_Layer_00 started
# Using Transport barge 01 to process 1000
# T=1546512535.00 Start condition is satisfied, Armour_Placement_S01_B02 transporting from Armour_Stock to Armour_Layer_00 started
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_01 contains: 4000
# Nothing to move
# T=1546519735.00 Start condition is satisfied, Clay_Placement_S03_B01 transporting from Clay_Stock to Clay_Layer_02 started
# Using Transport barge 01 to process 1000
# T=1546519735.00 Start condition is satisfied, Clay_Placement_S03_B02 transporting from Clay_Stock to Clay_Layer_02 started
# Using Transport barge 02 to process 1000
# T=1546519735.00 Start condition is satisfied, Sand_Placement_S02 transporting from Sand_Stock to Sand_Layer_01 started
# Using Hopper to process 1000
# Using Transport barge 02 to process 1000
# T=1546519735.01 Stop condition is satisfied, Clay_Placement_S02_B01 transporting from Clay_Stock to Clay_Layer_01 complete
# Moved:
#   object:      Hopper contains: 0
#   from:        5.05205 52.94219
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 144000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_01 contains: 5000
# T=1546536135.01 Stop condition is satisfied, Clay_Placement_S02_B02 transporting from Clay_Stock to Clay_Layer_01 complete
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.06469 52.94886
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_01 contains: 1000
# Using Hopper to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.06732 52.94708
#   to:          5.01930 52.94240
# Moved:
#   object:      Hopper contains: 0
#   from:        5.06469 52.94886
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 143000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Clay_Stock contains: 139000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.06732 52.94708
#   to:          5.91930 52.94240
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.07996 52.95373
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.06469 52.94886
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_01 contains: 2000
# Using Hopper to process 1000
# Moved:
#   object:      Hopper contains: 0
#   from:        5.06469 52.94886
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Armour_Stock contains: 149000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Processed 1000:
#   from:        Sand_Stock contains: 142000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.06469 52.94886
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_01 contains: 3000
# Using Hopper to process 1000
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_02 contains: 1000
# Using Transport barge 02 to process 1000
# Moved:
#   object:      Hopper contains: 0
#   from:        5.06469 52.94886
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 141000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.06469 52.94886
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_01 contains: 4000
# Using Hopper to process 1000
# Moved:
#   object:      Hopper contains: 0
#   from:        5.06469 52.94886
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 140000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.06469 52.94886
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_01 contains: 5000
# T=1546606832.88 Stop condition is satisfied, Sand_Placement_S02 transporting from Sand_Stock to Sand_Layer_01 complete
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.07996 52.95373
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Armour_Stock contains: 148000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.04951 52.94394
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_00 contains: 1000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.04951 52.94394
#   to:          5.01930 52.94240
# Processed 1000:
#   from:        Clay_Stock contains: 138000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.07996 52.95373
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_02 contains: 2000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.04951 52.94394
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_00 contains: 2000
# Using Transport barge 02 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.04951 52.94394
#   to:          5.01930 52.94240
# Processed 1000:
#   from:        Clay_Stock contains: 137000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.07996 52.95373
#   to:          5.91930 52.94240
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.07996 52.95373
# Processed 1000:
#   from:        Armour_Stock contains: 147000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_02 contains: 3000
# Using Transport barge 02 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.07996 52.95373
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Armour_Stock contains: 146000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.04951 52.94394
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_00 contains: 3000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.04951 52.94394
#   to:          5.01930 52.94240
# Processed 1000:
#   from:        Clay_Stock contains: 136000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.07996 52.95373
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_02 contains: 4000
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.04951 52.94394
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_00 contains: 4000
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.04951 52.94394
#   to:          5.01930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Clay_Stock contains: 135000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.07996 52.95373
#   to:          5.91930 52.94240
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.07996 52.95373
# T=1546871229.35 Stop condition is satisfied, Clay_Placement_S03_B01 transporting from Clay_Stock to Clay_Layer_02 complete
# T=1546872535.00 Start condition is satisfied, Clay_Placement_S04_B01 transporting from Clay_Stock to Clay_Layer_03 started
# Nothing to move
# T=1546872535.00 Start condition is satisfied, Clay_Placement_S04_B02 transporting from Clay_Stock to Clay_Layer_03 started
# Using Transport barge 02 to process 1000
# T=1546872535.00 Start condition is satisfied, Sand_Placement_S03 transporting from Sand_Stock to Sand_Layer_02 started
# Using Hopper to process 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Hopper contains: 0
#   from:        5.06469 52.94886
#   to:          5.27142 52.96385
# Nothing to move
# Processed 1000:
#   from:        Sand_Stock contains: 139000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Armour_Stock contains: 145000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.07733 52.95552
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_02 contains: 1000
# Using Hopper to process 1000
# Nothing to move
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_02 contains: 5000
# T=1546891014.74 Stop condition is satisfied, Clay_Placement_S03_B02 transporting from Clay_Stock to Clay_Layer_02 complete
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.07996 52.95373
#   to:          5.01930 52.94240
# Nothing to move
# Nothing to move
# Moved:
#   object:      Hopper contains: 0
#   from:        5.07733 52.95552
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 138000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Clay_Stock contains: 134000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.07733 52.95552
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_02 contains: 2000
# Using Hopper to process 1000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.09260 52.96039
# Nothing to move
# Moved:
#   object:      Hopper contains: 0
#   from:        5.07733 52.95552
#   to:          5.27142 52.96385
# Nothing to move
# Processed 1000:
#   from:        Sand_Stock contains: 137000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.07733 52.95552
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_02 contains: 3000
# Using Hopper to process 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Hopper contains: 0
#   from:        5.07733 52.95552
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 136000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_03 contains: 1000
# Using Transport barge 02 to process 1000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.09260 52.96039
#   to:          5.01930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.07733 52.95552
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_02 contains: 4000
# Using Hopper to process 1000
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.04951 52.94394
# Using Transport barge 01 to process 1000
# T=1546940935.00 Start condition is satisfied, Armour_Placement_S02_B01 transporting from Armour_Stock to Armour_Layer_01 started
# Using Transport barge 01 to process 1000
# T=1546940935.00 Start condition is satisfied, Armour_Placement_S02_B02 transporting from Armour_Stock to Armour_Layer_01 started
# Nothing to move
# T=1546940935.00 Start condition is satisfied, Levvel_Placement_S01_B01 transporting from Levvel_Stock to Levvel_Layer_00 started
# Using Transport barge 01 to process 1000
# T=1546940935.00 Start condition is satisfied, Levvel_Placement_S01_B02 transporting from Levvel_Stock to Levvel_Layer_00 started
# Nothing to move
# T=1546941872.59 Stop condition is satisfied, Armour_Placement_S01_B02 transporting from Armour_Stock to Armour_Layer_00 complete
# Processed 1000:
#   from:        Clay_Stock contains: 133000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Hopper contains: 0
#   from:        5.07733 52.95552
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 135000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.09260 52.96039
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.07733 52.95552
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_02 contains: 5000
# T=1546954266.65 Stop condition is satisfied, Sand_Placement_S03 transporting from Sand_Stock to Sand_Layer_02 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_00 contains: 5000
# T=1546958971.11 Stop condition is satisfied, Armour_Placement_S01_B01 transporting from Armour_Stock to Armour_Layer_00 complete
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.04951 52.94394
#   to:          5.01930 52.94240
# Using Transport barge 02 to process 1000
# Using Transport barge 02 to process 1000
# Processed 1000:
#   from:        Clay_Stock contains: 132000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.09260 52.96039
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_03 contains: 2000
# Using Transport barge 02 to process 1000
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_03 contains: 3000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.09260 52.96039
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Armour_Stock contains: 144000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.09260 52.96039
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Armour_Stock contains: 143000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.06215 52.95060
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.06215 52.95060
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_01 contains: 1000
# Using Transport barge 02 to process 1000
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_01 contains: 2000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.06215 52.95060
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Levvel_Stock contains: 149000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.06215 52.95060
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Levvel_Stock contains: 148000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.04656 52.94579
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.04656 52.94579
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_00 contains: 1000
# Using Transport barge 02 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.04656 52.94579
#   to:          5.01930 52.94240
# Processed 1000:
#   from:        Clay_Stock contains: 131000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.09260 52.96039
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_00 contains: 2000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.04656 52.94579
#   to:          5.01930 52.94240
# Processed 1000:
#   from:        Clay_Stock contains: 130000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.09260 52.96039
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_03 contains: 4000
# Nothing to move
# T=1547268535.00 Start condition is satisfied, Clay_Placement_S05_B01 transporting from Clay_Stock to Clay_Layer_04 started
# Using Transport barge 01 to process 1000
# T=1547268535.00 Start condition is satisfied, Clay_Placement_S05_B02 transporting from Clay_Stock to Clay_Layer_04 started
# Using Transport barge 02 to process 1000
# T=1547268535.00 Start condition is satisfied, Sand_Placement_S04 transporting from Sand_Stock to Sand_Layer_03 started
# Using Hopper to process 1000
# T=1547269631.14 Stop condition is satisfied, Clay_Placement_S04_B02 transporting from Clay_Stock to Clay_Layer_03 complete
# Moved:
#   object:      Hopper contains: 0
#   from:        5.07733 52.95552
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 134000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.08997 52.96219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_03 contains: 1000
# Using Hopper to process 1000
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_03 contains: 5000
# T=1547286031.14 Stop condition is satisfied, Clay_Placement_S04_B01 transporting from Clay_Stock to Clay_Layer_03 complete
# Moved:
#   object:      Hopper contains: 0
#   from:        5.08997 52.96219
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 133000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.08997 52.96219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_03 contains: 2000
# Using Hopper to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.09260 52.96039
#   to:          5.91930 52.94240
# Moved:
#   object:      Hopper contains: 0
#   from:        5.08997 52.96219
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 132000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Processed 1000:
#   from:        Armour_Stock contains: 142000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.08997 52.96219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_03 contains: 3000
# Using Hopper to process 1000
# Moved:
#   object:      Hopper contains: 0
#   from:        5.08997 52.96219
#   to:          5.27142 52.96385
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.09260 52.96039
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Sand_Stock contains: 131000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.08997 52.96219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_03 contains: 4000
# Using Hopper to process 1000
# Processed 1000:
#   from:        Armour_Stock contains: 141000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Hopper contains: 0
#   from:        5.08997 52.96219
#   to:          5.27142 52.96385
# Processed 1000:
#   from:        Sand_Stock contains: 130000
#   by:          Hopper
#   to:          Hopper contains: 1000
# Moved:
#   object:      Hopper contains: 1000
#   from:        5.27142 52.96385
#   to:          5.08997 52.96219
# Processed 1000:
#   from:        Hopper contains: 0
#   by:          Hopper
#   to:          Sand_Layer_03 contains: 5000
# T=1547345104.96 Stop condition is satisfied, Sand_Placement_S04 transporting from Sand_Stock to Sand_Layer_03 complete
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.06215 52.95060
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.06215 52.95060
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_01 contains: 3000
# Using Transport barge 02 to process 1000
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_01 contains: 4000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.06215 52.95060
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 147000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.06215 52.95060
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 146000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.04656 52.94579
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.04656 52.94579
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_00 contains: 3000
# Using Transport barge 02 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.04656 52.94579
#   to:          5.01930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Clay_Stock contains: 129000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.10525 52.96704
# Nothing to move
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_00 contains: 4000
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.04656 52.94579
#   to:          5.01930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Clay_Stock contains: 128000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.10525 52.96704
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_04 contains: 1000
# Using Transport barge 02 to process 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_04 contains: 2000
# Using Transport barge 01 to process 1000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.10525 52.96704
#   to:          5.01930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Clay_Stock contains: 127000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.10525 52.96704
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.10525 52.96704
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Armour_Stock contains: 140000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_04 contains: 3000
# Using Transport barge 01 to process 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.10525 52.96704
#   to:          5.01930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Clay_Stock contains: 126000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.01930 52.94240
#   to:          5.10525 52.96704
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Clay_Layer_04 contains: 4000
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.06215 52.95060
# Nothing to move
# T=1547656805.80 Stop condition is satisfied, Armour_Placement_S02_B01 transporting from Armour_Stock to Armour_Layer_01 complete
# T=1547657335.00 Start condition is satisfied, Armour_Placement_S03_B01 transporting from Armour_Stock to Armour_Layer_02 started
# Using Transport barge 01 to process 1000
# T=1547657335.00 Start condition is satisfied, Armour_Placement_S03_B02 transporting from Armour_Stock to Armour_Layer_02 started
# Using Transport barge 02 to process 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_01 contains: 5000
# T=1547674952.54 Stop condition is satisfied, Armour_Placement_S02_B02 transporting from Armour_Stock to Armour_Layer_01 complete
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.10525 52.96704
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Armour_Stock contains: 139000
# ...
#   from:        5.27700 53.06387
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 64000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.27700 53.06387
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 63000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.26149 53.05929
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_17 contains: 1000
# Using Transport barge 02 to process 1000
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.26149 53.05929
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_17 contains: 2000
# Using Transport barge 01 to process 1000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.26149 53.05929
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Armour_Stock contains: 55000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.26149 53.05929
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 62000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.27700 53.06387
# T=1559273683.40 Stop condition is satisfied, Armour_Placement_S19_B01 transporting from Armour_Stock to Armour_Layer_18 complete
# T=1559274535.00 Start condition is satisfied, Armour_Placement_S20_B01 transporting from Armour_Stock to Armour_Layer_19 started
# Nothing to move
# T=1559274535.00 Start condition is satisfied, Armour_Placement_S20_B02 transporting from Armour_Stock to Armour_Layer_19 started
# Using Transport barge 02 to process 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_18 contains: 5000
# T=1559292070.75 Stop condition is satisfied, Armour_Placement_S19_B02 transporting from Armour_Stock to Armour_Layer_18 complete
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.26149 53.05929
# Using Transport barge 01 to process 1000
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_17 contains: 3000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.27700 53.06387
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Levvel_Stock contains: 61000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.26149 53.05929
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Armour_Stock contains: 54000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.26149 53.05929
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_17 contains: 4000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28964 53.07053
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_19 contains: 1000
# Using Transport barge 01 to process 1000
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.26149 53.05929
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Armour_Stock contains: 53000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.28964 53.07053
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 60000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28964 53.07053
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_19 contains: 2000
# Using Transport barge 02 to process 1000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.26149 53.05929
# T=1559504935.00 Start condition is satisfied, Levvel_Placement_S19_B01 transporting from Levvel_Stock to Levvel_Layer_18 started
# Using Transport barge 01 to process 1000
# T=1559504935.00 Start condition is satisfied, Levvel_Placement_S19_B02 transporting from Levvel_Stock to Levvel_Layer_18 started
# Using Transport barge 02 to process 1000
# T=1559507951.79 Stop condition is satisfied, Levvel_Placement_S18_B02 transporting from Levvel_Stock to Levvel_Layer_17 complete
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_17 contains: 5000
# T=1559524476.81 Stop condition is satisfied, Levvel_Placement_S18_B01 transporting from Levvel_Stock to Levvel_Layer_17 complete
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.28964 53.07053
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Armour_Stock contains: 52000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.26149 53.05929
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Armour_Stock contains: 51000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28964 53.07053
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_19 contains: 3000
# Using Transport barge 02 to process 1000
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28964 53.07053
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_19 contains: 4000
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.28964 53.07053
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 59000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.28964 53.07053
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 58000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.27413 53.06596
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_18 contains: 1000
# Using Transport barge 02 to process 1000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.27413 53.06596
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_18 contains: 2000
# Using Transport barge 01 to process 1000
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.27413 53.06596
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Armour_Stock contains: 50000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.27413 53.06596
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 57000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28964 53.07053
# T=1559789858.57 Stop condition is satisfied, Armour_Placement_S20_B01 transporting from Armour_Stock to Armour_Layer_19 complete
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Armour_Layer_19 contains: 5000
# T=1559808550.25 Stop condition is satisfied, Armour_Placement_S20_B02 transporting from Armour_Stock to Armour_Layer_19 complete
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.27413 53.06596
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_18 contains: 3000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.28964 53.07053
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Levvel_Stock contains: 56000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.27413 53.06596
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Levvel_Stock contains: 55000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.27413 53.06596
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_18 contains: 4000
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.27413 53.06596
# T=1559918935.00 Start condition is satisfied, Levvel_Placement_S20_B01 transporting from Levvel_Stock to Levvel_Layer_19 started
# Using Transport barge 01 to process 1000
# T=1559918935.00 Start condition is satisfied, Levvel_Placement_S20_B02 transporting from Levvel_Stock to Levvel_Layer_19 started
# Using Transport barge 02 to process 1000
# T=1559919071.00 Stop condition is satisfied, Levvel_Placement_S19_B02 transporting from Levvel_Stock to Levvel_Layer_18 complete
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_18 contains: 5000
# T=1559938862.24 Stop condition is satisfied, Levvel_Placement_S19_B01 transporting from Levvel_Stock to Levvel_Layer_18 complete
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.27413 53.06596
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Levvel_Stock contains: 54000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.27413 53.06596
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Levvel_Stock contains: 53000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28678 53.07264
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28678 53.07264
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_19 contains: 1000
# Using Transport barge 02 to process 1000
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_19 contains: 2000
# Using Transport barge 01 to process 1000
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.28678 53.07264
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Levvel_Stock contains: 52000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Moved:
#   object:      Transport barge 01 contains: 0
#   from:        5.28678 53.07264
#   to:          5.91930 52.94240
# Processed 1000:
#   from:        Levvel_Stock contains: 51000
#   by:          Gantry crane
#   to:          Transport barge 01 contains: 1000
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28678 53.07264
# Moved:
#   object:      Transport barge 01 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28678 53.07264
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_19 contains: 3000
# Using Transport barge 02 to process 1000
# Processed 1000:
#   from:        Transport barge 01 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_19 contains: 4000
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 0
#   from:        5.28678 53.07264
#   to:          5.91930 52.94240
# Nothing to move
# Nothing to move
# Nothing to move
# Processed 1000:
#   from:        Levvel_Stock contains: 50000
#   by:          Gantry crane
#   to:          Transport barge 02 contains: 1000
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Nothing to move
# Moved:
#   object:      Transport barge 02 contains: 1000
#   from:        5.91930 52.94240
#   to:          5.28678 53.07264
# T=1560209903.74 Stop condition is satisfied, Levvel_Placement_S20_B01 transporting from Levvel_Stock to Levvel_Layer_19 complete
# Processed 1000:
#   from:        Transport barge 02 contains: 0
#   by:          Installation crane
#   to:          Levvel_Layer_19 contains: 5000
# T=1560228007.86 Stop condition is satisfied, Levvel_Placement_S20_B02 transporting from Levvel_Stock to Levvel_Layer_19 complete
#
# *** Installation of dike finished in 18058 days, 4:40:07 ***

# %% [markdown]
# ## Analysing the Results
#
# In addition to the print statements provided by the Activity class, it also enters log entries into the logs of the origin, destination, mover, loader and unloader to mark when events such as loading or unloading the mover took place. For the mover, origin and destination, these log entries also contain the level of the container at the time of the log entry. This can be used for some basic visualisation of the simulation in Google Earth.

# %% [markdown]
# Using the information in the log you could also create plots of the usage of each piece of equipment during the simulation. For example, the code below creates a plot of the usage of the two transporting barges.

# %%
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
class plot:
    """plot class"""

    def vessel_planning(vessels, activities, colors, web=False):
        """create a plot of the planning of vessels"""

        def get_segments(series, activity, y_val):
            """extract 'start' and 'stop' of activities from log"""
            x = []
            y = []
            for i, v in series.iteritems():
                if v == activity + ' start':
                    start = i
                if v == activity + ' stop':
                    x.extend((start, start, i, i, i))
                    y.extend((y_val, y_val, y_val, y_val, None))
            return x, y

        # organise logdata into 'dataframes' 
        dataframes = []
        for vessel in vessels:
            df = pd.DataFrame(
                {'log_value': vessel.value, 'log_string': vessel.log}, vessel.t)
            dataframes.append(df)
        df = dataframes[0]

        # prepare traces for each of the activities
        traces = []
        for i, activity in enumerate(activities):
            x_combined = []
            y_combined = []
            for k, df in enumerate(dataframes):
                y_val = vessels[k].name
                x, y = get_segments(
                    df['log_string'], activity=activity, y_val=y_val)
                x_combined.extend(x)
                y_combined.extend(y)
            traces.append(go.Scatter(
                name=activity,
                x=x_combined,
                y=y_combined,
                mode='lines',
                hoverinfo='y+name',
                line=dict(color=colors[i], width=10),
                connectgaps=False))
        
        # prepare layout of figure
        layout = go.Layout(
            title='Vessel planning',
            hovermode='closest',
            legend=dict(x=0, y=-.2, orientation="h"),
            xaxis=dict(
                title='Time',
                titlefont=dict(
                    family='Courier New, monospace',
                    size=18,
                    color='#7f7f7f'),
                range=[0, vessel.t[-1]]),
            yaxis=dict(
                title='Vessels',
                titlefont=dict(
                    family='Courier New, monospace',
                    size=18,
                    color='#7f7f7f')))
        
        # plot figure
        init_notebook_mode(connected=True)        
        fig = go.Figure(data=traces, layout=layout)
        return iplot(fig, filename='news-source')

# %%
vessels = [transport_barge_01, transport_barge_02, hopper]
activities = ['loading', 'unloading', 'sailing full', 'sailing empty', 'waiting for spill']
colors = {0:'rgb(55,126,184)', 1:'rgb(77,175,74)', 2:'rgb(255,0,0)', 3:'rgb(255,150,0)', 4:'rgb(255, 0, 0)'}

plot.vessel_planning(vessels, activities, colors)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="6f21dc92-b6b3-4aa1-93c2-85ccf6800d07" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6f21dc92-b6b3-4aa1-93c2-85ccf6800d07", [{"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(55,126,184)", "width": 10}, "mode": "lines", "name": "loading", "x": [1545126535.003989, 1545126535.003989, 1545136535.003989, 1545136535.003989, 1545136535.003989, 1546357627.873304, 1546357627.873304, 1546367627.873304, 1546367627.873304, 1546367627.873304, 1546397627.873304, 1546397627.873304, 1546407627.873304, 1546407627.873304, 1546407627.873304, 1546437627.873304, 1546437627.873304, 1546447627.873304, 1546447627.873304, 1546447627.873304, 1546478178.6596296, 1546478178.6596296, 1546488178.6596296, 1546488178.6596296, 1546488178.6596296, 1546551931.6112974, 1546551931.6112974, 1546561931.6112974, 1546561931.6112974, 1546561931.6112974, 1546641677.1818218, 1546641677.1818218, 1546651677.1818218, 1546651677.1818218, 1546651677.1818218, 1546711215.5234973, 1546711215.5234973, 1546721215.5234973, 1546721215.5234973, 1546721215.5234973, 1546800961.0940218, 1546800961.0940218, 1546810961.0940218, 1546810961.0940218, 1546810961.0940218, 1546870499.4356973, 1546870499.4356973, 1546880499.4356973, 1546880499.4356973, 1546880499.4356973, 1546960245.0062218, 1546960245.0062218, 1546970245.0062218, 1546970245.0062218, 1546970245.0062218, 1547033721.1440895, 1547033721.1440895, 1547043721.1440895, 1547043721.1440895, 1547043721.1440895, 1547157361.169602, 1547157361.169602, 1547167361.169602, 1547167361.169602, 1547167361.169602, 1547247200.4995074, 1547247200.4995074, 1547257200.4995074, 1547257200.4995074, 1547257200.4995074, 1547320781.1711955, 1547320781.1711955, 1547330781.1711955, 1547330781.1711955, 1547330781.1711955, 1547444421.196708, 1547444421.196708, 1547454421.196708, 1547454421.196708, 1547454421.196708, 1547534260.5266135, 1547534260.5266135, 1547544260.5266135, 1547544260.5266135, 1547544260.5266135, 1547577087.5941594, 1547577087.5941594, 1547587087.5941594, 1547587087.5941594, 1547587087.5941594, 1547617478.3163388, 1547617478.3163388, 1547627478.3163388, 1547627478.3163388, 1547627478.3163388, 1547691571.7552118, 1547691571.7552118, 1547701571.7552118, 1547701571.7552118, 1547701571.7552118, 1547813851.6222868, 1547813851.6222868, 1547823851.6222868, 1547823851.6222868, 1547823851.6222868, 1547936131.4893618, 1547936131.4893618, 1547946131.4893618, 1547946131.4893618, 1547946131.4893618, 1548025773.5758748, 1548025773.5758748, 1548035773.5758748, 1548035773.5758748, 1548035773.5758748, 1548096989.3153398, 1548096989.3153398, 1548106989.3153398, 1548106989.3153398, 1548106989.3153398, 1548219269.1824148, 1548219269.1824148, 1548229269.1824148, 1548229269.1824148, 1548229269.1824148, 1548308911.2689278, 1548308911.2689278, 1548318911.2689278, 1548318911.2689278, 1548318911.2689278, 1548380127.0083928, 1548380127.0083928, 1548390127.0083928, 1548390127.0083928, 1548390127.0083928, 1548501063.7222958, 1548501063.7222958, 1548511063.7222958, 1548511063.7222958, 1548511063.7222958, 1548590705.8088088, 1548590705.8088088, 1548600705.8088088, 1548600705.8088088, 1548600705.8088088, 1548661921.5482738, 1548661921.5482738, 1548671921.5482738, 1548671921.5482738, 1548671921.5482738, 1548782858.2621768, 1548782858.2621768, 1548792858.2621768, 1548792858.2621768, 1548792858.2621768, 1548872344.7657528, 1548872344.7657528, 1548882344.7657528, 1548882344.7657528, 1548882344.7657528, 1548945038.390681, 1548945038.390681, 1548955038.390681, 1548955038.390681, 1548955038.390681, 1549034524.894257, 1549034524.894257, 1549044524.894257, 1549044524.894257, 1549044524.894257, 1549106341.8572345, 1549106341.8572345, 1549116341.8572345, 1549116341.8572345, 1549116341.8572345, 1549228528.8268971, 1549228528.8268971, 1549238528.8268971, 1549238528.826897 ...

# %% [markdown]
# ### Check sites

# %%
print(stocks[0].SpillConditions["Spill limit"][0].level)
print(stocks[1].SpillConditions["Spill limit"][0].level)
print(stocks[2].SpillConditions["Spill limit"][0].level)
print(stocks[3].SpillConditions["Spill limit"][0].level)
# Out:
# 0
# 0
# 0
# 0

# %%
vessels[1].log
# Out:
# ['waiting for spill start',
#  'waiting for spill stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  'sailing empty start',
#  'sailing empty stop',
#  'loading start',
#  'loading stop',
#  'sailing full start',
#  'sailing full stop',
#  'unloading start',
#  'unloading stop',
#  ...]

# %%
stocks[0].value
# Out:
# [150000,
#  149000,
#  6750.0,
#  149000,
#  148000,
#  6750.0,
#  148000,
#  147000,
#  6750.0,
#  147000,
#  146000,
#  6750.0,
#  146000,
#  145000,
#  6750.0,
#  145000,
#  144000,
#  6750.0,
#  144000,
#  143000,
#  6750.0,
#  143000,
#  142000,
#  6750.0,
#  142000,
#  141000,
#  6750.0,
#  141000,
#  140000,
#  6750.0,
#  140000,
#  139000,
#  6750.0,
#  139000,
#  138000,
#  6750.0,
#  138000,
#  137000,
#  6750.0,
#  137000,
#  136000,
#  6750.0,
#  136000,
#  135000,
#  6750.0,
#  135000,
#  134000,
#  6750.0,
#  134000,
#  133000,
#  6750.0,
#  133000,
#  132000,
#  6750.0,
#  132000,
#  131000,
#  6750.0,
#  131000,
#  130000,
#  6750.0,
#  130000,
#  129000,
#  6750.0,
#  129000,
#  128000,
#  6750.0,
#  128000,
#  127000,
#  6750.0,
#  127000,
#  126000,
#  6750.0,
#  126000,
#  125000,
#  6750.0,
#  125000,
#  124000,
#  6750.0,
#  124000,
#  123000,
#  6750.0,
#  123000,
#  122000,
#  6750.0,
#  122000,
#  121000,
#  6750.0,
#  121000,
#  120000,
#  6750.0,
#  120000,
#  119000,
#  6750.0,
#  119000,
#  118000,
#  6750.0,
#  118000,
#  117000,
#  6750.0,
#  117000,
#  116000,
#  6750.0,
#  116000,
#  115000,
#  6750.0,
#  115000,
#  114000,
#  6750.0,
#  114000,
#  113000,
#  6750.0,
#  113000,
#  112000,
#  6750.0,
#  112000,
#  111000,
#  6750.0,
#  111000,
#  110000,
#  6750.0,
#  110000,
#  109000,
#  6750.0,
#  109000,
#  108000,
#  6750.0,
#  108000,
#  107000,
#  6750.0,
#  107000,
#  106000,
#  6750.0,
#  106000,
#  105000,
#  6750.0,
#  105000,
#  104000,
#  6750.0,
#  104000,
#  103000,
#  6750.0,
#  103000,
#  102000,
#  6750.0,
#  102000,
#  101000,
#  6750.0,
#  101000,
#  100000,
#  6750.0,
#  100000,
#  99000,
#  6750.0,
#  99000,
#  98000,
#  6750.0,
#  98000,
#  97000,
#  6750.0,
#  97000,
#  96000,
#  6750.0,
#  96000,
#  95000,
#  6750.0,
#  95000,
#  94000,
#  6750.0,
#  94000,
#  93000,
#  6750.0,
#  93000,
#  92000,
#  6750.0,
#  92000,
#  91000,
#  6750.0,
#  91000,
#  90000,
#  6750.0,
#  90000,
#  89000,
#  6750.0,
#  89000,
#  88000,
#  6750.0,
#  88000,
#  87000,
#  6750.0,
#  87000,
#  86000,
#  6750.0,
#  86000,
#  85000,
#  6750.0,
#  85000,
#  84000,
#  6750.0,
#  84000,
#  83000,
#  6750.0,
#  83000,
#  82000,
#  6750.0,
#  82000,
#  81000,
#  6750.0,
#  81000,
#  80000,
#  6750.0,
#  80000,
#  79000,
#  6750.0,
#  79000,
#  78000,
#  6750.0,
#  78000,
#  77000,
#  6750.0,
#  77000,
#  76000,
#  6750.0,
#  76000,
#  75000,
#  6750.0,
#  75000,
#  74000,
#  6750.0,
#  74000,
#  73000,
#  6750.0,
#  73000,
#  72000,
#  6750.0,
#  72000,
#  71000,
#  6750.0,
#  71000,
#  70000,
#  6750.0,
#  70000,
#  69000,
#  6750.0,
#  69000,
#  68000,
#  6750.0,
#  68000,
#  67000,
#  6750.0,
#  67000,
#  66000,
#  6750.0,
#  66000,
#  65000,
#  6750.0,
#  65000,
#  64000,
#  6750.0,
#  64000,
#  63000,
#  6750.0,
#  63000,
#  62000,
#  6750.0,
#  62000,
#  61000,
#  6750.0,
#  61000,
#  60000,
#  6750.0,
#  60000,
#  59000,
#  6750.0,
#  59000,
#  58000,
#  6750.0,
#  58000,
#  57000,
#  6750.0,
#  57000,
#  56000,
#  6750.0,
#  56000,
#  55000,
#  6750.0,
#  55000,
#  54000,
#  6750.0,
#  54000,
#  53000,
#  6750.0,
#  53000,
#  52000,
#  6750.0,
#  52000,
#  51000,
#  6750.0,
#  51000,
#  50000,
#  6750.0]
